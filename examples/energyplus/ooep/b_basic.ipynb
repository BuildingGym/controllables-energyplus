# %%
#%load_ext autoreload
#%autoreload all

# %% [markdown]
# # Programming

# %% [markdown]
# ## Setup

# %% [markdown]
# Run the below code in a cell to install the dependencies.
#
# ```python
# %pip install --quiet tqdm pandas
# %pip install --quiet --extra-index-url https://test.pypi.org/simple/ git+https://github.com/NTU-CCA-HVAC-OPTIM-a842a748/EnergyPlus-OOEP
# # NOTE local repo
# #%pip install --extra-index-url https://test.pypi.org/simple/ ../../..
# %pip install git+https://github.com/NTU-CCA-HVAC-OPTIM-a842a748/EnergyPlus-Datasets.git
# ```

# %% [markdown]
# ## Importing ~~`pyenergyplus`~~ `ooep`

# %%
import energyplus.ooep as ooep
import energyplus.ooep.ems

# %% [markdown]
# ## `ooep` - EnergyPlus API, Object-Oriented

# %% [markdown]
# <table style="text-align: center">
#     <caption>Architecture Overview (*NIX)</caption>
#     <tr>
#         <th>EnergyPlus<br>OO Abstraction Layer</th>
#         <th rowspan="2">&rlhar;</th>
#         <th colspan="3">EnergyPlus<br>State Machine</th>
#     </tr>
#     <tr>
#         <td>
#             API<br>
#             <code>ooep</code>
#         </td>
#         <td>
#             API<br>
#             (<code>pyenergyplus</code>)<br>
#             (<code>libenergyplusapi.so</code>)
#         </td>
#         <td>ABI<br>&rlhar;</td>
#         <td>Kernel<br>(<code>energyplus</code>)</td>
#     </tr>
# </table>

# %%
from energyplus.dataset.basic import dataset as epds

list(epds.models.glob('*.idf'))[:10]
# Out:
# [PosixPath('/home/sysadmin/.local/lib/python3.11/site-packages/energyplus/dataset/basic/assets/models/5ZoneWaterCooled_Baseboard.idf'),
#  PosixPath('/home/sysadmin/.local/lib/python3.11/site-packages/energyplus/dataset/basic/assets/models/PipeHeatTransfer_Schedule.idf'),
#  PosixPath('/home/sysadmin/.local/lib/python3.11/site-packages/energyplus/dataset/basic/assets/models/5ZoneNightVent2.idf'),
#  PosixPath('/home/sysadmin/.local/lib/python3.11/site-packages/energyplus/dataset/basic/assets/models/UserDefinedRoomAirPatterns.idf'),
#  PosixPath('/home/sysadmin/.local/lib/python3.11/site-packages/energyplus/dataset/basic/assets/models/DualDuctVarVolDamper.idf'),
#  PosixPath('/home/sysadmin/.local/lib/python3.11/site-packages/energyplus/dataset/basic/assets/models/PythonPluginCurveOverride_PackagedTerminalHeatPump.idf'),
#  PosixPath('/home/sysadmin/.local/lib/python3.11/site-packages/energyplus/dataset/basic/assets/models/ZoneWSHP_wDOAS.idf'),
#  PosixPath('/home/sysadmin/.local/lib/python3.11/site-packages/energyplus/dataset/basic/assets/models/HeatPumpWaterToAirWithRHControl.idf'),
#  PosixPath('/home/sysadmin/.local/lib/python3.11/site-packages/energyplus/dataset/basic/assets/models/UnitVent5ZoneFixedOANoCoilOpt.idf'),
#  PosixPath('/home/sysadmin/.local/lib/python3.11/site-packages/energyplus/dataset/basic/assets/models/HVACTemplate-5ZoneDualDuct.idf')]

# %% [markdown]
# ### `ooep` in Action

# %% [markdown]
# #### Setup

# %% [markdown]
# - (Context/State Management) Enter `ooep.ems` environment...
#   Don't forget to `__close__` it when done \
#   OR better yet, just use `python`'s `with`-statement:
#   ```python
#     import ooep.ems
#     with ooep.ems.Environment() as e:
#         # NOTE do whatever you need to do with `e`
#         ...
#   ```

# %%
env = ooep.ems.Environment().__enter__()

# %% [markdown]
# - 🎉

# %%
env('--help', verbose=True)
# Out:
# PythonLinkage: This version of EnergyPlus not linked to Python library.
# Built on Platform: Ubuntu22.04_x86_64
#
# Usage: energyplus [OPTIONS] [input_file]
#
# Positionals:
#   input_file TEXT:FILE        Input file (default: in.idf in current directory)
#
# Options:
#   -h,--help                   Print this help message and exit
#   -v,--version                Display program version information and exit
#   -a,--annual Excludes: --design-day
#                               Force annual simulation
#   -D,--design-day Excludes: --annual
#                               Force design-day-only simulation
#   -d,--output-directory DIR   Output directory path (default: current directory)
#   -i,--idd IDD                Input data dictionary path (default: Energy+.idd in executable directory)
#   -m,--epmacro                Run EPMacro prior to simulation
#   -p,--output-prefix PRE      Prefix for output file names (default: eplus)
#   -r,--readvars               Run ReadVarsESO after simulation
#   -c,--convert
# 0
#   Output IDF->epJSON or epJSON->IDF, dependent on input file type
#   --convert-only              Only convert IDF->epJSON or epJSON->IDF, dependent on input file type. No simulation
#   -s,--output-suffix SUFFIX   Suffix style for output file names (default: L)
#                                  L: Legacy (e.g., eplustbl.csv)
#                                  C: Capital (e.g., eplusTable.csv)
#                                  D: Dash (e.g., eplus-table.csv)
#   -j,--jobs N                 Multi-thread with N threads; 1 thread with no arg. (Currently only for G-Function generation)
#   -w,--weather EPW            Weather file path (default: in.epw in current directory)
#   -x,--expandobjects          Run ExpandObjects prior to simulation
#
#
# Example: energyplus -w weather.epw -r input.idf

# %%
env = env.__enter__()

env(
    # TODO
    '--design-day',
    '--output-directory', 'build/demo-eplus',
    '--weather', f'{epds.weathers}/USA_FL_Tampa.Intl.AP.722110_TMY3.epw',
    #f'{epds.models}/CoolingTower_VariableSpeed_MultiCell.idf'
    f'{epds.models}/ASHRAE901_OfficeLarge_STD2019_Denver_Chiller205_Detailed.idf'
)
# Out:
# 0

# %% [markdown]
# #### Variables

# %%
env.specs.variables
# Out:
#                                           variable_name  \
# 0                  Site Outdoor Air Drybulb Temperature
# 1                 Site Outdoor Air Dewpoint Temperature
# 2                  Site Outdoor Air Wetbulb Temperature
# 3                                       Site Wind Speed
# 4                                  Site Sky Temperature
# ...                                                 ...
# 2095  Zone Mechanical Ventilation No Load Heat Addit...
# 2096  Zone Mechanical Ventilation Heating Load Incre...
# 2097  Zone Mechanical Ventilation Heating Load Incre...
# 2098  Zone Mechanical Ventilation Heating Load Decre...
# 2099   Zone Mechanical Ventilation Air Changes per Hour
#
#                   variable_key
# 0                  ENVIRONMENT
# 1                  ENVIRONMENT
# 2                  ENVIRONMENT
# 3                  ENVIRONMENT
# 4                  ENVIRONMENT
# ...                        ...
# 2095  DATACENTER_BASEMENT_ZN_6
# 2096  DATACENTER_BASEMENT_ZN_6
# 2097  DATACENTER_BASEMENT_ZN_6
# 2098  DATACENTER_BASEMENT_ZN_6
# 2099  DATACENTER_BASEMENT_ZN_6
#
# [2100 rows x 2 columns]

# %% [markdown]
# - Variable keys

# %%
env.specs.variables['variable_key'].unique()
# Out:
# array(['ENVIRONMENT', 'BASEMENT', 'CORE_BOTTOM', 'CORE_MID', 'CORE_TOP',
#        'PERIMETER_BOT_ZN_3', 'PERIMETER_BOT_ZN_2', 'PERIMETER_BOT_ZN_1',
#        'PERIMETER_BOT_ZN_4', 'PERIMETER_MID_ZN_3', 'PERIMETER_MID_ZN_2',
#        'PERIMETER_MID_ZN_1', 'PERIMETER_MID_ZN_4', 'PERIMETER_TOP_ZN_3',
#        'PERIMETER_TOP_ZN_2', 'PERIMETER_TOP_ZN_1', 'PERIMETER_TOP_ZN_4',
#        'GROUNDFLOOR_PLENUM', 'MIDFLOOR_PLENUM', 'TOPFLOOR_PLENUM',
#        'DATACENTER_BOT_ZN_6', 'DATACENTER_MID_ZN_6',
#        'DATACENTER_TOP_ZN_6', 'DATACENTER_BASEMENT_ZN_6',
#        'BASEMENT_LIGHTS', 'CORE_BOTTOM_LIGHTS', 'CORE_MID_LIGHTS',
#        'CORE_TOP_LIGHTS', 'PERIMETER_BOT_ZN_3_LIGHTS',
#        'PERIMETER_BOT_ZN_2_LIGHTS', 'PERIMETER_BOT_ZN_1_LIGHTS',
#        'PERIMETER_BOT_ZN_4_LIGHTS', 'PERIMETER_MID_ZN_3_LIGHTS',
#        'PERIMETER_MID_ZN_2_LIGHTS', 'PERIMETER_MID_ZN_1_LIGHTS',
#        'PERIMETER_MID_ZN_4_LIGHTS', 'PERIMETER_TOP_ZN_3_LIGHTS',
#        'PERIMETER_TOP_ZN_2_LIGHTS', 'PERIMETER_TOP_ZN_1_LIGHTS',
#        'PERIMETER_TOP_ZN_4_LIGHTS', 'DATACENTER_BASEMENT_LIGHTS',
#        'DATACENTER_BOT_LIGHTS', 'DATACENTER_MID_LIGHTS',
#        'DATACENTER_TOP_LIGHTS', 'BASEMENT_MISCPLUG_EQUIP',
#        'CORE_BOTTOM_MISCPLUG_EQUIP', 'CORE_MID_MISCPLUG_EQUIP',
#        'CORE_TOP_MISCPLUG_EQUIP', 'PERIMETER_BOT_ZN_3_MISCPLUG_EQUIP',
#        'PERIMETER_BOT_ZN_2_MISCPLUG_EQUIP',
#        'PERIMETER_BOT_ZN_1_MISCPLUG_EQUIP',
#        'PERIMETER_BOT_ZN_4_MISCPLUG_EQUIP',
#        'PERIMETER_MID_ZN_3_MISCPLUG_EQUIP',
#        'PERIMETER_MID_ZN_2_MISCPLUG_EQUIP',
#        'PERIMETER_MID_ZN_1_MISCPLUG_EQUIP',
#        'PERIMETER_MID_ZN_4_MISCPLUG_EQUIP',
#        'PERIMETER_TOP_ZN_3_MISCPLUG_EQUIP',
#        'PERIMETER_TOP_ZN_2_MISCPLUG_EQUIP',
#        'PERIMETER_TOP_ZN_1_MISCPLUG_EQUIP',
#        'PERIMETER_TOP_ZN_4_MISCPLUG_EQUIP',
#        'DATACENTER_BASEMENT_MISCPLUG_EQUIP',
#        'DATACENTER_BOT_MISCPLUG_EQUIP', 'DATACENTER_MID_MISCPLUG_EQUIP',
#        'DATACENTER_TOP_MISCPLUG_EQUIP', 'EMS',
#        'PERIMETER_BOT_ZN_3_WALL_NORTH_WINDOW1',
#        'PERIMETER_BOT_ZN_3_WALL_NORTH_WINDOW2',
#        'PERIMETER_BOT_ZN_3_WALL_NORTH_WINDOW3',
#        'PERIMETER_BOT_ZN_3_WALL_NORTH_WINDOW4',
#        'PERIMETER_BOT_ZN_3_WALL_NORTH_WINDOW5',
#        'PERIMETER_BOT_ZN_2_WALL_EAST_WINDOW1',
#        'PERIMETER_BOT_ZN_2_WALL_EAST_WINDOW2',
#        'PERIMETER_BOT_ZN_2_WALL_EAST_WINDOW3',
#        'PERIMETER_BOT_ZN_1_WALL_SOUTH_WINDOW1',
#        'PERIMETER_BOT_ZN_1_WALL_SOUTH_WINDOW2',
#        'PERIMETER_BOT_ZN_1_WALL_SOUTH_WINDOW3',
#        'PERIMETER_BOT_ZN_1_WALL_SOUTH_WINDOW4',
#        'PERIMETER_BOT_ZN_1_WALL_SOUTH_WINDOW5',
#        'PERIMETER_BOT_ZN_4_WALL_WEST_WINDOW1',
#        'PERIMETER_BOT_ZN_4_WALL_WEST_WINDOW2',
#        'PERIMETER_BOT_ZN_4_WALL_WEST_WINDOW3',
#        'PERIMETER_MID_ZN_3_WALL_NORTH_WINDOW',
#        'PERIMETER_MID_ZN_2_WALL_EAST_WINDOW',
#        'PERIMETER_MID_ZN_1_WALL_SOUTH_WINDOW',
#        'PERIMETER_MID_ZN_4_WALL_WEST_WINDOW',
#        'PERIMETER_TOP_ZN_3_WALL_NORTH_WINDOW',
#        'PERIMETER_TOP_ZN_2_WALL_EAST_WINDOW',
#        'PERIMETER_TOP_ZN_1_WALL_SOUTH_WINDOW',
#        'PERIMETER_TOP_ZN_4_WALL_WEST_WINDOW',
#        'PERIMETER_BOT_ZN_1_DAYLCTRL', 'PERIMETER_BOT_ZN_2_DAYLCTRL',
#        'PERIMETER_BOT_ZN_3_DAYLCTRL', 'PERIMETER_BOT_ZN_4_DAYLCTRL',
#        'PERIMETER_MID_ZN_1_DAYLCTRL', 'PERIMETER_MID_ZN_2_DAYLCTRL',
#        'PERIMETER_MID_ZN_3_DAYLCTRL', 'PERIMETER_MID_ZN_4_DAYLCTRL',
#        'PERIMETER_TOP_ZN_1_DAYLCTRL', 'PERIMETER_TOP_ZN_2_DAYLCTRL',
#        'PERIMETER_TOP_ZN_3_DAYLCTRL', 'PERIMETER_TOP_ZN_4_DAYLCTRL',
#        'SIMHVAC', 'CORE_BOTTOM SUB CAT', 'CORE_MID SUB CAT',
#        'CORE_TOP SUB CAT', 'COOLSYS1 CHILLER1', 'COOLSYS1 CHILLER2',
#        'CENTRAL TOWER', 'SHWSYS1', 'HEATSYS1', 'COOLSYS1_SUPPLY',
#        'COOLSYS1_DEMAND', 'SINGLE WATER PLANT LOOP', 'TOWERWATERSYS',
#        'TRANSFORMER 1', 'WHOLE BUILDING', 'DATACENTER_EXTRAWATERHEATC',
#        'CORE_BOTTOM VAV BOX REHEAT COIL', 'CORE_MID VAV BOX REHEAT COIL',
#        'CORE_TOP VAV BOX REHEAT COIL',
#        'PERIMETER_BOT_ZN_3 VAV BOX REHEAT COIL',
#        'PERIMETER_BOT_ZN_2 VAV BOX REHEAT COIL',
#        'PERIMETER_BOT_ZN_1 VAV BOX REHEAT COIL',
#        'PERIMETER_BOT_ZN_4 VAV BOX REHEAT COIL',
#        'PERIMETER_MID_ZN_3 VAV BOX REHEAT COIL',
#        'PERIMETER_MID_ZN_2 VAV BOX REHEAT COIL',
#        'PERIMETER_MID_ZN_1 VAV BOX REHEAT COIL',
#        'PERIMETER_MID_ZN_4 VAV BOX REHEAT COIL',
#        'PERIMETER_TOP_ZN_3 VAV BOX REHEAT COIL',
#        'PERIMETER_TOP_ZN_2 VAV BOX REHEAT COIL',
#        'PERIMETER_TOP_ZN_1 VAV BOX REHEAT COIL',
#        'PERIMETER_TOP_ZN_4 VAV BOX REHEAT COIL', 'CAV_BAS_HEATC',
#        'VAV_BOT WITH REHEAT_HEATC', 'VAV_MID WITH REHEAT_HEATC',
#        'VAV_TOP WITH REHEAT_HEATC', 'CAV_BAS_COOLC',
#        'VAV_BOT WITH REHEAT_COOLC', 'VAV_MID WITH REHEAT_COOLC',
#        'VAV_TOP WITH REHEAT_COOLC', 'CAV_BAS FAN',
#        'VAV_BOT WITH REHEAT FAN', 'VAV_MID WITH REHEAT FAN',
#        'VAV_TOP WITH REHEAT FAN', 'DATACENTER BASEMENT SUPPLY FAN',
#        'DATACENTER BOT SUPPLY FAN', 'DATACENTER MID SUPPLY FAN',
#        'DATACENTER TOP SUPPLY FAN', 'EXTERIOR_LIGHTS_A',
#        'EXTERIOR_LIGHTS_B', 'EXTERIOR_LIGHTS_C', 'ELEVATORS',
#        'ELEVATORS_LIGHTS_FAN', 'VAV_BOT WITH REHEAT',
#        'VAV_MID WITH REHEAT', 'VAV_TOP WITH REHEAT',
#        'HEAT PUMP COOLING MODE AIRLOOP DATACENTER BASEMENT',
#        'HEAT PUMP COOLING MODE AIRLOOP DATACENTER BOT',
#        'HEAT PUMP COOLING MODE AIRLOOP DATACENTER MID',
#        'HEAT PUMP COOLING MODE AIRLOOP DATACENTER TOP',
#        'HEAT PUMP HEATING MODE AIRLOOP DATACENTER BASEMENT',
#        'HEAT PUMP HEATING MODE AIRLOOP DATACENTER BOT',
#        'HEAT PUMP HEATING MODE AIRLOOP DATACENTER MID',
#        'HEAT PUMP HEATING MODE AIRLOOP DATACENTER TOP',
#        'DATACENTER_EXTRAELECHEATC',
#        'HEAT PUMP DX SUPP HEATING COIL AIRLOOP DATACENTER BASEMENT',
#        'HEAT PUMP DX SUPP HEATING COIL AIRLOOP DATACENTER BOT',
#        'HEAT PUMP DX SUPP HEATING COIL AIRLOOP DATACENTER MID',
#        'HEAT PUMP DX SUPP HEATING COIL AIRLOOP DATACENTER TOP',
#        'DATACENTER BASEMENT HUMIDIFIER', 'BYPASS HEAT EXCHANGER',
#        'SHWSYS1 WATER HEATER', 'HEATSYS1 BOILER', 'DUMMY BOILER',
#        'TOWERWATERSYS COOLTOWER 1', 'TOWERWATERSYS COOLTOWER 2',
#        'HEATSYS1 PUMP', 'COOLSYS1 PUMP SECONDARY', 'SHWSYS1 PUMP',
#        'COOLSYS1 CHILLER1 PUMP', 'COOLSYS1 CHILLER2 PUMP',
#        'PLANT CIRC PUMP', 'TOWERWATERSYS PUMP', 'TOWER_FAN_CURVE',
#        'VAV_BOT WITH REHEAT_OA-VAV WITH REHEAT_COOLCNODE',
#        'VAV_MID WITH REHEAT_OA-VAV WITH REHEAT_COOLCNODE',
#        'VAV_TOP WITH REHEAT_OA-VAV WITH REHEAT_COOLCNODE',
#        'TOWERWATERSYS SUPPLY INLET NODE',
#        'DATACENTER_HUMIDIFIER-DATACENTER_EXTRAELECHEATCNODE',
#        'DATACENTER_EXTRAELECHEATC-DATACENTER_EXTRAWATERHEATCNODE',
#        'COOLING COIL AIR OUTLET NODE AIRLOOP DATACENTER BASEMENT',
#        'AIRLOOP DATACENTER BASEMENT SUPPLY FAN OUTLET', 'SITE', 'CAV_BAS',
#        'AIRLOOP DATACENTER BASEMENT', 'AIRLOOP DATACENTER BOT',
#        'AIRLOOP DATACENTER MID', 'AIRLOOP DATACENTER TOP'], dtype=object)

# %%
env.specs.variables[
    env.specs.variables['variable_key']
        .str
        .contains('CORE_MID')
]
# Out:
#                                           variable_name  \
# 17               Zone Total Internal Latent Gain Energy
# 18                 Zone Total Internal Latent Gain Rate
# 65                                People Occupant Count
# 66                               People Air Temperature
# 67                         People Air Relative Humidity
# 111                          Zone People Occupant Count
# 112                    Zone People Total Heating Energy
# 141                           Lights Electricity Energy
# 165                        Zone Lights Electricity Rate
# 166                      Zone Lights Electricity Energy
# 167                    Zone Lights Total Heating Energy
# 217               Electric Equipment Electricity Energy
# 239          Zone Electric Equipment Electricity Energy
# 240        Zone Electric Equipment Total Heating Energy
# 301   Zone Windows Total Transmitted Solar Radiation...
# 302   Zone Exterior Windows Total Transmitted Beam S...
# 303   Zone Interior Windows Total Transmitted Beam S...
# 304   Zone Exterior Windows Total Transmitted Diffus...
# 305   Zone Interior Windows Total Transmitted Diffus...
# 306   Zone Windows Total Transmitted Solar Radiation...
# 307   Zone Exterior Windows Total Transmitted Beam S...
# 308   Zone Interior Windows Total Transmitted Beam S...
# 309   Zone Exterior Windows Total Transmitted Diffus...
# 310   Zone Interior Windows Total Transmitted Diffus...
# 519                   Zone Windows Total Heat Gain Rate
# 520                   Zone Windows Total Heat Loss Rate
# 521                 Zone Windows Total Heat Gain Energy
# 522                 Zone Windows Total Heat Loss Energy
# 978                           Zone Mean Air Temperature
# 1039            Zone Air System Sensible Heating Energy
# 1040            Zone Air System Sensible Cooling Energy
# 1041              Zone Air System Sensible Heating Rate
# 1042              Zone Air System Sensible Cooling Rate
# 1126       Water Use Connections Plant Hot Water Energy
# 1194                 Zone Oscillating Temperatures Time
# 1219              Zone Thermal Comfort Fanger Model PMV
# 1220              Zone Thermal Comfort Fanger Model PPD
# 1253  Zone Thermal Comfort ASHRAE 55 Simple Model Su...
# 1254  Zone Thermal Comfort ASHRAE 55 Simple Model Wi...
# 1255  Zone Thermal Comfort ASHRAE 55 Simple Model Su...
# 1324                 Zone Heating Setpoint Not Met Time
# 1325  Zone Heating Setpoint Not Met While Occupied Time
# 1326                 Zone Cooling Setpoint Not Met Time
# 1327  Zone Cooling Setpoint Not Met While Occupied Time
# 1414                        Heating Coil Heating Energy
# 1415      Heating Coil Source Side Heat Transfer Energy
# 1416                          Heating Coil Heating Rate
# 1606                   Water Use Equipment Total Volume
# 1607             Water Use Equipment Mains Water Volume
# 1608                 Water Use Equipment Heating Energy
# 1938  Zone Mechanical Ventilation No Load Heat Remov...
# 1939  Zone Mechanical Ventilation Cooling Load Incre...
# 1940  Zone Mechanical Ventilation Cooling Load Incre...
# 1941  Zone Mechanical Ventilation Cooling Load Decre...
# 1942  Zone Mechanical Ventilation No Load Heat Addit...
# 1943  Zone Mechanical Ventilation Heating Load Incre...
# 1944  Zone Mechanical Ventilation Heating Load Incre...
# 1945  Zone Mechanical Ventilation Heating Load Decre...
# 1946   Zone Mechanical Ventilation Air Changes per Hour
#
#                       variable_key
# 17                        CORE_MID
# 18                        CORE_MID
# 65                        CORE_MID
# 66                        CORE_MID
# 67                        CORE_MID
# 111                       CORE_MID
# 112                       CORE_MID
# 141                CORE_MID_LIGHTS
# 165                       CORE_MID
# 166                       CORE_MID
# 167                       CORE_MID
# 217        CORE_MID_MISCPLUG_EQUIP
# 239                       CORE_MID
# 240                       CORE_MID
# 301                       CORE_MID
# 302                       CORE_MID
# 303                       CORE_MID
# 304                       CORE_MID
# 305                       CORE_MID
# 306                       CORE_MID
# 307                       CORE_MID
# 308                       CORE_MID
# 309                       CORE_MID
# 310                       CORE_MID
# 519                       CORE_MID
# 520                       CORE_MID
# 521                       CORE_MID
# 522                       CORE_MID
# 978                       CORE_MID
# 1039                      CORE_MID
# 1040                      CORE_MID
# 1041                      CORE_MID
# 1042                      CORE_MID
# 1126              CORE_MID SUB CAT
# 1194                      CORE_MID
# 1219                      CORE_MID
# 1220                      CORE_MID
# 1253                      CORE_MID
# 1254                      CORE_MID
# 1255                      CORE_MID
# 1324                      CORE_MID
# 1325                      CORE_MID
# 1326                      CORE_MID
# 1327                      CORE_MID
# 1414  CORE_MID VAV BOX REHEAT COIL
# 1415  CORE_MID VAV BOX REHEAT COIL
# 1416  CORE_MID VAV BOX REHEAT COIL
# 1606              CORE_MID SUB CAT
# 1607              CORE_MID SUB CAT
# 1608              CORE_MID SUB CAT
# 1938                      CORE_MID
# 1939                      CORE_MID
# 1940                      CORE_MID
# 1941                      CORE_MID
# 1942                      CORE_MID
# 1943                      CORE_MID
# 1944                      CORE_MID
# 1945                      CORE_MID
# 1946                      CORE_MID

# %% [markdown]
# #### Internal Variables

# %%
env.specs.internal_variables
# Out:
#                      variable_type            variable_key
# 0    Plant Design Volume Flow Rate                 SHWSYS1
# 1    Plant Design Volume Flow Rate                HEATSYS1
# 2    Plant Design Volume Flow Rate         COOLSYS1_SUPPLY
# 3    Plant Design Volume Flow Rate         COOLSYS1_DEMAND
# 4    Plant Design Volume Flow Rate           TOWERWATERSYS
# ..                             ...                     ...
# 743    Pump Maximum Mass Flow Rate            SHWSYS1 PUMP
# 744    Pump Maximum Mass Flow Rate  COOLSYS1 CHILLER1 PUMP
# 745    Pump Maximum Mass Flow Rate  COOLSYS1 CHILLER2 PUMP
# 746    Pump Maximum Mass Flow Rate         PLANT CIRC PUMP
# 747    Pump Maximum Mass Flow Rate      TOWERWATERSYS PUMP
#
# [748 rows x 2 columns]

# %% [markdown]
# #### Meters

# %%
env.specs.meters
# Out:
#                                       meter_name
# 0                           Electricity:Facility
# 1                           Electricity:Building
# 2                      Electricity:Zone:BASEMENT
# 3                  Electricity:SpaceType:GENERAL
# 4                     InteriorLights:Electricity
# ..                                           ...
# 314                    General:Pumps:Electricity
# 315                   Carbon Equivalent:Facility
# 316  CarbonEquivalentEmissions:Carbon Equivalent
# 317                        WIRED_LTG_ELECTRICITY
# 318                              WIRED_INT_EQUIP
#
# [319 rows x 1 columns]

# %% [markdown]
# #### Actuators

# %%
env.specs.actuators
# Out:
#      component_type               control_type                 actuator_key
# 0      Weather Data           Outdoor Dry Bulb                  Environment
# 1      Weather Data          Outdoor Dew Point                  Environment
# 2      Weather Data  Outdoor Relative Humidity                  Environment
# 3      Weather Data              Diffuse Solar                  Environment
# 4      Weather Data               Direct Solar                  Environment
# ...             ...                        ...                          ...
# 5085    AirLoopHVAC        Availability Status          VAV_TOP WITH REHEAT
# 5086    AirLoopHVAC        Availability Status  AIRLOOP DATACENTER BASEMENT
# 5087    AirLoopHVAC        Availability Status       AIRLOOP DATACENTER BOT
# 5088    AirLoopHVAC        Availability Status       AIRLOOP DATACENTER MID
# 5089    AirLoopHVAC        Availability Status       AIRLOOP DATACENTER TOP
#
# [5090 rows x 3 columns]

# %% [markdown]
# - Component types of the actuators...

# %%
env.specs.actuators['component_type'].unique()
# Out:
# array(['Weather Data', 'Schedule:Compact', 'Schedule:Constant',
#        'Material', 'People', 'Lights', 'ElectricEquipment', 'Surface',
#        'Zone', 'Zone Infiltration', 'Plant Loop Overall',
#        'Supply Side Half Loop', 'Demand Side Half Loop',
#        'Demand Side Branch', 'Plant Component Pipe:Adiabatic',
#        'Plant Component WaterUse:Connections', 'Supply Side Branch',
#        'Plant Component Pump:ConstantSpeed',
#        'Plant Component WaterHeater:Mixed',
#        'Plant Component Coil:Heating:Water',
#        'Plant Component Pump:VariableSpeed',
#        'Plant Component Boiler:HotWater',
#        'Plant Component HeatExchanger:FluidToFluid',
#        'Plant Component Chiller:Electric:ASHRAE205',
#        'Plant Component Coil:Cooling:Water',
#        'Plant Component Coil:Cooling:WaterToAirHeatPump:EquationFit',
#        'Plant Component Coil:Heating:WaterToAirHeatPump:EquationFit',
#        'Plant Component FluidCooler:TwoSpeed',
#        'Plant Component HeaderedPumps:VariableSpeed',
#        'Plant Component CoolingTower:VariableSpeed', 'Sizing:Zone',
#        'Zone Temperature Control', 'Zone Humidity Control',
#        'AirTerminal:SingleDuct:ConstantVolume:NoReheat', 'Fan',
#        'Sizing:System', 'ExteriorLights', 'Outdoor Air Controller',
#        'AirLoopHVAC:UnitaryHeatPump:WaterToAir', 'Unitary HVAC', 'Pump',
#        'Curve', 'System Node Setpoint', 'Outdoor Air System Node',
#        'AirLoopHVAC'], dtype=object)

# %%
env.specs.actuators[
    env.specs.actuators['component_type'] 
        == 'Plant Component Chiller:Electric:ASHRAE205'
]
# Out:
#                                   component_type        control_type  \
# 1424  Plant Component Chiller:Electric:ASHRAE205  On/Off Supervisory
# 1427  Plant Component Chiller:Electric:ASHRAE205  On/Off Supervisory
#
#            actuator_key
# 1424  COOLSYS1 CHILLER1
# 1427  COOLSYS1 CHILLER2

# %%
env.specs.actuators[
    env.specs.actuators['component_type'] 
        == 'Plant Component CoolingTower:VariableSpeed'
]
# Out:
#                                   component_type        control_type  \
# 1504  Plant Component CoolingTower:VariableSpeed  On/Off Supervisory
# 1506  Plant Component CoolingTower:VariableSpeed  On/Off Supervisory
#
#                    actuator_key
# 1504  TOWERWATERSYS COOLTOWER 1
# 1506  TOWERWATERSYS COOLTOWER 2

# %%
env.specs.actuators[
    env.specs.actuators['component_type'].isin(
        ('Zone Temperature Control', 'Zone Humidity Control')
    )
]
# Out:
#                 component_type                              control_type  \
# 1631  Zone Temperature Control                          Heating Setpoint
# 1632  Zone Temperature Control                          Cooling Setpoint
# 1633  Zone Temperature Control                          Heating Setpoint
# 1634  Zone Temperature Control                          Cooling Setpoint
# 1635  Zone Temperature Control                          Heating Setpoint
# 1636  Zone Temperature Control                          Cooling Setpoint
# 1637  Zone Temperature Control                          Heating Setpoint
# 1638  Zone Temperature Control                          Cooling Setpoint
# 1639  Zone Temperature Control                          Heating Setpoint
# 1640  Zone Temperature Control                          Cooling Setpoint
# 1641  Zone Temperature Control                          Heating Setpoint
# 1642  Zone Temperature Control                          Cooling Setpoint
# 1643  Zone Temperature Control                          Heating Setpoint
# 1644  Zone Temperature Control                          Cooling Setpoint
# 1645  Zone Temperature Control                          Heating Setpoint
# 1646  Zone Temperature Control                          Cooling Setpoint
# 1647  Zone Temperature Control                          Heating Setpoint
# 1648  Zone Temperature Control                          Cooling Setpoint
# 1649  Zone Temperature Control                          Heating Setpoint
# 1650  Zone Temperature Control                          Cooling Setpoint
# 1651  Zone Temperature Control                          Heating Setpoint
# 1652  Zone Temperature Control                          Cooling Setpoint
# 1653  Zone Temperature Control                          Heating Setpoint
# 1654  Zone Temperature Control                          Cooling Setpoint
# 1655  Zone Temperature Control                          Heating Setpoint
# 1656  Zone Temperature Control                          Cooling Setpoint
# 1657  Zone Temperature Control                          Heating Setpoint
# 1658  Zone Temperature Control                          Cooling Setpoint
# 1659  Zone Temperature Control                          Heating Setpoint
# 1660  Zone Temperature Control                          Cooling Setpoint
# 1661  Zone Temperature Control                          Heating Setpoint
# 1662  Zone Temperature Control                          Cooling Setpoint
# 1663  Zone Temperature Control                          Heating Setpoint
# 1664  Zone Temperature Control                          Cooling Setpoint
# 1665  Zone Temperature Control                          Heating Setpoint
# 1666  Zone Temperature Control                          Cooling Setpoint
# 1667  Zone Temperature Control                          Heating Setpoint
# 1668  Zone Temperature Control                          Cooling Setpoint
# 1669  Zone Temperature Control                          Heating Setpoint
# 1670  Zone Temperature Control                          Cooling Setpoint
# 1671     Zone Humidity Control    Relative Humidity Humidifying Setpoint
# 1672     Zone Humidity Control  Relative Humidity Dehumidifying Setpoint
#
#                   actuator_key
# 1631                  BASEMENT
# 1632                  BASEMENT
# 1633               CORE_BOTTOM
# 1634               CORE_BOTTOM
# 1635                  CORE_MID
# 1636                  CORE_MID
# 1637                  CORE_TOP
# 1638                  CORE_TOP
# 1639        PERIMETER_BOT_ZN_3
# 1640        PERIMETER_BOT_ZN_3
# 1641        PERIMETER_BOT_ZN_2
# 1642        PERIMETER_BOT_ZN_2
# 1643        PERIMETER_BOT_ZN_1
# 1644        PERIMETER_BOT_ZN_1
# 1645        PERIMETER_BOT_ZN_4
# 1646        PERIMETER_BOT_ZN_4
# 1647        PERIMETER_MID_ZN_3
# 1648        PERIMETER_MID_ZN_3
# 1649        PERIMETER_MID_ZN_2
# 1650        PERIMETER_MID_ZN_2
# 1651        PERIMETER_MID_ZN_1
# 1652        PERIMETER_MID_ZN_1
# 1653        PERIMETER_MID_ZN_4
# 1654        PERIMETER_MID_ZN_4
# 1655        PERIMETER_TOP_ZN_3
# 1656        PERIMETER_TOP_ZN_3
# 1657        PERIMETER_TOP_ZN_2
# 1658        PERIMETER_TOP_ZN_2
# 1659        PERIMETER_TOP_ZN_1
# 1660        PERIMETER_TOP_ZN_1
# 1661        PERIMETER_TOP_ZN_4
# 1662        PERIMETER_TOP_ZN_4
# 1663  DATACENTER_BASEMENT_ZN_6
# 1664  DATACENTER_BASEMENT_ZN_6
# 1665       DATACENTER_BOT_ZN_6
# 1666       DATACENTER_BOT_ZN_6
# 1667       DATACENTER_MID_ZN_6
# 1668       DATACENTER_MID_ZN_6
# 1669       DATACENTER_TOP_ZN_6
# 1670       DATACENTER_TOP_ZN_6
# 1671  DATACENTER_BASEMENT_ZN_6
# 1672  DATACENTER_BASEMENT_ZN_6

# %% [markdown]
# #### Events

# %%
env.specs.events
# Out:
#                                         event_name
# 0                            after_component_input
# 1            after_new_environment_warmup_complete
# 2              after_predictor_after_hvac_managers
# 3             after_predictor_before_hvac_managers
# 4                            begin_new_environment
# 5           begin_system_timestep_before_predictor
# 6      begin_zone_timestep_after_init_heat_balance
# 7     begin_zone_timestep_before_init_heat_balance
# 8   begin_zone_timestep_before_set_current_weather
# 9                                end_system_sizing
# 10        end_system_timestep_after_hvac_reporting
# 11       end_system_timestep_before_hvac_reporting
# 12                                 end_zone_sizing
# 13          end_zone_timestep_after_zone_reporting
# 14         end_zone_timestep_before_zone_reporting
# 15                    inside_system_iteration_loop
# 16                  register_external_hvac_manager
# 17                           unitary_system_sizing
# 18                                         message
# 19                                        progress

# %% [markdown]
# ### Simulation

# %%
env = env.__enter__()

# %%
_ = env(
    # TODO
    '--design-day',
    #'--annual',
    '--output-directory', 'build/demo-eplus',
    '--weather', f'{epds.weathers}/USA_FL_Tampa.Intl.AP.722110_TMY3.epw',
    f'{epds.models}/ASHRAE901_OfficeLarge_STD2019_Denver_Chiller205_Detailed.idf'
)

# %%
env.__exit__()
