# %% [markdown]
# # 📚 Case Study 101a: Reinforcement Learning Based Control, Mono-Agent
#
# Before you start:
# - Make sure you have completed [](TUT000_setup.ipynb) through [](TUT003_variables.ipynb).
#
# What you will learn in this chapter:
# - TODO

# %%
import numpy as _numpy_

from controllables.core.tools.gymnasium import BoxSpace, DictSpace
from controllables.core.tools.rllib import Env
from controllables.energyplus import Actuator, OutputVariable
from controllables.energyplus import examples


class UserEnv(Env):
    action_space = DictSpace({
        'thermostat': BoxSpace(
            low=15., high=20.,
            dtype=_numpy_.float32,
            shape=(),
        ).bind(
            Actuator.Ref(
                type='Zone Temperature Control',
                control_type='Heating Setpoint',
                key='MAIN ZONE',
            )            
        )
    })

    observation_space = DictSpace({
        'temperature': BoxSpace(
            low=-_numpy_.inf, high=+_numpy_.inf,
            dtype=_numpy_.float32,
            shape=(),
        ).bind(
            lambda x: x[OutputVariable.Ref(
                type='Zone Mean Air Temperature',
                key='MAIN ZONE',
            )].cast(_numpy_.array)
        ),
    })

    reward = lambda agent: -abs(
        agent.observation['temperature'].value - agent.action['thermostat'].value
    )
    r"""
    Reward function.

    This reward function aims to minimize the control error, 
    i.e., the difference between the thermostat setpoint and the actual temperature.
    """

    def __init__(self, config: dict = dict()):
        super().__init__({
            'action_space': self.__class__.action_space,
            'observation_space': self.__class__.observation_space,
            'reward': self.__class__.reward,
            **config,
        })

    def run(self):
        # create a system
        system = examples.systems.X1ZoneEvapCooler(repeat=True)
        # enable progress reporting
        system.add('logging:progress')
        # attach this environment to the system
        system.add(self)
        # run the system in background
        system.start()

        # continuously...
        while True:
            # start a new episode
            episode_id = self.start_episode()
            # loop: here, it runs 100 steps of the episode
            for _ in range(100):
                with system.events['timestep'].wait(deferred=True):
                    self.step_episode(episode_id)
            # end the started episode after the above steps
            self.end_episode(episode_id)

# %% [markdown]
# ### Training

# %%
from ray.rllib.algorithms.ppo import PPO, PPOConfig

algo = PPO(
    PPOConfig()
    .environment(UserEnv)
    .env_runners(
        # NOTE this env (an `ExternalEnv`) does not support connectors
        enable_connectors=False,
    )
    # TODO
    .resources(num_gpus=1.)
)
# Out:
# /home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:568: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2025-01-27 19:12:03,703	INFO worker.py:1816 -- Started a local Ray instance.
#   0%|          | 0/100.0 [00:00<?, ?it/s]
#   0%|          | 0/100.0 [00:00<?, ?it/s, Initializing HVAC]
#   0%|          | 0.0/100.0 [00:00<?, ?it/s, Starting Simulation at 12/21 for DENVER CENTENNIAL ANN HTG 99.6% CONDNS DB]/home/AD/user/lab/controllables-core/packages/controllables/energyplus/variables.py:396: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='MAIN ZONE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=958449)   _warnings_.warn(
# 2025-01-27 19:12:08,160	WARNING util.py:61 -- Install gputil for GPU system monitoring.

# %%
for i in range(2):
    print(i, algo.train())
# Out:
#   1%|          | 1.0/100.0 [00:01<01:45,  1.06s/it, Starting Simulation at 07/21 for DENVER CENTENNIAL ANN CLG 1% CONDNS DB=>MWB]
#   1%|          | 1.0/100.0 [00:01<01:45,  1.06s/it, Starting Simulation at 01/01/2013 for RUN PERIOD 1]
#   2%|▏         | 2.0/100.0 [00:02<01:23,  1.17it/s, Starting Simulation at 01/01/2013 for RUN PERIOD 1]
#   1%|          | 1.0/100.0 [00:01<01:45,  1.06s/it, Starting Simulation at 07/21 for DENVER CENTENNIAL ANN CLG 1% CONDNS DB=>MWB]
#   1%|          | 1.0/100.0 [00:01<01:45,  1.06s/it, Starting Simulation at 01/01/2013 for RUN PERIOD 1]
#   5%|▌         | 5.0/100.0 [00:08<03:35,  2.27s/it, Starting Simulation at 01/01/2013 for RUN PERIOD 1] [repeated 6x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
#   6%|▌         | 6.0/100.0 [00:09<02:42,  1.73s/it, Updating Shadowing Calculations, Start Date=01/21/2013]
#   7%|▋         | 7.000000000000001/100.0 [00:09<02:04,  1.34s/it, Continuing Simulation at 01/21/2013 for RUN PERIOD 1]
#   8%|▊         | 8.0/100.0 [00:10<01:43,  1.13s/it, Continuing Simulation at 01/21/2013 for RUN PERIOD 1]
# (RolloutWorker pid=958449) Exception in thread Thread-1:
# (RolloutWorker pid=958449) Traceback (most recent call last):
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/events.py", line 129, in cb_
# (RolloutWorker pid=958449)     return cb(*args, **kwargs)
# (RolloutWorker pid=958449)            ^^^^^^^^^^^^^^^^^^^
#   8%|▊         | 8.0/100.0 [05:10<01:43,  1.13s/it, Writing tabular output file results using tab format.]  File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/events.py", line 159, in _state
# (RolloutWorker pid=958449)     self._event.__call__(
#   8%|▊         | 8.0/100.0 [05:10<01:43,  1.13s/it, Writing tabular output file results using HTML format.]  File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/events.py", line 98, in __call__
# (RolloutWorker pid=958449)     return super().__call__(context)
# (RolloutWorker pid=958449)            ^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callbacks.py", line 496, in __call__
# (RolloutWorker pid=958449)     return self._callables.__call__(*args, **kwargs)
# (RolloutWorker pid=958449)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callables.py", line 89, in __call__
# (RolloutWorker pid=958449)     res[f] = f(*args, **kwargs)
# (RolloutWorker pid=958449)              ^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callbacks.py", line 158, in __call__
# (RolloutWorker pid=958449)     res = ctx.ack.get()
# (RolloutWorker pid=958449)           ^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callables.py", line 222, in get
# (RolloutWorker pid=958449)     raise self.__exc__
# (RolloutWorker pid=958449)   File "/usr/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
# (RolloutWorker pid=958449)     self.run()
# (RolloutWorker pid=958449)   File "/tmp/ipykernel_958141/2175495296.py", line 72, in run
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/core/tools/rllib/env.py", line 319, in step_episode
# (RolloutWorker pid=958449)     self.agent.action.value = self.get_action(episode_id)
# (RolloutWorker pid=958449)                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/core/tools/rllib/env.py", line 271, in get_action
# (RolloutWorker pid=958449)     return super().get_action(
# (RolloutWorker pid=958449)            ^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 139, in get_action
# (RolloutWorker pid=958449)     return episode.wait_for_action(observation)
# (RolloutWorker pid=958449)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 297, in wait_for_action
# (RolloutWorker pid=958449)     return self.action_queue.get(True, timeout=300.0)
# (RolloutWorker pid=958449)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/usr/lib/python3.11/queue.py", line 179, in get
# (RolloutWorker pid=958449)     raise Empty
# (RolloutWorker pid=958449) _queue.Empty
# 100%|██████████| 100.0/100.0 [05:10<00:00,  3.21s/it, EnergyPlus Run Time=00hr 05min 10.20sec]Exception in thread Thread-4:
# (RolloutWorker pid=958449) Traceback (most recent call last):
# (RolloutWorker pid=958449)   File "/usr/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
# (RolloutWorker pid=958449)     self.run()
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/systems.py", line 110, in run
# (RolloutWorker pid=958449)     status = self._kernel.run(args=self._cli_args)
# (RolloutWorker pid=958449)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/_kernel/__init__.py", line 107, in run
# (RolloutWorker pid=958449)     self.hooks.__call__('run:post')
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callbacks.py", line 560, in __call__
# (RolloutWorker pid=958449)     return self[ref].__call__(*args, **kwargs)
# (RolloutWorker pid=958449)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callbacks.py", line 496, in __call__
# (RolloutWorker pid=958449)     return self._callables.__call__(*args, **kwargs)
# (RolloutWorker pid=958449)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callables.py", line 89, in __call__
# (RolloutWorker pid=958449)     res[f] = f(*args, **kwargs)
# (RolloutWorker pid=958449)              ^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/events.py", line 134, in _raise_exc
# (RolloutWorker pid=958449)     raise __exc__
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/events.py", line 129, in cb_
# (RolloutWorker pid=958449)     return cb(*args, **kwargs)
# (RolloutWorker pid=958449)            ^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/events.py", line 159, in _state
# (RolloutWorker pid=958449)     self._event.__call__(
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/events.py", line 98, in __call__
# (RolloutWorker pid=958449)     return super().__call__(context)
# (RolloutWorker pid=958449)            ^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callbacks.py", line 496, in __call__
# (RolloutWorker pid=958449)     return self._callables.__call__(*args, **kwargs)
# (RolloutWorker pid=958449)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callables.py", line 89, in __call__
# (RolloutWorker pid=958449)     res[f] = f(*args, **kwargs)
# (RolloutWorker pid=958449)              ^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callbacks.py", line 158, in __call__
# (RolloutWorker pid=958449)     res = ctx.ack.get()
# (RolloutWorker pid=958449)           ^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callables.py", line 222, in get
# (RolloutWorker pid=958449)     raise self.__exc__
# (RolloutWorker pid=958449)   File "/usr/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
# (RolloutWorker pid=958449)     self.run()
# (RolloutWorker pid=958449)   File "/tmp/ipykernel_958141/2175495296.py", line 72, in run
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/core/tools/rllib/env.py", line 319, in step_episode
# (RolloutWorker pid=958449)     self.agent.action.value = self.get_action(episode_id)
# (RolloutWorker pid=958449)                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/packages/controllables/core/tools/rllib/env.py", line 271, in get_action
# (RolloutWorker pid=958449)     return super().get_action(
# (RolloutWorker pid=958449)            ^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 139, in get_action
# (RolloutWorker pid=958449)     return episode.wait_for_action(observation)
# (RolloutWorker pid=958449)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 297, in wait_for_action
# (RolloutWorker pid=958449)     return self.action_queue.get(True, timeout=300.0)
# (RolloutWorker pid=958449)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=958449)   File "/usr/lib/python3.11/queue.py", line 179, in get
# (RolloutWorker pid=958449)     raise Empty
# (RolloutWorker pid=958449) _queue.Empty
#   8%|▊         | 8.0/100.0 [05:10<01:43,  1.12s/it, Writing tabular output file results using tab format.]_queue.Empty
# 100%|██████████| 100.0/100.0 [05:10<00:00,  3.21s/it, EnergyPlus Run Time=00hr 05min 10.18sec]Exception in thread Thread-4:
# 2025-01-27 19:12:10,597	WARNING deprecation.py:50 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!
# 0 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'custom_metrics': {}, 'learner_stats': {'cur_kl_coeff': np.float64(0.20000000000000004), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.664679316038727), 'policy_loss': np.float64(0.006058646494182207), 'vf_loss': np.float64(9.658453166100287), 'vf_explained_var': np.float64(-7.562739874726983e-09), 'kl': np.float64(0.0008376219968927363), 'entropy': np.float64(1.4068728159832697), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'num_grad_updates_lifetime': np.float64(465.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(464.5)}}, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000}, 'env_runners': {'episode_reward_max': np.float64(-89.9541574477447), 'episode_reward_min': np.float64(-727.7377725308874), 'episode_reward_mean': np.float64(-163.27378682404384), 'episode_len_mean': np.float64(100.0), 'episode_media': {}, 'episodes_timesteps_total': 4000, 'policy_reward_min': {'default_policy': np.float64(-727.7377725308874)}, 'policy_reward_max': {'default_policy': np.float64(-89.9541574477447)}, 'policy_reward_mean': {'default_policy': np.float64(-163.27378682404384)}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [np.float64(-104.74988382365993), np.float64(-316.39872932745936), np.float64(-675.8625479731919), np.float64(-142.4170683681633), np.float64(-113.96803217644573), np.float64(-116.73482917354414), np.float64(-128.2067602001388), np.float64(-98.66098501659054), np.float64(-113.27423209444254), np.float64(-112.44829687363703), np.float64(-100.58870548771567), np.float64(-113.23917399618578), np.float64(-93.89281539108576), np.float64(-113.4149044927463), np.float64(-142.0227990856858), np.float64(-174.36284543308793), np.float64(-153.31265523028603), np.float64(-130.42636272048833), np.float64(-133.22769212154577), np.float64(-138.66427406097964), np.float64(-119.38214912318833), np.float64(-355.6063550603072), np.float64(-727.7377725308874), np.float64(-141.49765632869438), np.float64(-114.52515388020046), np.float64(-124.59459876387668), np.float64(-137.2461535914596), np.float64(-107.8627583030814), np.float64(-99.14112072600028), np.float64(-121.96990603009837), np.float64(-115.73364294585382), np.float64(-108.06951915630542), np.float64(-89.9541574477447), np.float64(-109.39147162851975), np.float64(-145.43047756105057), np.float64(-183.69076570526857), np.float64(-148.27070232925735), np.float64(-111.1398412937615), np.float64(-134.05783893189917), np.float64(-119.77583857721882)], 'episode_lengths': [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100], 'policy_default_policy_reward': [np.float64(-104.74988382365993), np.float64(-316.39872932745936), np.float64(-675.8625479731919), np.float64(-142.4170683681633), np.float64(-113.96803217644573), np.float64(-116.73482917354414), np.float64(-128.2067602001388), np.float64(-98.66098501659054), np.float64(-113.27423209444254), np.float64(-112.44829687363703), np.float64(-100.58870548771567), np.float64(-113.23917399618578), np.float64(-93.89281539108576), np.float64(-113.4149044927463), np.float64(-142.0227990856858), np.float64(-174.36284543308793), np.float64(-153.31265523028603), np.float64(-130.42636272048833), np.float64(-133.22769212154577), np.float64(-138.66427406097964), np.float64(-119.38214912318833), np.float64(-355.6063550603072), np.float64(-727.7377725308874), np.float64(-141.49765632869438), np.float64(-114.52515388020046), np.float64(-124.59459876387668), np.float64(-137.2461535914596), np.float64(-107.8627583030814), np.float64(-99.14112072600028), np.float64(-121.96990603009837), np.float64(-115.73364294585382), np.float64(-108.06951915630542), np.float64(-89.9541574477447), np.float64(-109.39147162851975 ...
# 1 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'custom_metrics': {}, 'learner_stats': {'cur_kl_coeff': np.float64(0.10000000000000002), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.716299249792613), 'policy_loss': np.float64(0.005346524206701145), 'vf_loss': np.float64(9.71018300210276), 'vf_explained_var': np.float64(-3.287869115029612e-08), 'kl': np.float64(0.007697197340010423), 'entropy': np.float64(1.3876704110894151), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'num_grad_updates_lifetime': np.float64(1395.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(464.5)}}, 'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000}, 'env_runners': {'episode_reward_max': np.float64(-89.9541574477447), 'episode_reward_min': np.float64(-727.7377725308874), 'episode_reward_mean': np.float64(-159.20356627407023), 'episode_len_mean': np.float64(100.0), 'episode_media': {}, 'episodes_timesteps_total': 8000, 'policy_reward_min': {'default_policy': np.float64(-727.7377725308874)}, 'policy_reward_max': {'default_policy': np.float64(-89.9541574477447)}, 'policy_reward_mean': {'default_policy': np.float64(-159.20356627407023)}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [np.float64(-104.74988382365993), np.float64(-316.39872932745936), np.float64(-675.8625479731919), np.float64(-142.4170683681633), np.float64(-113.96803217644573), np.float64(-116.73482917354414), np.float64(-128.2067602001388), np.float64(-98.66098501659054), np.float64(-113.27423209444254), np.float64(-112.44829687363703), np.float64(-100.58870548771567), np.float64(-113.23917399618578), np.float64(-93.89281539108576), np.float64(-113.4149044927463), np.float64(-142.0227990856858), np.float64(-174.36284543308793), np.float64(-153.31265523028603), np.float64(-130.42636272048833), np.float64(-133.22769212154577), np.float64(-138.66427406097964), np.float64(-119.38214912318833), np.float64(-355.6063550603072), np.float64(-727.7377725308874), np.float64(-141.49765632869438), np.float64(-114.52515388020046), np.float64(-124.59459876387668), np.float64(-137.2461535914596), np.float64(-107.8627583030814), np.float64(-99.14112072600028), np.float64(-121.96990603009837), np.float64(-115.73364294585382), np.float64(-108.06951915630542), np.float64(-89.9541574477447), np.float64(-109.39147162851975), np.float64(-145.43047756105057), np.float64(-183.69076570526857), np.float64(-148.27070232925735), np.float64(-111.1398412937615), np.float64(-134.05783893189917), np.float64(-119.77583857721882), np.float64(-115.89873960327401), np.float64(-115.47541483154586), np.float64(-127.61702073167044), np.float64(-117.38326661192893), np.float64(-101.7837547275063), np.float64(-109.37209623628922), np.float64(-146.79447069361223), np.float64(-127.82463126387057), np.float64(-167.65084385756452), np.float64(-194.88975345087442), np.float64(-202.04056243255064), np.float64(-238.82216649813859), np.float64(-196.15052097679944), np.float64(-137.38138454861348), np.float64(-122.53709374850905), np.float64(-201.06720878002736), np.float64(-198.088454878051), np.float64(-161.64959628401175), np.float64(-188.34618740196336), np.float64(-152.92437125909885), np.float64(-116.94727585232751), np.float64(-118.58233293760055), np.float64(-143.16711112512937), np.float64(-114.66714892286208), np.float64(-102.10127333938216), np.float64(-115.24661242034719), np.float64(-149.41600649113064), np.float64(-134.8426720945707), np.float64(-155.23393892913847), np.float64(-193.27380938441632), np.float64(-174.00873251605935), np.float64(-210.23448338035382), np.float64(-185.30764407950716), np.float64(-144.3296358750009), np.float64(-136.66777164977185), np.float64(-207.1274707686207), np.float64(-200.02397289644077), np.float64(-164.96196703448172), np.float64(-157.77684916643636), np.float64(-157.71958128438848)], 'episode_lengths': [100, 100, 100, 100, 100, 1 ...

# %% [markdown]
# ### Evaluation
#
# TODO

# %%
from ray.rllib.algorithms.callbacks import DefaultCallbacks
from controllables.core.tools.records import VariableRecords


class PlottingCallbacks(DefaultCallbacks):
    def __init__(self):
        self.env_records = None

    def on_episode_start(self, *, episode, worker, **kwargs):
        env = worker.env
        system = env.system
        if self.env_records is None:
            self.env_records = records = VariableRecords({
                '🕰️': system['time'],
                '🍩': env.agent.reward,
            })
            display(
                records.plot.scatter(x='🕰️', y='🍩')
                .watch(records.events['change'] % 1_000)
            )

    def on_episode_step(self, *, episode, **kwargs):
        self.env_records.poll()


# create a new algorithm instance specifically for evaluation
algo_eval = PPO(
    PPOConfig()
    .environment(UserEnv)
    .env_runners(
        # NOTE this env (an `ExternalEnv`) does not support connectors
        enable_connectors=False,
        # disable distributed workers for local plotting
        num_rollout_workers=0,
        create_env_on_local_worker=True,
    )
    .evaluation(
        evaluation_num_workers=0,
    )
    .callbacks(PlottingCallbacks)
)

# restore weights from the trained algorithm
algo_eval.restore(algo.save())
# Out:
# 2025-01-27 19:12:21,386	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.env_runners(num_rollout_workers)` has been deprecated. Use `AlgorithmConfig.env_runners(num_env_runners)` instead. This will raise an error in the future!
# 2025-01-27 19:12:21,386	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.evaluation(evaluation_num_workers=..)` has been deprecated. Use `AlgorithmConfig.evaluation(evaluation_num_env_runners=..)` instead. This will raise an error in the future!
# /home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:568: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2025-01-27 19:12:21,404	WARNING util.py:61 -- Install gputil for GPU system monitoring.
#   0%|          | 0/100.0 [00:00<?, ?it/s]
# 2025-01-27 19:12:21,447	INFO trainable.py:583 -- Restored on 192.168.200.249 from checkpoint: Checkpoint(filesystem=local, path=/tmp/tmp6zlpniiv)

# %%
algo_eval.evaluate()
# Out:
# /home/AD/user/lab/controllables-core/packages/controllables/energyplus/variables.py:396: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='MAIN ZONE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# {'env_runners': {'episode_reward_max': np.float64(-82.57539414317334),
#   'episode_reward_min': np.float64(-779.032968362217),
#   'episode_reward_mean': np.float64(-353.2756049011565),
#   'episode_len_mean': np.float64(100.0),
#   'episode_media': {},
#   'episodes_timesteps_total': 40000,
#   'policy_reward_min': {'default_policy': np.float64(-779.032968362217)},
#   'policy_reward_max': {'default_policy': np.float64(-82.57539414317334)},
#   'policy_reward_mean': {'default_policy': np.float64(-353.2756049011565)},
#   'custom_metrics': {},
#   'hist_stats': {'episode_reward': [np.float64(-112.65701623075596),
#     np.float64(-338.2226661743705),
#     np.float64(-670.5977928076817),
#     np.float64(-93.05482061781025),
#     np.float64(-127.74099769615474),
#     np.float64(-129.0199111437539),
#     np.float64(-114.85539684549133),
#     np.float64(-87.15856127477514),
#     np.float64(-95.28611124042529),
#     np.float64(-87.78153670530116),
#     np.float64(-111.31042529845604),
#     np.float64(-113.5706569180681),
#     np.float64(-89.14495907731302),
#     np.float64(-119.72838649061417),
#     np.float64(-132.69389702387565),
#     np.float64(-164.32027124365186),
#     np.float64(-160.5200347884187),
#     np.float64(-121.89587649300096),
#     np.float64(-120.06747105115595),
#     np.float64(-104.36804126323949),
#     np.float64(-113.49347437891434),
#     np.float64(-98.17204384459515),
#     np.float64(-126.14042403807423),
#     np.float64(-108.3021503933399),
#     np.float64(-117.02000808716014),
#     np.float64(-118.08704433240159),
#     np.float64(-141.17036770152237),
#     np.float64(-111.52672625255511),
#     np.float64(-146.986444142738),
#     np.float64(-199.9808753066168),
#     np.float64(-135.91516756689853),
#     np.float64(-214.63765501999202),
#     np.float64(-157.05186359309363),
#     np.float64(-135.84762686930523),
#     np.float64(-125.00982966266878),
#     np.float64(-201.19288776006255),
#     np.float64(-181.82836000613918),
#     np.float64(-166.62672558143944),
#     np.float64(-183.28362396647637),
#     np.float64(-154.24697150684818),
#     np.float64(-125.57225700481084),
#     np.float64(-141.58397755080495),
#     np.float64(-132.5327710594682),
#     np.float64(-113.21108537550032),
#     np.float64(-129.1497543555165),
#     np.float64(-116.15991849584913),
#     np.float64(-108.58172207553422),
#     np.float64(-103.04582912269191),
#     np.float64(-109.67542949643803),
#     np.float64(-102.67287844744911),
#     np.float64(-105.63419657468512),
#     np.float64(-123.99375587008515),
#     np.float64(-82.57539414317334),
#     np.float64(-101.38864542014346),
#     np.float64(-89.31336685760361),
#     np.float64(-102.04931952420577),
#     np.float64(-102.08645679301401),
#     np.float64(-103.2594875333809),
#     np.float64(-111.09302610635838),
#     np.float64(-120.42790582237333),
#     np.float64(-117.71512111879824),
#     np.float64(-146.5169632194968),
#     np.float64(-120.48175604667665),
#     np.float64(-102.18945328830841),
#     np.float64(-87.10025009970488),
#     np.float64(-107.25015025812117),
#     np.float64(-122.3476537907635),
#     np.float64(-120.81014097370738),
#     np.float64(-106.63139603835498),
#     np.float64(-104.93753146691638),
#     np.float64(-111.56280821378957),
#     np.float64(-187.6491337665973),
#     np.float64(-198.1039454216369),
#     np.float64(-188.13096598754225),
#     np.float64(-136.18752486292598),
#     np.float64(-138.65642035054896),
#     np.float64(-112.43476576092654),
#     np.float64(-140.96222391544714),
#     np.float64(-133.89988909251355),
#     np.float64(-128.55230353137745),
#     np.float64(-157.1029521711684),
#     np.float64(-163.48239983326243),
#     np.float64(-164.41298856912488),
#     np.float64(-147.00026642356124),
#     np.float64(-180.65640842942747),
#     np.float64(-193.3083066973411),
#     np.float64(-141.69928885869058),
#     np.float64(-147.79822642310262),
#     np.float64(-118.26602202292496),
#     np.float64(-108.4471084148806),
#     np.float64(-156.02386268322522),
#     np.float64(-150.67353163483708),
#     np.float64(-110.14379892541716),
#     np.float64(-105.83902136979555),
#     np.float64(-125.40703980964612),
#     np.float64(-148.27078290457786),
#     np.float64(-117.70767917604506),
#     np.float64(-200.95706645213124),
#     np.float64(-189.11512348144566),
#     np.float64(-180.02902702329135),
#     np.float64(-182.5168647939965),
#     np.float64(-223.74389977988886),
#     np.float64(-177.5232725623174),
#     np.float64(-259.41540457435144),
#     np.float64(-269.97927571474173),
#     np.float64(-241.9813200109717),
#     np.float64(-275.76676710952535),
#     np.float64(-417.9578185610844),
#     np.float64(-313.53504077117753),
#     np.float64(-270.92437576860226),
#     np.float64(-284.8747701265499),
#     np.float64(-156.62913294934387),
#     np.float64(-113.09190120217842),
#     np.float64(-98.75577087263514),
#     np.float64(-87.67698170868563),
#     np.float64(-100.80808620483816),
#     np.float64(-113.55796910398529),
#     np.float64(-134.3074338759711),
#     np.float64(-131.9134622664944),
#     np.float64(-121.14861715990241),
#     np.float64(-156.34812928365457),
#     np.float64(-113.98281116450775),
#     np.float64(-129.38673043882704),
#     np.float64(-148.84697401138473),
#     np.float64(-216.4309644054457),
#     np.float64(-141.80118197598486),
#     np.float64(-93.25597104720364),
#     np.float64(-129.42486139558704),
#     np.float64(-116.50395036811932),
#     np.float64(-113.83234046621895),
#     np.float64(-171.48122676976885),
#     np.float64(-204.65420102204476),
#     np.float64(-188.02854878717818),
#     np.float64(-92.65331577422782),
#     np.float64(-130.33773609194844),
#     np.float64(-93.66178134304775),
#     np.float64(-105.99239822685024),
#     np.float64(-119.19432254968292),
#     np.float64(-111.30205029317892),
#     np.float64(-146.51213837644715),
#     np.float64(-206.74877550331033),
#     np.float64(-227.1110273934137),
#     np.float64(-263.0599651219591),
#     np.float64(-194.54616579761722),
#     np.float64(-179.1754183435732),
#     np.float64(-109.8516642448997),
#     np.float64(-119.29639070172294),
#     np.float64(-185.97974446248847),
#     np.float64(-175.2910141685179),
#     np.float64(-257.5259964868688),
#     np.float64(-195.4187694343584),
#     np.float64(-158.27722433551287),
#     np.float64(-116.193214750557),
#     np.float64(-124.91884166304246),
#     np.float64(-110.21575913982679),
#     np.float64(-95.75932187791085),
#     np.float64(-175.77888691447998),
#     np.float64(-191.42623428760146),
#     np.float64(-188.53196998896556),
#     np.float64(-291.4833478045011),
#     np.float64(-346.1873332295942),
#     np.float64(-231.6462624630411),
#     np.float64(-232.72629053810886),
#     np.float64(-128.32129016656705),
#     np.float64(-121.71344638846887),
#     np.float64(-125.98450027496057),
#     np.float64(-137.95134282143647),
#     np.float64(-148.05009922374333),
#     np.float64(-151.72917516071612),
#     np.float64(-187.08590675880865),
#     np.float64(-258.159714209092),
#     np.float64(-203.57954952075372),
#     np.float64(-200.33709514222613),
#     np.float64(-150.08435103911702),
#     np.float64(-131.88047672434286),
#     np.float64(-121.9962391301853),
#     np.float64(-152.31520086008192),
#     np.float64(-127.16266091895184),
#     np.float64(-150.69646471867594),
#     np.float64(-216.0804381040241),
#     np.float64(-294.4409862972887),
#     np.float64(-284.99601845650733),
#     np.float64(-397.48551672960383),
#     np.float64(-379.5351225884448),
#     np.float64(-307.1545210075104),
#     np.float64(-365.964866281739),
#     np.float64(-253.83874764739693),
#     np.float64(-219.10466622852456),
#     np.float64(-339.026306074713),
#     np.float64(-454.8484843846207),
#     np.float64(-335.7059101508049),
#     np.float64(-154.25124565963162),
#     np.float64(-217.6556854680291),
#     np.float64(-296.6128899786792),
#     np.float64(-200.18053785780538),
#     np.float64(-256.49718171045015),
#     np.float64(-374.37237200957765),
#     np.float64(-318.0808707226058),
#     np.float64(-544.6136566769147),
#     np.float64(-534.1210061984655),
#     np.float64(-439.85368206093165),
#     np.float64(-380.8035434523578),
#     np.float64(-280.62270694680643),
#     np.float64(-291.57475176705213),
#     np.float64(-240.58247990504069),
#     np.float64(-362.56222349942215),
#     np.float64(-253.38861598378367),
#     np.float64(-184.89837105836276),
#     np.float64(-253.45881844143273),
#     np.float64(-347.4412184342367),
#     np.float64(-239.05265044690117),
#     np.float64(-256.3723021989495),
#     np.float64(-230.0003481949092),
#     np.float64(-215.3523356604298),
#     np.float64(-218.02814856905627),
#     np.float64(-329.8428490749315),
#     np.float64(-224.08485146327854),
#     np.float64(-204.90760890614868),
#     np.float64(-327.5945758735411),
#     np.float64(-446.5601555651939),
#     np.float64(-480.27853154635665),
#     np.float64(-656.1332031929378),
#     np.float64(-487.06483276262594),
#     np.float64(-412.08675758861176),
#     np.float64(-475.4738465452545),
#     np.float64(-651.411710313587),
#     np.float64(-543.6616511393506),
#     np.float64(-627.4320114698911),
#     np.float64(-716.356413753787),
#     np.float64(-585.2923377395807),
#     np.float64(-599.2046439744922),
#     np.float64(-620.3188923608878),
#     np.float64(-521.5675668487527),
#     np.float64(-432.9178320194184),
#     np.float64(-579.5263292438092),
#     np.float64(-681.8483620379943),
#     np.float64(-543.6559444043406),
#     np.float64(-648.7392847262003),
#     np.float64(-716.8912355532848),
#     np.float64(-574.4864293302736),
#     np.float64(-654.8403670708751),
#     np.float64(-693.813942217243),
#     np.float64(-601.5491882361384),
#     np.float64(-589.8124172783928),
#     np.float64(-625.1016409391868),
#     np.float64(-619.8680106330427),
#     np.float64(-529.6355859028314),
#     np.float64(-650.7752287981373),
#     np.float64(-651.6774125167507),
#     np.float64(-554.3275667365309),
#     np.float64(-584.3220999660251),
#     np.float64(-580.8319815562375),
#     np.float64(-524.6387114942016),
#     np.float64(-590.8670201304188),
#     np.float64(-750.7412049516593),
#     np.float64(-636.3048829952737),
#     np.float64(-602.5326275340614),
#     np.float64(-779.032968362217),
#     np.float64(-655.2949250095572),
#     np.float64(-546.9266447828456),
#     np.float64(-708.2286975459772),
#     np.float64(-682.2620994731428),
#     np.float64(-559.6044105396815),
#     np.float64(-677.1305277781389),
#     np.float64(-732.6740582806989),
#     np.float64(-531.4029114917782),
#     np.float64(-558.2721430822995),
#     np.float64(-576.0916088847979),
#     np.float64(-583.3795995858576),
#     np.float64(-480.777815000758),
#     np.float64(-583.6264201029074),
#     np.float64(-651.325843520375),
#     np.float64(-567.6820083971514),
#     np.float64(-688.1491818217719),
#     np.float64(-661.6838076360581),
#     np.float64(-511.75542441763787),
#     np.float64(-617.2481899749092),
#     np.float64(-708.9590075184027),
#     np.float64(-564.1269654039339),
#     np.float64(-516.5246402217551),
#     np.float64(-727.1902452894896),
#     np.float64(-635.699325527755),
#     np.float64(-544.0503801230745),
#     np.float64(-694.4970788323981),
#     np.float64(-722.6159351905236),
#     np.float64(-562.4299171569547),
#     np.float64(-733.8554613179166),
#     np.float64(-775.749429544694),
#     np.float64(-617.7476952504438),
#     np.float64(-638.6389807551009),
#     np.float64(-582.9919967942913),
#     np.float64(-562.4481465961657),
#     np.float64(-552.5169267432118),
#     np.float64(-750.7425354928733),
#     np.float64(-691.8016962692811),
#     np.float64(-553.6422181218713),
#     np.float64(-699.2774993010673),
#     np.float64(-730.2595178148101),
#     np.float64(-558.6752895954088),
#     np.float64(-588.6333617863872),
#     np.float64(-692.165345724754),
#     np.float64(-551.0112024179484),
#     np.float64(-520.7312112833514),
#     np.float64(-513.4518174362637),
#     np.float64(-481.72961998986705),
#     np.float64(-467.5996813214964),
#     np.float64(-595.7895058069305),
#     np.float64(-577.6373281683625),
#     np.float64(-535.4101621777658),
#     np.float64(-518.2530069879493),
#     np.float64(-660.6272285756312),
#     np.float64(-547.0326368787332),
#     np.float64(-626.356574520566),
#     np.float64(-645.1150703985335),
#     np.float64(-603.6161199026344),
#     np.float64(-562.5467675260293),
#     np.float64(-655.2724399575657),
#     np.float64(-631.0051528052811),
#     np.float64(-514.27023151788),
#     np.float64(-708.5710196472365),
#     np.float64(-651.6217919021116),
#     np.float64(-544.740417781971),
#     np.float64(-711.7063122032988),
#     np.float64(-712.0838044816339),
#     np.float64(-549.3572018045326),
#     np.float64(-471.1146909461209),
#     np.float64(-604.8381759122283),
#     np.float64(-604.618997722404),
#     np.float64(-533.9354269840812),
#     np.float64(-698.9688874687039),
#     np.float64(-706.4689972375091),
#     np.float64(-549.9428778123943),
#     np.float64(-662.5446781838269),
#     np.float64(-670.9938903356648),
#     np.float64(-563.3125331663459),
#     np.float64(-619.0609267554744),
#     np.float64(-703.9472335109758),
#     np.float64(-568.0905463161164),
#     np.float64(-496.09259936226124),
#     np.float64(-551.1173796949402),
#     np.float64(-489.77109388600246),
#     np.float64(-522.9187503271492),
#     np.float64(-692.0935341981105),
#     np.float64(-666.9434962286854),
#     np.float64(-588.5156831051567),
#     np.float64(-664.2696901192824),
#     np.float64(-542.6420814212444),
#     np.float64(-508.76029627087007),
#     np.float64(-527.6894597817411),
#     np.float64(-510.9855897773818),
#     np.float64(-507.2477093733652),
#     np.float64(-550.6368808330029),
#     np.float64(-714.8381352047174),
#     np.float64(-559.6055827717338),
#     np.float64(-465.68097349244454),
#     np.float64(-686.2878766715118),
#     np.float64(-573.5933289727842),
#     np.float64(-492.76481429060334),
#     np.float64(-613.9670262597517),
#     np.float64(-571.3720399282216),
#     np.float64(-537.8069340933445),
#     np.float64(-561.4182468067826),
#     np.float64(-618.5592908133419),
#     np.float64(-561.9917101822323),
#     np.float64(-564.3093431796951),
#     np.float64(-658.1487223856591),
#     np.float64(-701.6458791223906),
#     np.float64(-524.0444946544293),
#     np.float64(-627.6634089698083),
#     np.float64(-695.4656739346634),
#     np.float64(-514.5065995024777),
#     np.float64(-588.5213811866985),
#     np.float64(-508.3722981927258),
#     np.float64(-395.03584611099916),
#     np.float64(-299.10765618473465),
#     np.float64(-455.0265503272177),
#     np.float64(-471.2362390580817),
#     np.float64(-348.196206310825),
#     np.float64(-586.4538682608288),
#     np.float64(-455.31619968184117),
#     np.float64(-330.1433148161137),
#     np.float64(-377.11832130222615),
#     np.float64(-232.06247935347025),
#     np.float64(-141.21219985274934),
#     np.float64(-157.4807352946287),
#     np.float64(-234.59108130661411),
#     np.float64(-295.44747590322214),
#     np.float64(-201.42384249235693),
#     np.float64(-367.72682879745645),
#     np.float64(-461.8505743621637),
#     np.float64(-350.3810859244532),
#     np.float64(-422.3519151651558),
#     np.float64(-578.5517566499918),
#     np.float64(-524.8160764117353),
#     np.float64(-568.2088163790742),
#     np.float64(-457.65495432647975),
#     np.float64(-272.0854638190673),
#     np.float64(-146.67774376702536),
#     np.float64(-133.1732854738828),
#     np.float64(-171.04290783307232)],
#    'episode_lengths': [100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100,
#     100],
#    'policy_default_policy_reward': [np.float64(-112.65701623075596),
#     np.float64(-338.2226661743705),
#     np.float64(-670.5977928076817),
#     np.float64(-93.05482061781025),
#     np.float64(-127.74099769615474),
#     np.float64(-129.0199111437539),
#     np.float64(-114.85539684549133),
#     np.float64(-87.15856127477514),
#     np.float64(-95.28611124042529),
#     np.float64(-87.78153670530116),
#     np.float64(-111.31042529845604),
#     np.float64(-113.5706569180681),
#     np.float64(-89.14495907731302),
#     np.float64(-119.72838649061417),
#     np.float64(-132.69389702387565),
#     np.float64(-164.32027124365186),
#     np.float64(-160.5200347884187),
#     np.float64(-121.89587649300096),
#     np.float64(-120.06747105115595),
#     np.float64(-104.36804126323949),
#     np.float64(-113.49347437891434),
#     np.float64(-98.17204384459515),
#     np.float64(-126.14042403807423),
#     np.float64(-108.3021503933399),
#     np.float64(-117.02000808716014),
#     np.float64(-118.08704433240159),
#     np.float64(-141.17036770152237),
#     np.float64(-111.52672625255511),
#     np.float64(-146.986444142738),
#     np.float64(-199.9808753066168),
#     np.float64(-135.91516756689853),
#     np.float64(-214.63765501999202),
#     np.float64(-157.05186359309363),
#     np.float64(-135.84762686930523),
#     np.float64(-125.00982966266878),
#     np.float64(-201.19288776006255),
#     np.float64(-181.82836000613918),
#     np.float64(-166.62672558143944),
#     np.float64(-183.28362396647637),
#     np.float64(-154.24697150684818),
#     np.float64(-125.57225700481084),
#     np.float64(-141.58397755080495),
#     np.float64(-132.5327710594682),
#     np.float64(-113.21108537550032),
#     np.float64(-129.1497543555165),
#     np.float64(-116.15991849584913),
#     np.float64(-108.58172207553422),
#     np.float64(-103.04582912269191),
#     np.float64(-109.67542949643803),
#     np.float64(-102.67287844744911),
#     np.float64(-105.63419657468512),
#     np.float64(-123.99375587008515),
#     np.float64(-82.57539414317334),
#     np.float64(-101.38864542014346),
#     np.float64(-89.31336685760361),
#     np.float64(-102.04931952420577),
#     np.float64(-102.08645679301401),
#     np.float64(-103.2594875333809),
#     np.float64(-111.09302610635838),
#     np.float64(-120.42790582237333),
#     np.float64(-117.71512111879824),
#     np.float64(-146.5169632194968),
#     np.float64(-120.48175604667665),
#     np.float64(-102.18945328830841),
#     np.float64(-87.10025009970488),
#     np.float64(-107.25015025812117),
#     np.float64(-122.3476537907635),
#     np.float64(-120.81014097370738),
#     np.float64(-106.63139603835498),
#     np.float64(-104.93753146691638),
#     np.float64(-111.56280821378957),
#     np.float64(-187.6491337665973),
#     np.float64(-198.1039454216369),
#     np.float64(-188.13096598754225),
#     np.float64(-136.18752486292598),
#     np.float64(-138.65642035054896),
#     np.float64(-112.43476576092654),
#     np.float64(-140.96222391544714),
#     np.float64(-133.89988909251355),
#     np.float64(-128.55230353137745),
#     np.float64(-157.1029521711684),
#     np.float64(-163.48239983326243),
#     np.float64(-164.41298856912488),
#     np.float64(-147.00026642356124),
#     np.float64(-180.65640842942747),
#     np.float64(-193.3083066973411),
#     np.float64(-141.69928885869058),
#     np.float64(-147.79822642310262),
#     np.float64(-118.26602202292496),
#     np.float64(-108.4471084148806),
#     np.float64(-156.02386268322522),
#     np.float64(-150.67353163483708),
#     np.float64(-110.14379892541716),
#     np.float64(-105.83902136979555),
#     np.float64(-125.40703980964612),
#     np.float64(-148.27078290457786),
#     np.float64(-117.70767917604506),
#     np.float64(-200.95706645213124),
#     np.float64(-189.11512348144566),
#     np.float64(-180.02902702329135),
#     np.float64(-182.5168647939965),
#     np.float64(-223.74389977988886),
#     np.float64(-177.5232725623174),
#     np.float64(-259.41540457435144),
#     np.float64(-269.97927571474173),
#     np.float64(-241.9813200109717),
#     np.float64(-275.76676710952535),
#     np.float64(-417.9578185610844),
#     np.float64(-313.53504077117753),
#     np.float64(-270.92437576860226),
#     np.float64(-284.8747701265499),
#     np.float64(-156.62913294934387),
#     np.float64(-113.09190120217842),
#     np.float64(-98.75577087263514),
#     np.float64(-87.67698170868563),
#     np.float64(-100.80808620483816),
#     np.float64(-113.55796910398529),
#     np.float64(-134.3074338759711),
#     np.float64(-131.9134622664944),
#     np.float64(-121.14861715990241),
#     np.float64(-156.34812928365457),
#     np.float64(-113.98281116450775),
#     np.float64(-129.38673043882704),
#     np.float64(-148.84697401138473),
#     np.float64(-216.4309644054457),
#     np.float64(-141.80118197598486),
#     np.float64(-93.25597104720364),
#     np.float64(-129.42486139558704),
#     np.float64(-116.50395036811932),
#     np.float64(-113.83234046621895),
#     np.float64(-171.48122676976885),
#     np.float64(-204.65420102204476),
#     np.float64(-188.02854878717818),
#     np.float64(-92.65331577422782),
#     np.float64(-130.33773609194844),
#     np.float64(-93.66178134304775),
#     np.float64(-105.99239822685024),
#     np.float64(-119.19432254968292),
#     np.float64(-111.30205029317892),
#     np.float64(-146.51213837644715),
#     np.float64(-206.74877550331033),
#     np.float64(-227.1110273934137),
#     np.float64(-263.0599651219591),
#     np.float64(-194.54616579761722),
#     np.float64(-179.1754183435732),
#     np.float64(-109.8516642448997),
#     np.float64(-119.29639070172294),
#     np.float64(-185.97974446248847),
#     np.float64(-175.2910141685179),
#     np.float64(-257.5259964868688),
#     np.float64(-195.4187694343584),
#     np.float64(-158.27722433551287),
#     np.float64(-116.193214750557),
#     np.float64(-124.91884166304246),
#     np.float64(-110.21575913982679),
#     np.float64(-95.75932187791085),
#     np.float64(-175.77888691447998),
#     np.float64(-191.42623428760146),
#     np.float64(-188.53196998896556),
#     np.float64(-291.4833478045011),
#     np.float64(-346.1873332295942),
#     np.float64(-231.6462624630411),
#     np.float64(-232.72629053810886),
#     np.float64(-128.32129016656705),
#     np.float64(-121.71344638846887),
#     np.float64(-125.98450027496057),
#     np.float64(-137.95134282143647),
#     np.float64(-148.05009922374333),
#     np.float64(-151.72917516071612),
#     np.float64(-187.08590675880865),
#     np.float64(-258.159714209092),
#     np.float64(-203.57954952075372),
#     np.float64(-200.33709514222613),
#     np.float64(-150.08435103911702),
#     np.float64(-131.88047672434286),
#     np.float64(-121.9962391301853),
#     np.float64(-152.31520086008192),
#     np.float64(-127.16266091895184),
#     np.float64(-150.69646471867594),
#     np.float64(-216.0804381040241),
#     np.float64(-294.4409862972887),
#     np.float64(-284.99601845650733),
#     np.float64(-397.48551672960383),
#     np.float64(-379.5351225884448),
#     np.float64(-307.1545210075104),
#     np.float64(-365.964866281739),
#     np.float64(-253.83874764739693),
#     np.float64(-219.10466622852456),
#     np.float64(-339.026306074713),
#     np.float64(-454.8484843846207),
#     np.float64(-335.7059101508049),
#     np.float64(-154.25124565963162),
#     np.float64(-217.6556854680291),
#     np.float64(-296.6128899786792),
#     np.float64(-200.18053785780538),
#     np.float64(-256.49718171045015),
#     np.float64(-374.37237200957765),
#     np.float64(-318.0808707226058),
#     np.float64(-544.6136566769147),
#     np.float64(-534.1210061984655),
#     np.float64(-439.85368206093165),
#     np.float64(-380.8035434523578),
#     np.float64(-280.62270694680643),
#     np.float64(-291.57475176705213),
#     np.float64(-240.58247990504069),
#     np.float64(-362.56222349942215),
#     np.float64(-253.38861598378367),
#     np.float64(-184.89837105836276),
#     np.float64(-253.45881844143273),
#     np.float64(-347.4412184342367),
#     np.float64(-239.05265044690117),
#     np.float64(-256.3723021989495),
#     np.float64(-230.0003481949092),
#     np.float64(-215.3523356604298),
#     np.float64(-218.02814856905627),
#     np.float64(-329.8428490749315),
#     np.float64(-224.08485146327854),
#     np.float64(-204.90760890614868),
#     np.float64(-327.5945758735411),
#     np.float64(-446.5601555651939),
#     np.float64(-480.27853154635665),
#     np.float64(-656.1332031929378),
#     np.float64(-487.06483276262594),
#     np.float64(-412.08675758861176),
#     np.float64(-475.4738465452545),
#     np.float64(-651.411710313587),
#     np.float64(-543.6616511393506),
#     np.float64(-627.4320114698911),
#     np.float64(-716.356413753787),
#     np.float64(-585.2923377395807),
#     np.float64(-599.2046439744922),
#     np.float64(-620.3188923608878),
#     np.float64(-521.5675668487527),
#     np.float64(-432.9178320194184),
#     np.float64(-579.5263292438092),
#     np.float64(-681.8483620379943),
#     np.float64(-543.6559444043406),
#     np.float64(-648.7392847262003),
#     np.float64(-716.8912355532848),
#     np.float64(-574.4864293302736),
#     np.float64(-654.8403670708751),
#     np.float64(-693.813942217243),
#     np.float64(-601.5491882361384),
#     np.float64(-589.8124172783928),
#     np.float64(-625.1016409391868),
#     np.float64(-619.8680106330427),
#     np.float64(-529.6355859028314),
#     np.float64(-650.7752287981373),
#     np.float64(-651.6774125167507),
#     np.float64(-554.3275667365309),
#     np.float64(-584.3220999660251),
#     np.float64(-580.8319815562375),
#     np.float64(-524.6387114942016),
#     np.float64(-590.8670201304188),
#     np.float64(-750.7412049516593),
#     np.float64(-636.3048829952737),
#     np.float64(-602.5326275340614),
#     np.float64(-779.032968362217),
#     np.float64(-655.2949250095572),
#     np.float64(-546.9266447828456),
#     np.float64(-708.2286975459772),
#     np.float64(-682.2620994731428),
#     np.float64(-559.6044105396815),
#     np.float64(-677.1305277781389),
#     np.float64(-732.6740582806989),
#     np.float64(-531.4029114917782),
#     np.float64(-558.2721430822995),
#     np.float64(-576.0916088847979),
#     np.float64(-583.3795995858576),
#     np.float64(-480.777815000758),
#     np.float64(-583.6264201029074),
#     np.float64(-651.325843520375),
#     np.float64(-567.6820083971514),
#     np.float64(-688.1491818217719),
#     np.float64(-661.6838076360581),
#     np.float64(-511.75542441763787),
#     np.float64(-617.2481899749092),
#     np.float64(-708.9590075184027),
#     np.float64(-564.1269654039339),
#     np.float64(-516.5246402217551),
#     np.float64(-727.1902452894896),
#     np.float64(-635.699325527755),
#     np.float64(-544.0503801230745),
#     np.float64(-694.4970788323981),
#     np.float64(-722.6159351905236),
#     np.float64(-562.4299171569547),
#     np.float64(-733.8554613179166),
#     np.float64(-775.749429544694),
#     np.float64(-617.7476952504438),
#     np.float64(-638.6389807551009),
#     np.float64(-582.9919967942913),
#     np.float64(-562.4481465961657),
#     np.float64(-552.5169267432118),
#     np.float64(-750.7425354928733),
#     np.float64(-691.8016962692811),
#     np.float64(-553.6422181218713),
#     np.float64(-699.2774993010673),
#     np.float64(-730.2595178148101),
#     np.float64(-558.6752895954088),
#     np.float64(-588.6333617863872),
#     np.float64(-692.165345724754),
#     np.float64(-551.0112024179484),
#     np.float64(-520.7312112833514),
#     np.float64(-513.4518174362637),
#     np.float64(-481.72961998986705),
#     np.float64(-467.5996813214964),
#     np.float64(-595.7895058069305),
#     np.float64(-577.6373281683625),
#     np.float64(-535.4101621777658),
#     np.float64(-518.2530069879493),
#     np.float64(-660.6272285756312),
#     np.float64(-547.0326368787332),
#     np.float64(-626.356574520566),
#     np.float64(-645.1150703985335),
#     np.float64(-603.6161199026344),
#     np.float64(-562.5467675260293),
#     np.float64(-655.2724399575657),
#     np.float64(-631.0051528052811),
#     np.float64(-514.27023151788),
#     np.float64(-708.5710196472365),
#     np.float64(-651.6217919021116),
#     np.float64(-544.740417781971),
#     np.float64(-711.7063122032988),
#     np.float64(-712.0838044816339),
#     np.float64(-549.3572018045326),
#     np.float64(-471.1146909461209),
#     np.float64(-604.8381759122283),
#     np.float64(-604.618997722404),
#     np.float64(-533.9354269840812),
#     np.float64(-698.9688874687039),
#     np.float64(-706.4689972375091),
#     np.float64(-549.9428778123943),
#     np.float64(-662.5446781838269),
#     np.float64(-670.9938903356648),
#     np.float64(-563.3125331663459),
#     np.float64(-619.0609267554744),
#     np.float64(-703.9472335109758),
#     np.float64(-568.0905463161164),
#     np.float64(-496.09259936226124),
#     np.float64(-551.1173796949402),
#     np.float64(-489.77109388600246),
#     np.float64(-522.9187503271492),
#     np.float64(-692.0935341981105),
#     np.float64(-666.9434962286854),
#     np.float64(-588.5156831051567),
#     np.float64(-664.2696901192824),
#     np.float64(-542.6420814212444),
#     np.float64(-508.76029627087007),
#     np.float64(-527.6894597817411),
#     np.float64(-510.9855897773818),
#     np.float64(-507.2477093733652),
#     np.float64(-550.6368808330029),
#     np.float64(-714.8381352047174),
#     np.float64(-559.6055827717338),
#     np.float64(-465.68097349244454),
#     np.float64(-686.2878766715118),
#     np.float64(-573.5933289727842),
#     np.float64(-492.76481429060334),
#     np.float64(-613.9670262597517),
#     np.float64(-571.3720399282216),
#     np.float64(-537.8069340933445),
#     np.float64(-561.4182468067826),
#     np.float64(-618.5592908133419),
#     np.float64(-561.9917101822323),
#     np.float64(-564.3093431796951),
#     np.float64(-658.1487223856591),
#     np.float64(-701.6458791223906),
#     np.float64(-524.0444946544293),
#     np.float64(-627.6634089698083),
#     np.float64(-695.4656739346634),
#     np.float64(-514.5065995024777),
#     np.float64(-588.5213811866985),
#     np.float64(-508.3722981927258),
#     np.float64(-395.03584611099916),
#     np.float64(-299.10765618473465),
#     np.float64(-455.0265503272177),
#     np.float64(-471.2362390580817),
#     np.float64(-348.196206310825),
#     np.float64(-586.4538682608288),
#     np.float64(-455.31619968184117),
#     np.float64(-330.1433148161137),
#     np.float64(-377.11832130222615),
#     np.float64(-232.06247935347025),
#     np.float64(-141.21219985274934),
#     np.float64(-157.4807352946287),
#     np.float64(-234.59108130661411),
#     np.float64(-295.44747590322214),
#     np.float64(-201.42384249235693),
#     np.float64(-367.72682879745645),
#     np.float64(-461.8505743621637),
#     np.float64(-350.3810859244532),
#     np.float64(-422.3519151651558),
#     np.float64(-578.5517566499918),
#     np.float64(-524.8160764117353),
#     np.float64(-568.2088163790742),
#     np.float64(-457.65495432647975),
#     np.float64(-272.0854638190673),
#     np.float64(-146.67774376702536),
#     np.float64(-133.1732854738828),
#     np.float64(-171.04290783307232)]},
#   'sampler_perf': {'mean_raw_obs_processing_ms': np.float64(0.31920585392495227),
#    'mean_inference_ms': np.float64(0.5955811122370156),
#    'mean_action_processing_ms': np.float64(0.08058823564525218),
#    'mean_env_wait_ms': np.float64(0.39173427163597113),
#    'mean_env_render_ms': np.float64(0.0)},
#   'num_faulty_episodes': 0,
#   'connector_metrics': {},
#   'num_episodes': 400,
#   'episode_return_max': np.float64(-82.57539414317334),
#   'episode_return_min': np.float64(-779.032968362217),
#   'episode_return_mean': np.float64(-353.2756049011565),
#   'episodes_this_iter': 400},
#  'num_agent_steps_sampled_this_iter': 40000,
#  'num_env_steps_sampled_this_iter': 40000,
#  'timesteps_this_iter': 40000}
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/events.py", line 129, in cb_
#     return cb(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/events.py", line 159, in _state
#     self._event.__call__(
#   File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/events.py", line 98, in __call__
#     return super().__call__(context)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callbacks.py", line 496, in __call__
#     return self._callables.__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callables.py", line 89, in __call__
#     res[f] = f(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callbacks.py", line 158, in __call__
#     res = ctx.ack.get()
#           ^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callables.py", line 222, in get
#     raise self.__exc__
#   File "/usr/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/tmp/ipykernel_958141/2175495296.py", line 72, in run
#   File "/home/AD/user/lab/controllables-core/packages/controllables/core/tools/rllib/env.py", line 319, in step_episode
#     self.agent.action.value = self.get_action(episode_id)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/packages/controllables/core/tools/rllib/env.py", line 271, in get_action
#     return super().get_action(
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 139, in get_action
#     return episode.wait_for_action(observation)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 297, in wait_for_action
#     return self.action_queue.get(True, timeout=300.0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/queue.py", line 179, in get
#     raise Empty
# _queue.Empty
# Exception in thread Thread-11:
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/systems.py", line 110, in run
#     status = self._kernel.run(args=self._cli_args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/_kernel/__init__.py", line 107, in run
#     self.hooks.__call__('run:post')
#   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callbacks.py", line 560, in __call__
#     return self[ref].__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callbacks.py", line 496, in __call__
#     return self._callables.__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callables.py", line 89, in __call__
#     res[f] = f(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/events.py", line 134, in _raise_exc
#     raise __exc__
#   File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/events.py", line 129, in cb_
#     return cb(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/events.py", line 159, in _state
#     self._event.__call__(
#   File "/home/AD/user/lab/controllables-core/packages/controllables/energyplus/events.py", line 98, in __call__
#     return super().__call__(context)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callbacks.py", line 496, in __call__
#     return self._callables.__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callables.py", line 89, in __call__
#     res[f] = f(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callbacks.py", line 158, in __call__
#     res = ctx.ack.get()
#           ^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/packages/controllables/core/callables.py", line 222, in get
#     raise self.__exc__
#   File "/usr/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/tmp/ipykernel_958141/2175495296.py", line 72, in run
#   File "/home/AD/user/lab/controllables-core/packages/controllables/core/tools/rllib/env.py", line 319, in step_episode
#     self.agent.action.value = self.get_action(episode_id)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/packages/controllables/core/tools/rllib/env.py", line 271, in get_action
#     return super().get_action(
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 139, in get_action
#     return episode.wait_for_action(observation)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 297, in wait_for_action
#     return self.action_queue.get(True, timeout=300.0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/queue.py", line 179, in get
#     raise Empty
# _queue.Empty
