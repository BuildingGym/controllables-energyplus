# %% [markdown]
# # 📚 Case Study 101a: Reinforcement Learning Based Control, Mono-Agent
#
# Before you start:
# - Make sure you have completed [](TUT000_setup.ipynb) through [](TUT003_variables.ipynb).
#
# What you will learn in this chapter:
# - TODO

# %%
import numpy as _numpy_

from controllables.core.tools.gymnasium import BoxSpace, DictSpace
from controllables.core.tools.rllib import Env
from controllables.energyplus import Actuator, OutputVariable
from controllables.energyplus import examples


class UserEnv(Env):
    action_space = DictSpace({
        'thermostat': BoxSpace(
            low=15., high=20.,
            dtype=_numpy_.float32,
            shape=(),
        ).bind(
            Actuator.Ref(
                type='Zone Temperature Control',
                control_type='Heating Setpoint',
                key='MAIN ZONE',
            )            
        )
    })

    observation_space = DictSpace({
        'temperature': BoxSpace(
            low=-_numpy_.inf, high=+_numpy_.inf,
            dtype=_numpy_.float32,
            shape=(),
        ).bind(
            OutputVariable.Ref(
                type='Zone Mean Air Temperature',
                key='MAIN ZONE',
            )
        ),
    })

    reward = lambda agent: -abs(
        agent.observation['temperature'].value - agent.action['thermostat'].value
    )
    r"""
    Reward function.

    This reward function aims to minimize the control error, 
    i.e., the difference between the thermostat setpoint and the actual temperature.
    """

    def __init__(self, config: dict = dict()):
        super().__init__({
            'action_space': self.__class__.action_space,
            'observation_space': self.__class__.observation_space,
            'reward': self.__class__.reward,
            **config,
        })

    def run(self):
        # create a system
        system = examples.systems.X1ZoneEvapCooler(repeat=True)
        # enable progress reporting
        system.add('logging:progress')
        # attach this environment to the system
        system.add(self)
        # run the system in background
        system.start()

        # continuously...
        while True:
            # start a new episode
            episode_id = self.start_episode()
            # loop: here, it runs 100 steps of the episode
            for _ in range(100):
                with system.events['timestep'].wait(deferred=True):
                    self.step_episode(episode_id)
            # end the started episode after the above steps
            self.end_episode(episode_id)

# %% [markdown]
# ### Training

# %%
from ray.rllib.algorithms.ppo import PPO, PPOConfig

algo = PPO(
    PPOConfig()
    .environment(UserEnv)
    .rollouts(
        # NOTE this env (an `ExternalEnv`) does not support connectors
        enable_connectors=False,
    )
    # TODO
    .resources(num_gpus=1.)
)
# Out:
# 2024-10-11 14:30:29,267	WARNING deprecation.py:50 -- DeprecationWarning: `rollouts` has been deprecated. Use `AlgorithmConfig.env_runners(..)` instead. This will raise an error in the future!
# /home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:555: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2024-10-11 14:30:29,932	INFO worker.py:1786 -- Started a local Ray instance.
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s, Initializing HVAC]
#   0%|          | 0/100 [00:00<?, ?it/s, Initializing Simulation]
#   0%|          | 0.0/100 [00:00<?, ?it/s, Starting Simulation at 12/21 for DENVER CENTENNIAL ANN HTG 99.6% CONDNS DB]/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/variables.py:355: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='MAIN ZONE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=938908)   _warnings_.warn(
#   0%|          | 0.0/100 [00:00<?, ?it/s, Starting Simulation at 12/21 for DENVER CENTENNIAL ANN HTG 99.6% CONDNS DB]/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/variables.py:355: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='MAIN ZONE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# 2024-10-11 14:30:33,133	WARNING util.py:61 -- Install gputil for GPU system monitoring.

# %%
for i in range(2):
    print(i, algo.train())
# Out:
#   0%|          | 0.0/100 [00:00<?, ?it/s, Warming up {2}]
#   1%|          | 1.0/100 [00:00<01:09,  1.42it/s, Starting Simulation at 07/21 for DENVER CENTENNIAL ANN CLG 1% CONDNS DB=>MWB]
#   1%|          | 1.0/100 [00:01<01:09,  1.42it/s, Warming up {4}]
#   1%|          | 1.0/100 [00:01<01:07,  1.47it/s, Warming up {2}]
#   1%|          | 1.0/100 [00:01<01:09,  1.42it/s, Starting Simulation at 01/01/2013 for RUN PERIOD 1]
#   1%|          | 1.0/100 [00:01<01:07,  1.47it/s, Starting Simulation at 01/01/2013 for RUN PERIOD 1]
#   2%|▏         | 2.0/100 [00:01<01:16,  1.28it/s, Starting Simulation at 01/01/2013 for RUN PERIOD 1]
#   0%|          | 0.0/100 [00:00<?, ?it/s, Warming up {2}]
#   1%|          | 1.0/100 [00:00<01:07,  1.47it/s, Starting Simulation at 07/21 for DENVER CENTENNIAL ANN CLG 1% CONDNS DB=>MWB]
#   5%|▌         | 5.0/100 [00:07<03:25,  2.16s/it, Starting Simulation at 01/01/2013 for RUN PERIOD 1] [repeated 6x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
#   6%|▌         | 6.0/100 [00:08<02:37,  1.68s/it, Updating Shadowing Calculations, Start Date=01/21/2013]
#   7%|▋         | 7.000000000000001/100 [00:09<02:01,  1.31s/it, Continuing Simulation at 01/21/2013 for RUN PERIOD 1]
#   8%|▊         | 8.0/100 [00:09<01:41,  1.11s/it, Continuing Simulation at 01/21/2013 for RUN PERIOD 1]
# (RolloutWorker pid=938908) Exception in thread Thread-1:
# (RolloutWorker pid=938908) Traceback (most recent call last):
# (RolloutWorker pid=938908)   File "/usr/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
# (RolloutWorker pid=938908)     self.run()
# (RolloutWorker pid=938908)   File "/tmp/ipykernel_938592/3944663123.py", line 66, in run
# (RolloutWorker pid=938908)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 255, in step_episode
# (RolloutWorker pid=938908)     self.agent.action.value = self.get_action(episode_id)
# (RolloutWorker pid=938908)                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=938908)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 218, in get_action
# (RolloutWorker pid=938908)     return super().get_action(
# (RolloutWorker pid=938908)            ^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=938908)   File "/home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 139, in get_action
# (RolloutWorker pid=938908)     return episode.wait_for_action(observation)
# (RolloutWorker pid=938908)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=938908)   File "/home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 297, in wait_for_action
# (RolloutWorker pid=938908)     return self.action_queue.get(True, timeout=300.0)
# (RolloutWorker pid=938908)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=938908)   File "/usr/lib/python3.11/queue.py", line 179, in get
# (RolloutWorker pid=938908)     raise Empty
# (RolloutWorker pid=938908) _queue.Empty
#   0%|          | 0/100 [00:00<?, ?it/s]
# (RolloutWorker pid=938903) Exception in thread Thread-1:
# (RolloutWorker pid=938903) Traceback (most recent call last):
# (RolloutWorker pid=938903)   File "/usr/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
# (RolloutWorker pid=938903)     self.run()
# (RolloutWorker pid=938903)   File "/tmp/ipykernel_938592/3944663123.py", line 66, in run
# (RolloutWorker pid=938903)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 255, in step_episode
# (RolloutWorker pid=938903)     self.agent.action.value = self.get_action(episode_id)
# (RolloutWorker pid=938903)                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=938903)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 218, in get_action
# (RolloutWorker pid=938903)     return super().get_action(
# (RolloutWorker pid=938903)            ^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=938903)   File "/home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 139, in get_action
# (RolloutWorker pid=938903)     return episode.wait_for_action(observation)
# (RolloutWorker pid=938903)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=938903)   File "/home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 297, in wait_for_action
# (RolloutWorker pid=938903)     return self.action_queue.get(True, timeout=300.0)
# (RolloutWorker pid=938903)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=938903)   File "/usr/lib/python3.11/queue.py", line 179, in get
# (RolloutWorker pid=938903)     raise Empty
# (RolloutWorker pid=938903) _queue.Empty
#   0%|          | 0.0/100 [00:00<?, ?it/s, Starting Simulation at 12/21 for DENVER CENTENNIAL ANN HTG 99.6% CONDNS DB]/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/variables.py:355: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='MAIN ZONE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=938907)   _warnings_.warn(
# (raylet) [2024-10-12 12:25:30,870 E 938799 938799] (raylet) node_manager.cc:3065: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: e83f3a1901447140c2e036236a1932f0ea1ce6fe3148c06b8753f5d0, IP: 192.168.200.249) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 192.168.200.249`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s, EnergyPlus, Version 23.2.0-7636e6b3e9, YMD=2024.10.12 12:28]
#   0%|          | 0.0/100 [00:00<?, ?it/s, Starting Simulation at 12/21 for DENVER CENTENNIAL ANN HTG 99.6% CONDNS DB]/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/variables.py:355: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='MAIN ZONE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=938899)   _warnings_.warn(
# (raylet) [2024-10-12 12:28:30,873 E 938799 938799] (raylet) node_manager.cc:3065: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: e83f3a1901447140c2e036236a1932f0ea1ce6fe3148c06b8753f5d0, IP: 192.168.200.249) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 192.168.200.249`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (RolloutWorker pid=938899) Exception in thread Thread-1:
# (RolloutWorker pid=938899) Traceback (most recent call last):
# (RolloutWorker pid=938899)   File "/usr/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
# (RolloutWorker pid=938899)     self.run()
# (RolloutWorker pid=938899)   File "/tmp/ipykernel_938592/3944663123.py", line 66, in run
# (RolloutWorker pid=938899)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 255, in step_episode
# (RolloutWorker pid=938899)     self.agent.action.value = self.get_action(episode_id)
# (RolloutWorker pid=938899)                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=938899)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 218, in get_action
# (RolloutWorker pid=938899)     return super().get_action(
# (RolloutWorker pid=938899)            ^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=938899)   File "/home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 139, in get_action
# (RolloutWorker pid=938899)     return episode.wait_for_action(observation)
# (RolloutWorker pid=938899)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=938899)   File "/home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 297, in wait_for_action
# (RolloutWorker pid=938899)     return self.action_queue.get(True, timeout=300.0)
# (RolloutWorker pid=938899)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=938899)   File "/usr/lib/python3.11/queue.py", line 179, in get
# (RolloutWorker pid=938899)     raise Empty
# (RolloutWorker pid=938899) _queue.Empty
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/100 [00:00<?, ?it/s, EnergyPlus, Version 23.2.0-7636e6b3e9, YMD=2024.10.12 12:34]
#   0%|          | 0.0/100 [00:00<?, ?it/s, Starting Simulation at 12/21 for DENVER CENTENNIAL ANN HTG 99.6% CONDNS DB]/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/variables.py:355: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='MAIN ZONE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
# (RolloutWorker pid=938909)   _warnings_.warn(
# (raylet) [2024-10-12 12:34:30,879 E 938799 938799] (raylet) node_manager.cc:3065: 1 Workers (tasks / actors) killed due to memory pressure (OOM), 0 Workers crashed due to other reasons at node (ID: e83f3a1901447140c2e036236a1932f0ea1ce6fe3148c06b8753f5d0, IP: 192.168.200.249) over the last time period. To see more information about the Workers killed on this node, use `ray logs raylet.out -ip 192.168.200.249`
# (raylet)
# (raylet) Refer to the documentation on how to address the out of memory issue: https://docs.ray.io/en/latest/ray-core/scheduling/ray-oom-prevention.html. Consider provisioning more memory on this node or reducing task parallelism by requesting more CPUs per task. To adjust the kill threshold, set the environment variable `RAY_memory_usage_threshold` when starting Ray. To disable worker killing, set the environment variable `RAY_memory_monitor_refresh_ms` to zero.
# (RolloutWorker pid=938909) Exception in thread Thread-1:
# (RolloutWorker pid=938909) Traceback (most recent call last):
# (RolloutWorker pid=938909)   File "/usr/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
# (RolloutWorker pid=938909)     self.run()
# (RolloutWorker pid=938909)   File "/tmp/ipykernel_938592/3944663123.py", line 66, in run
# (RolloutWorker pid=938909)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 255, in step_episode
# (RolloutWorker pid=938909)     self.agent.action.value = self.get_action(episode_id)
# (RolloutWorker pid=938909)                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=938909)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 218, in get_action
# (RolloutWorker pid=938909)     return super().get_action(
# (RolloutWorker pid=938909)            ^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=938909)   File "/home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 139, in get_action
# (RolloutWorker pid=938909)     return episode.wait_for_action(observation)
# (RolloutWorker pid=938909)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=938909)   File "/home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 297, in wait_for_action
# (RolloutWorker pid=938909)     return self.action_queue.get(True, timeout=300.0)
# (RolloutWorker pid=938909)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=938909)   File "/usr/lib/python3.11/queue.py", line 179, in get
# (RolloutWorker pid=938909)     raise Empty
# (RolloutWorker pid=938909) _queue.Empty
# 2024-10-11 14:30:35,757	WARNING deprecation.py:50 -- DeprecationWarning: `ray.rllib.execution.train_ops.multi_gpu_train_one_step` has been deprecated. This will raise an error in the future!
# 0 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'custom_metrics': {}, 'learner_stats': {'cur_kl_coeff': 0.20000000000000004, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.703443007315359, 'policy_loss': 0.002579946020838394, 'vf_loss': 9.700014789130098, 'vf_explained_var': -1.986821492513021e-09, 'kl': 0.0042412850173360475, 'entropy': 1.4620032405340544, 'entropy_coeff': 0.0}, 'model': {}, 'num_grad_updates_lifetime': 465.5, 'diff_num_grad_updates_vs_sampler_policy': 464.5}}, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000}, 'env_runners': {'episode_reward_max': -100.27354907989502, 'episode_reward_min': -692.2425556182861, 'episode_reward_mean': -162.7630206823349, 'episode_len_mean': 100.0, 'episode_media': {}, 'episodes_timesteps_total': 4000, 'policy_reward_min': {'default_policy': -692.2425556182861}, 'policy_reward_max': {'default_policy': -100.27354907989502}, 'policy_reward_mean': {'default_policy': -162.7630206823349}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-114.77738189697266, -318.36307430267334, -670.5254468917847, -122.70989894866943, -116.28971862792969, -122.57246112823486, -115.6611213684082, -116.19912147521973, -113.90430164337158, -113.5844898223877, -116.12948226928711, -114.18343162536621, -102.58525943756104, -120.61964988708496, -128.75443077087402, -186.84833526611328, -139.9865550994873, -126.20004558563232, -148.8408327102661, -119.65008354187012, -114.78246784210205, -350.2067070007324, -692.2425556182861, -156.60093116760254, -124.23616123199463, -110.00620746612549, -131.42919635772705, -100.27354907989502, -109.2036018371582, -109.85718059539795, -111.23858261108398, -123.27812576293945, -113.37078094482422, -117.96191787719727, -128.29802799224854, -170.15846347808838, -133.94728755950928, -124.9911117553711, -133.04382801055908, -127.00902080535889], 'episode_lengths': [100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100, 100], 'policy_default_policy_reward': [-114.77738189697266, -318.36307430267334, -670.5254468917847, -122.70989894866943, -116.28971862792969, -122.57246112823486, -115.6611213684082, -116.19912147521973, -113.90430164337158, -113.5844898223877, -116.12948226928711, -114.18343162536621, -102.58525943756104, -120.61964988708496, -128.75443077087402, -186.84833526611328, -139.9865550994873, -126.20004558563232, -148.8408327102661, -119.65008354187012, -114.78246784210205, -350.2067070007324, -692.2425556182861, -156.60093116760254, -124.23616123199463, -110.00620746612549, -131.42919635772705, -100.27354907989502, -109.2036018371582, -109.85718059539795, -111.23858261108398, -123.27812576293945, -113.37078094482422, -117.96191787719727, -128.29802799224854, -170.15846347808838, -133.94728755950928, -124.9911117553711, -133.04382801055908, -127.00902080535889]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.11737466979180158, 'mean_inference_ms': 0.5535655892290495, 'mean_action_processing_ms': 0.08253116881357803, 'mean_env_wait_ms': 0.5332558890016641, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 40, 'episode_return_max': -100.27354907989502, 'episode_return_min': -692.2425556182861, 'episode_return_mean': -162.7630206823349, 'episodes_this_iter': 40}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 4000, 'num_agent_steps_trained': 4000, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 593.6534987120217, 'num_env_steps_trained_throughput_per_sec': 593.6534987120217, 'timesteps_total': 4000, 'num_env_steps_sampled_lifetime': 4000, 'num_agen ...
# ### Evaluation
#
# TODO

# %%
from ray.rllib.algorithms.callbacks import DefaultCallbacks
from controllables.core.tools.records import VariableRecords


class PlottingCallbacks(DefaultCallbacks):
    def __init__(self):
        self.env_records = None

    def on_episode_start(self, *, episode, worker, **kwargs):
        env = worker.env
        system = env.system
        if self.env_records is None:
            self.env_records = records = VariableRecords({
                '🕰️': system['time'],
                '🍩': env.agent.reward,
            })
            display(
                records.plot.scatter(x='🕰️', y='🍩')
                .watch(records.events['change'] % 1_000)
            )

    def on_episode_step(self, *, episode, **kwargs):
        self.env_records.poll()


# create a new algorithm instance specifically for evaluation
algo_eval = PPO(
    PPOConfig()
    .environment(UserEnv)
    .env_runners(
        # NOTE this env (an `ExternalEnv`) does not support connectors
        enable_connectors=False,
        # disable distributed workers for local plotting
        num_rollout_workers=0,
        create_env_on_local_worker=True,
    )
    .evaluation(
        evaluation_num_workers=0,
    )
    .callbacks(PlottingCallbacks)
)

# restore weights from the trained algorithm
algo_eval.restore(algo.save())
# Out:
# 2024-10-11 14:30:46,165	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.env_runners(num_rollout_workers)` has been deprecated. Use `AlgorithmConfig.env_runners(num_env_runners)` instead. This will raise an error in the future!
# 2024-10-11 14:30:46,166	WARNING deprecation.py:50 -- DeprecationWarning: `AlgorithmConfig.evaluation(evaluation_num_workers=..)` has been deprecated. Use `AlgorithmConfig.evaluation(evaluation_num_env_runners=..)` instead. This will raise an error in the future!
# /home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:555: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2024-10-11 14:30:46,184	WARNING util.py:61 -- Install gputil for GPU system monitoring.
#   0%|          | 0/100 [00:00<?, ?it/s]
# 2024-10-11 14:30:46,210	WARNING deprecation.py:50 -- DeprecationWarning: `_enable_new_api_stack` has been deprecated. Use `AlgorithmConfig._enable_new_api_stack` instead. This will raise an error in the future!
# 2024-10-11 14:30:46,236	INFO trainable.py:583 -- Restored on 192.168.200.249 from checkpoint: Checkpoint(filesystem=local, path=/tmp/tmpsdsrhrf_)

# %%
algo_eval.evaluate()
# Out:
# /home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/variables.py:355: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='MAIN ZONE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(
# {'env_runners': {'episode_reward_max': -89.72452068328857,
#   'episode_reward_min': -786.6589460372925,
#   'episode_reward_mean': -358.1904717040062,
#   'episode_len_mean': 100.0,
#   'episode_media': {},
#   'episodes_timesteps_total': 40000,
#   'policy_reward_min': {'default_policy': -786.6589460372925},
#   'policy_reward_max': {'default_policy': -89.72452068328857},
#   'policy_reward_mean': {'default_policy': -358.1904717040062},
#   'custom_metrics': {},
#   'hist_stats': {'episode_reward': [-102.94939613342285,
#     -316.2675256729126,
#     -659.9846363067627,
#     -117.86398696899414,
#     -116.76044654846191,
#     -123.20420837402344,
#     -113.22254180908203,
#     -102.05380058288574,
#     -116.11430168151855,
#     -91.32668876647949,
#     -123.42814350128174,
#     -89.72452068328857,
#     -103.8595199584961,
#     -135.62759113311768,
#     -125.70651054382324,
#     -190.1004238128662,
#     -144.19491291046143,
#     -125.39299869537354,
#     -110.02676105499268,
#     -113.25980281829834,
#     -121.3205394744873,
#     -106.76973819732666,
#     -124.68805980682373,
#     -131.80196952819824,
#     -93.67505836486816,
#     -124.15166091918945,
#     -129.0185079574585,
#     -114.81012916564941,
#     -138.8437900543213,
#     -206.58559131622314,
#     -161.2212839126587,
#     -195.34330558776855,
#     -177.48682975769043,
#     -127.76957416534424,
#     -157.711669921875,
#     -209.37622547149658,
#     -172.3892879486084,
#     -147.66004753112793,
#     -168.34492778778076,
#     -164.4016227722168,
#     -137.09285640716553,
#     -175.06220054626465,
#     -128.62042331695557,
#     -136.6043930053711,
#     -123.96184349060059,
#     -139.50703811645508,
#     -115.92948722839355,
#     -114.54910087585449,
#     -115.5465316772461,
#     -109.75074577331543,
#     -111.35252857208252,
#     -122.5620813369751,
#     -109.2632942199707,
#     -107.56895160675049,
#     -94.37308025360107,
#     -90.92442321777344,
#     -99.23900890350342,
#     -99.73305320739746,
#     -97.60369777679443,
#     -121.1868724822998,
#     -94.7587776184082,
#     -131.93535804748535,
#     -112.51188278198242,
#     -92.99738693237305,
#     -103.83690738677979,
#     -131.99870014190674,
#     -137.7929563522339,
#     -136.2449016571045,
#     -127.58947944641113,
#     -115.74145412445068,
#     -118.44151496887207,
#     -198.61471271514893,
#     -203.38660049438477,
#     -191.80608558654785,
#     -139.2814826965332,
#     -132.52815055847168,
#     -105.23841857910156,
#     -167.67424488067627,
#     -139.53756141662598,
#     -122.5443925857544,
#     -142.1615753173828,
#     -140.8063268661499,
#     -166.44577598571777,
#     -160.09907150268555,
#     -206.75685691833496,
#     -189.66888046264648,
#     -124.53798294067383,
#     -138.52179527282715,
#     -119.47575759887695,
#     -111.44347763061523,
#     -146.65759944915771,
#     -151.80080127716064,
#     -97.58103084564209,
#     -93.13924217224121,
#     -114.85750675201416,
#     -119.98259162902832,
#     -116.03882503509521,
#     -200.2708511352539,
#     -219.65366744995117,
#     -170.62253093719482,
#     -194.60920810699463,
#     -241.35770416259766,
#     -204.59977626800537,
#     -271.71760845184326,
#     -287.53116035461426,
#     -255.75453662872314,
#     -622.6437292098999,
#     -563.7609510421753,
#     -680.7867736816406,
#     -664.3248052597046,
#     -551.0317058563232,
#     -662.6991834640503,
#     -690.315957069397,
#     -560.9848356246948,
#     -670.3662405014038,
#     -709.8958568572998,
#     -566.8696727752686,
#     -515.2339420318604,
#     -513.115213394165,
#     -516.3584432601929,
#     -475.45643520355225,
#     -678.8639612197876,
#     -680.8641443252563,
#     -560.4974536895752,
#     -685.8296709060669,
#     -593.0173587799072,
#     -502.8042163848877,
#     -511.7520055770874,
#     -524.9664640426636,
#     -499.9966154098511,
#     -539.4982500076294,
#     -706.466721534729,
#     -599.986517906189,
#     -448.46067905426025,
#     -692.9198455810547,
#     -566.33571434021,
#     -503.085168838501,
#     -606.5109729766846,
#     -572.9900197982788,
#     -531.0774078369141,
#     -541.438229560852,
#     -667.4801273345947,
#     -589.4999084472656,
#     -566.3831720352173,
#     -696.0473108291626,
#     -678.7340831756592,
#     -545.2723445892334,
#     -614.1835308074951,
#     -694.1925373077393,
#     -567.8815059661865,
#     -556.9984817504883,
#     -544.0274906158447,
#     -446.8583745956421,
#     -294.9608373641968,
#     -455.06962871551514,
#     -450.4865074157715,
#     -404.5324659347534,
#     -569.7639474868774,
#     -455.09764671325684,
#     -348.7357769012451,
#     -394.03901195526123,
#     -218.4123249053955,
#     -156.43558406829834,
#     -155.2485704421997,
#     -266.3840265274048,
#     -282.65058422088623,
#     -216.33843898773193,
#     -395.39176845550537,
#     -430.00041484832764,
#     -334.0991458892822,
#     -440.33392906188965,
#     -582.6090478897095,
#     -494.83652782440186,
#     -603.8278942108154,
#     -426.89049434661865,
#     -297.11583614349365,
#     -172.36456966400146,
#     -145.17084312438965,
#     -190.56408882141113]},
#   'sampler_perf': {'mean_raw_obs_processing_ms': 0.4665399022021036,
#    'mean_inference_ms': 0.5472619499134216,
#    'mean_action_processing_ms': 0.08026627230675501,
#    'mean_env_wait_ms': 0.49319785643484315,
#    'mean_env_render_ms': 0.0},
#   'num_faulty_episodes': 0,
#   'connector_metrics': {},
#   'num_episodes': 400,
#   'episode_return_max': -89.72452068328857,
#   'episode_return_min': -786.6589460372925,
#   'episode_return_mean': -358.1904717040062,
#   'episodes_this_iter': 400},
#  'num_agent_steps_sampled_this_iter': 40000,
#  'num_env_steps_sampled_this_iter': 40000,
#  'timesteps_this_iter': 40000}
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/tmp/ipykernel_938592/3944663123.py", line 66, in run
#   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 255, in step_episode
#     self.agent.action.value = self.get_action(episode_id)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 218, in get_action
#     return super().get_action(
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 139, in get_action
#     return episode.wait_for_action(observation)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 297, in wait_for_action
#     return self.action_queue.get(True, timeout=300.0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/queue.py", line 179, in get
#     raise Empty
# _queue.Empty
