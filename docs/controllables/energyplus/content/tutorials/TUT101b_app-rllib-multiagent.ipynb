# %% [markdown]
# # 📚 Case Study 101b: Reinforcement Learning Based Control, Multi-Agent
#
# Before you start:
# - Make sure you have completed [](TUT000_setup.ipynb) through [](TUT003_variables.ipynb),
# as well as [](TUT101a_app-rllib-monoagent.ipynb).
#
# What you will learn in this chapter:
# - TODO

# %%
import numpy as _numpy_

from controllables.core.tools.gymnasium import BoxSpace, DictSpace
from controllables.core.tools.rllib import MultiAgentEnv
from controllables.energyplus import Actuator, OutputMeter
from controllables.energyplus import examples


class UserMultiAgentEnv(MultiAgentEnv):
    action_spaces = {
        space_key: DictSpace({
            'thermostat': BoxSpace(
                low=15., high=20.,
                dtype=_numpy_.float32,
                shape=(),
            ).bind(
                Actuator.Ref(
                    type='Zone Temperature Control',
                    control_type='Heating Setpoint',
                    key=ref_key,
                ) 
            ),
        })
        for space_key, ref_key in [
            ('zone_1-1', 'SPACE1-1'),
            ('zone_2-1', 'SPACE2-1'),
        ]
    }

    observation_spaces = {
        space_key: DictSpace({
            'energy-transfer': BoxSpace(
                low=-_numpy_.inf, high=+_numpy_.inf,
                dtype=_numpy_.float32,
                shape=(),
            ).bind(
                OutputMeter.Ref(
                    type=f'EnergyTransfer:Zone:{ref_key}',
                )
            ),
            'energy-consumption': BoxSpace(
                low=-_numpy_.inf, high=+_numpy_.inf,
                dtype=_numpy_.float32,
                shape=(),
            ).bind(
                OutputMeter.Ref(
                    type=f'Electricity:HVAC',
                )
            ),
        })
        for space_key, ref_key in [
            ('zone_1-1', 'SPACE1-1'),
            ('zone_2-1', 'SPACE2-1'),
        ]
    }

    rewards = {
        space_key: lambda agent: (
            agent.observation.value['energy-transfer'] 
            / agent.observation.value['energy-consumption']
        ) if agent.observation.value['energy-consumption'] != 0. else 0.
        for space_key in [
            'zone_1-1',
            'zone_2-1',
        ]
    }

    def __init__(self, config: dict = dict()):
        super().__init__({
            'action_spaces': self.__class__.action_spaces,
            'observation_spaces': self.__class__.observation_spaces,
            'rewards': self.__class__.rewards,
            **config,
        })

    def run(self):
        system = examples.systems.X5ZoneAirCooled(repeat=True)
        #system.add('logging:progress')
        # schedule a (recurring) episode associated with the system
        self.__attach__(system).schedule_episode()
        # run the system in background
        system.start()
        # wait for the system to finish to keep this env alive
        system.wait()

# %%
from ray.rllib.policy.policy import PolicySpec
from ray.rllib.algorithms.ppo import PPO, PPOConfig

algo = PPO(
    PPOConfig()
    .environment(UserMultiAgentEnv)
    .rollouts(
        # NOTE this env (an `ExternalEnv`) does not support connectors
        enable_connectors=False,
        # TODO for eval
        create_env_on_local_worker=True,
        # TODO rm
        #num_rollout_workers=0,
        #rollout_fragment_length=1_000,
    )
    .multi_agent(
        # TODO doc policy mapping
        policies={
            space_key: PolicySpec(
                action_space=UserMultiAgentEnv.action_spaces[space_key],
                observation_space=UserMultiAgentEnv.observation_spaces[space_key],
            )
            for space_key in ['zone_1-1', 'zone_2-1']
        },
        policy_mapping_fn=lambda agent_id, *args, **kwargs: str(agent_id),
    )
    # TODO
    .resources(num_gpus=1.)
)
# Out:
# 2024-10-05 18:08:33,530	WARNING deprecation.py:50 -- DeprecationWarning: `rollouts` has been deprecated. Use `AlgorithmConfig.env_runners(..)` instead. This will raise an error in the future!
# /home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:555: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2024-10-05 18:08:34,191	INFO worker.py:1786 -- Started a local Ray instance.
# (RolloutWorker pid=292217) /home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py:365: TemporaryUnavailableWarning: ("OutputMeter(OutputMeter.Ref(type='Electricity:HVAC'))", <function MultiAgentEnv.schedule_episode.<locals>._ at 0x7febe8dbf7e0>)
# (RolloutWorker pid=292217)   _warnings_.warn(e.warning(f))
# (RolloutWorker pid=292217) /home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/gymnasium/agent.py:309: UserWarning: Termination value function not defined: <controllables.core.tools.gymnasium.agent.Agent object at 0x7febeac75590> using default <controllables.core.variables.MutableVariable object at 0x7febe8deab50>
# (RolloutWorker pid=292217)   _warnings_.warn(
# (RolloutWorker pid=292217) /home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/gymnasium/agent.py:309: UserWarning: Termination value function not defined: <controllables.core.tools.gymnasium.agent.Agent object at 0x7febea9b3210> using default <controllables.core.variables.MutableVariable object at 0x7febe8de9590>
# (RolloutWorker pid=292217)   _warnings_.warn(
# 2024-10-05 18:08:37,291	WARNING util.py:61 -- Install gputil for GPU system monitoring.

# %%
for i in range(20):
    print(i, algo.train())
# Out:
# /home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py:365: TemporaryUnavailableWarning: ("OutputMeter(OutputMeter.Ref(type='Electricity:HVAC'))", <function MultiAgentEnv.schedule_episode.<locals>._ at 0x7f5a40046480>)
#   _warnings_.warn(e.warning(f))
# /home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/gymnasium/agent.py:309: UserWarning: Termination value function not defined: <controllables.core.tools.gymnasium.agent.Agent object at 0x7f6084bfb950> using default <controllables.core.variables.MutableVariable object at 0x7f5a406c7010>
#   _warnings_.warn(
# /home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/gymnasium/agent.py:309: UserWarning: Termination value function not defined: <controllables.core.tools.gymnasium.agent.Agent object at 0x7f6084c08d90> using default <controllables.core.variables.MutableVariable object at 0x7f5f181e8ed0>
#   _warnings_.warn(
# 2024-10-05 18:08:43,403	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# 0 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_2-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.2494422703360517, 'cur_kl_coeff': 0.20000000000000004, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.96875596344471, 'policy_loss': -0.004068968684684175, 'vf_loss': 9.97220127383868, 'vf_explained_var': -0.0020351000751058263, 'kl': 0.0031182732980596485, 'entropy': 1.4382414517303308, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 480.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}, 'zone_1-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.315661608427763, 'cur_kl_coeff': 0.20000000000000004, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.976139344771703, 'policy_loss': -0.0059144112446423, 'vf_loss': 9.981092673540115, 'vf_explained_var': 0.0003855065753062566, 'kl': 0.004805310630308668, 'entropy': 1.3991320552925268, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 480.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}}, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 290.149672552056, 'num_env_steps_trained_throughput_per_sec': 290.149672552056, 'timesteps_total': 4000, 'num_env_steps_sampled_lifetime': 4000, 'num_agent_steps_sampled_lifetime': 8000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 8000, 'timers': {'training_iteration_time_ms': 13786.004, 'restore_workers_time_ms': 0.013, 'training_step_time_ms': 13785.954, 'sample_time_ms': 6090.523, 'learn_time_ms': 7691.373, 'learn_throughput': 520.063, 'synch_weights_time_ms': 3.909}, 'counters': {'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000}, 'done': False, 'training_iteration': 1, 'trial_id': 'default', 'date': '2024-10-05_18-08-51', 'timestamp': 1728151731, 'time_this_iter_s': 13.78825855255127, 'time_total_s': 13.78825855255127, 'pid': 291897, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dynamo_mode': None, 'torch_ ...
# 1 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_2-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.0987908102882404, 'cur_kl_coeff': 0.10000000000000002, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.969664810101191, 'policy_loss': -0.006771953057129091, 'vf_loss': 9.975724191466968, 'vf_explained_var': -0.0009627447153131168, 'kl': 0.007125486933401959, 'entropy': 1.4374991709987321, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 1440.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}, 'zone_1-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.1997068895337482, 'cur_kl_coeff': 0.10000000000000002, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.990701053539912, 'policy_loss': -0.010413008462152599, 'vf_loss': 10.0, 'vf_explained_var': 0.00350502443810304, 'kl': 0.011140551840706022, 'entropy': 1.3933980292330186, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 1440.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}}, 'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_agent_steps_sampled': 16000, 'num_agent_steps_trained': 16000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 16000, 'num_agent_steps_trained': 16000, 'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 296.3300201742738, 'num_env_steps_trained_throughput_per_sec': 296.3300201742738, 'timesteps_total': 8000, 'num_env_steps_sampled_lifetime': 8000, 'num_agent_steps_sampled_lifetime': 16000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 16000, 'timers': {'training_iteration_time_ms': 13642.237, 'restore_workers_time_ms': 0.01, 'training_step_time_ms': 13642.199, 'sample_time_ms': 6028.516, 'learn_time_ms': 7609.672, 'learn_throughput': 525.647, 'synch_weights_time_ms': 3.869}, 'counters': {'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_agent_steps_sampled': 16000, 'num_agent_steps_trained': 16000}, 'done': False, 'training_iteration': 2, 'trial_id': 'default', 'date': '2024-10-05_18-09-04', 'timestamp': 1728151744, 'time_this_iter_s': 13.500623941421509, 'time_total_s': 27.28888249397278, 'pid': 291897, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dynamo_mode': None, 'torch ...
# 2 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_2-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.2325174346255758, 'cur_kl_coeff': 0.10000000000000002, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.966479518016179, 'policy_loss': -0.006435445646638982, 'vf_loss': 9.971989544232686, 'vf_explained_var': 0.0006480145578583082, 'kl': 0.009254617402727662, 'entropy': 1.396143155793349, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 2400.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}, 'zone_1-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.2950232979531089, 'cur_kl_coeff': 0.10000000000000002, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.96763159930706, 'policy_loss': -0.0032625091106941303, 'vf_loss': 9.97058074673017, 'vf_explained_var': 0.0019162607689698536, 'kl': 0.0031333762301647065, 'entropy': 1.3937869964788356, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 2400.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}}, 'num_env_steps_sampled': 12000, 'num_env_steps_trained': 12000, 'num_agent_steps_sampled': 24000, 'num_agent_steps_trained': 24000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 24000, 'num_agent_steps_trained': 24000, 'num_env_steps_sampled': 12000, 'num_env_steps_trained': 12000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 292.4938165124154, 'num_env_steps_trained_throughput_per_sec': 292.4938165124154, 'timesteps_total': 12000, 'num_env_steps_sampled_lifetime': 12000, 'num_agent_steps_sampled_lifetime': 24000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 24000, 'timers': {'training_iteration_time_ms': 13653.327, 'restore_workers_time_ms': 0.009, 'training_step_time_ms': 13653.294, 'sample_time_ms': 5998.883, 'learn_time_ms': 7650.594, 'learn_throughput': 522.835, 'synch_weights_time_ms': 3.681}, 'counters': {'num_env_steps_sampled': 12000, 'num_env_steps_trained': 12000, 'num_agent_steps_sampled': 24000, 'num_agent_steps_trained': 24000}, 'done': False, 'training_iteration': 3, 'trial_id': 'default', 'date': '2024-10-05_18-09-18', 'timestamp': 1728151758, 'time_this_iter_s': 13.677506685256958, 'time_total_s': 40.966389179229736, 'pid': 291897, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dyn ...
# 3 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_2-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.2529282262859245, 'cur_kl_coeff': 0.10000000000000002, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.963332320253054, 'policy_loss': -0.004386894374814195, 'vf_loss': 9.967127528786659, 'vf_explained_var': 0.003007714326183001, 'kl': 0.005917130440999095, 'entropy': 1.419663295770685, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 3360.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}, 'zone_1-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.2097586284391582, 'cur_kl_coeff': 0.05000000000000001, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.985879771908124, 'policy_loss': -0.004708949395959886, 'vf_loss': 9.99040792385737, 'vf_explained_var': 0.0012126465638478596, 'kl': 0.0036157456850775807, 'entropy': 1.3783342315504947, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 3360.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}}, 'num_env_steps_sampled': 16000, 'num_env_steps_trained': 16000, 'num_agent_steps_sampled': 32000, 'num_agent_steps_trained': 32000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 32000, 'num_agent_steps_trained': 32000, 'num_env_steps_sampled': 16000, 'num_env_steps_trained': 16000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 298.89379009959003, 'num_env_steps_trained_throughput_per_sec': 298.89379009959003, 'timesteps_total': 16000, 'num_env_steps_sampled_lifetime': 16000, 'num_agent_steps_sampled_lifetime': 32000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 32000, 'timers': {'training_iteration_time_ms': 13585.667, 'restore_workers_time_ms': 0.008, 'training_step_time_ms': 13585.637, 'sample_time_ms': 5952.065, 'learn_time_ms': 7629.83, 'learn_throughput': 524.258, 'synch_weights_time_ms': 3.611}, 'counters': {'num_env_steps_sampled': 16000, 'num_env_steps_trained': 16000, 'num_agent_steps_sampled': 32000, 'num_agent_steps_trained': 32000}, 'done': False, 'training_iteration': 4, 'trial_id': 'default', 'date': '2024-10-05_18-09-31', 'timestamp': 1728151771, 'time_this_iter_s': 13.38482117652893, 'time_total_s': 54.35121035575867, 'pid': 291897, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dynam ...
# 4 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_2-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.9161491158107917, 'cur_kl_coeff': 0.10000000000000002, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.329435423016548, 'policy_loss': -0.0021099936517809206, 'vf_loss': 9.331164687871933, 'vf_explained_var': 0.06335216462612152, 'kl': 0.0038074075828234324, 'entropy': 1.2133663612107435, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 4320.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}, 'zone_1-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.663041660686334, 'cur_kl_coeff': 0.025000000000000005, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.14405252536138, 'policy_loss': -0.003872658261389006, 'vf_loss': 9.147672232985496, 'vf_explained_var': 0.017393940004209678, 'kl': 0.01011828592237644, 'entropy': 1.3544903761396805, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 4320.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}}, 'num_env_steps_sampled': 20000, 'num_env_steps_trained': 20000, 'num_agent_steps_sampled': 40000, 'num_agent_steps_trained': 40000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 40000, 'num_agent_steps_trained': 40000, 'num_env_steps_sampled': 20000, 'num_env_steps_trained': 20000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 308.8646644153238, 'num_env_steps_trained_throughput_per_sec': 308.8646644153238, 'timesteps_total': 20000, 'num_env_steps_sampled_lifetime': 20000, 'num_agent_steps_sampled_lifetime': 40000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 40000, 'timers': {'training_iteration_time_ms': 13458.665, 'restore_workers_time_ms': 0.008, 'training_step_time_ms': 13458.638, 'sample_time_ms': 5857.904, 'learn_time_ms': 7597.082, 'learn_throughput': 526.518, 'synch_weights_time_ms': 3.526}, 'counters': {'num_env_steps_sampled': 20000, 'num_env_steps_trained': 20000, 'num_agent_steps_sampled': 40000, 'num_agent_steps_trained': 40000}, 'done': False, 'training_iteration': 5, 'trial_id': 'default', 'date': '2024-10-05_18-09-44', 'timestamp': 1728151784, 'time_this_iter_s': 12.952723979949951, 'time_total_s': 67.30393433570862, 'pid': 291897, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dynamo ...
# 5 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_2-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.8476123138951759, 'cur_kl_coeff': 0.05000000000000001, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 8.966693510115146, 'policy_loss': -0.0017028926464263349, 'vf_loss': 8.96814172019561, 'vf_explained_var': 0.08683216000596682, 'kl': 0.005094275822492023, 'entropy': 1.130085388571024, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 5280.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}, 'zone_1-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.3242346435474852, 'cur_kl_coeff': 0.025000000000000005, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 8.980468331774075, 'policy_loss': -0.006680637580575422, 'vf_loss': 8.986797891060512, 'vf_explained_var': 0.02690424385170142, 'kl': 0.014045710128083517, 'entropy': 1.3293458717564741, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 5280.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}}, 'num_env_steps_sampled': 24000, 'num_env_steps_trained': 24000, 'num_agent_steps_sampled': 48000, 'num_agent_steps_trained': 48000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 48000, 'num_agent_steps_trained': 48000, 'num_env_steps_sampled': 24000, 'num_env_steps_trained': 24000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 305.88710878104035, 'num_env_steps_trained_throughput_per_sec': 305.88710878104035, 'timesteps_total': 24000, 'num_env_steps_sampled_lifetime': 24000, 'num_agent_steps_sampled_lifetime': 48000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 48000, 'timers': {'training_iteration_time_ms': 13395.009, 'restore_workers_time_ms': 0.008, 'training_step_time_ms': 13394.982, 'sample_time_ms': 5786.336, 'learn_time_ms': 7605.03, 'learn_throughput': 525.968, 'synch_weights_time_ms': 3.493}, 'counters': {'num_env_steps_sampled': 24000, 'num_env_steps_trained': 24000, 'num_agent_steps_sampled': 48000, 'num_agent_steps_trained': 48000}, 'done': False, 'training_iteration': 6, 'trial_id': 'default', 'date': '2024-10-05_18-09-57', 'timestamp': 1728151797, 'time_this_iter_s': 13.0788733959198, 'time_total_s': 80.38280773162842, 'pid': 291897, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dynamo_m ...
# 6 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_2-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.655266512123247, 'cur_kl_coeff': 0.05000000000000001, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.01255579193433, 'policy_loss': 8.701057668076828e-05, 'vf_loss': 9.012288252015908, 'vf_explained_var': 0.07600036965062221, 'kl': 0.0036105846529191398, 'entropy': 1.122175121307373, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 6240.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}, 'zone_1-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.2826715533621609, 'cur_kl_coeff': 0.025000000000000005, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.035608476400375, 'policy_loss': -0.0033518765286620084, 'vf_loss': 9.03883451918761, 'vf_explained_var': 0.024691830637554327, 'kl': 0.00503383375152377, 'entropy': 1.3272951807826758, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 6240.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}}, 'num_env_steps_sampled': 28000, 'num_env_steps_trained': 28000, 'num_agent_steps_sampled': 56000, 'num_agent_steps_trained': 56000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 56000, 'num_agent_steps_trained': 56000, 'num_env_steps_sampled': 28000, 'num_env_steps_trained': 28000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 317.381077033016, 'num_env_steps_trained_throughput_per_sec': 317.381077033016, 'timesteps_total': 28000, 'num_env_steps_sampled_lifetime': 28000, 'num_agent_steps_sampled_lifetime': 56000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 56000, 'timers': {'training_iteration_time_ms': 13281.886, 'restore_workers_time_ms': 0.007, 'training_step_time_ms': 13281.861, 'sample_time_ms': 5699.874, 'learn_time_ms': 7578.412, 'learn_throughput': 527.815, 'synch_weights_time_ms': 3.453}, 'counters': {'num_env_steps_sampled': 28000, 'num_env_steps_trained': 28000, 'num_agent_steps_sampled': 56000, 'num_agent_steps_trained': 56000}, 'done': False, 'training_iteration': 7, 'trial_id': 'default', 'date': '2024-10-05_18-10-10', 'timestamp': 1728151810, 'time_this_iter_s': 12.605308771133423, 'time_total_s': 92.98811650276184, 'pid': 291897, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dynamo_mod ...
# 7 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_2-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.530352198223894, 'cur_kl_coeff': 0.025000000000000005, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.077334050337473, 'policy_loss': -0.004763889171105499, 'vf_loss': 9.081756127874057, 'vf_explained_var': 0.07499768932660421, 'kl': 0.01367277330980557, 'entropy': 1.0635404627149303, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 7200.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}, 'zone_1-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.315179908958574, 'cur_kl_coeff': 0.025000000000000005, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.111720590790112, 'policy_loss': -0.0016826794875669294, 'vf_loss': 9.113332904378574, 'vf_explained_var': 0.02198365336904923, 'kl': 0.00281377909022638, 'entropy': 1.3030494396885237, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 7200.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}}, 'num_env_steps_sampled': 32000, 'num_env_steps_trained': 32000, 'num_agent_steps_sampled': 64000, 'num_agent_steps_trained': 64000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 64000, 'num_agent_steps_trained': 64000, 'num_env_steps_sampled': 32000, 'num_env_steps_trained': 32000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 307.54819546490216, 'num_env_steps_trained_throughput_per_sec': 307.54819546490216, 'timesteps_total': 32000, 'num_env_steps_sampled_lifetime': 32000, 'num_agent_steps_sampled_lifetime': 64000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 64000, 'timers': {'training_iteration_time_ms': 13247.413, 'restore_workers_time_ms': 0.008, 'training_step_time_ms': 13247.388, 'sample_time_ms': 5662.47, 'learn_time_ms': 7581.352, 'learn_throughput': 527.61, 'synch_weights_time_ms': 3.446}, 'counters': {'num_env_steps_sampled': 32000, 'num_env_steps_trained': 32000, 'num_agent_steps_sampled': 64000, 'num_agent_steps_trained': 64000}, 'done': False, 'training_iteration': 8, 'trial_id': 'default', 'date': '2024-10-05_18-10-23', 'timestamp': 1728151823, 'time_this_iter_s': 13.008302450180054, 'time_total_s': 105.9964189529419, 'pid': 291897, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dynamo_m ...
# 8 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_2-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.5654943179960052, 'cur_kl_coeff': 0.025000000000000005, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.153859894474348, 'policy_loss': -0.0028984582638562034, 'vf_loss': 9.156555904944737, 'vf_explained_var': 0.07158157372226318, 'kl': 0.008097201566319736, 'entropy': 1.0877286208172638, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 8160.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}, 'zone_1-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.258104661044975, 'cur_kl_coeff': 0.012500000000000002, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.188743968804678, 'policy_loss': -0.002782871436405306, 'vf_loss': 9.191421873370807, 'vf_explained_var': 0.021812128399809203, 'kl': 0.008395118687064955, 'entropy': 1.2905117336660623, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 8160.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}}, 'num_env_steps_sampled': 36000, 'num_env_steps_trained': 36000, 'num_agent_steps_sampled': 72000, 'num_agent_steps_trained': 72000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 72000, 'num_agent_steps_trained': 72000, 'num_env_steps_sampled': 36000, 'num_env_steps_trained': 36000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 308.2257762864866, 'num_env_steps_trained_throughput_per_sec': 308.2257762864866, 'timesteps_total': 36000, 'num_env_steps_sampled_lifetime': 36000, 'num_agent_steps_sampled_lifetime': 72000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 72000, 'timers': {'training_iteration_time_ms': 13217.423, 'restore_workers_time_ms': 0.007, 'training_step_time_ms': 13217.399, 'sample_time_ms': 5638.153, 'learn_time_ms': 7575.677, 'learn_throughput': 528.006, 'synch_weights_time_ms': 3.45}, 'counters': {'num_env_steps_sampled': 36000, 'num_env_steps_trained': 36000, 'num_agent_steps_sampled': 72000, 'num_agent_steps_trained': 72000}, 'done': False, 'training_iteration': 9, 'trial_id': 'default', 'date': '2024-10-05_18-10-36', 'timestamp': 1728151836, 'time_this_iter_s': 12.979541301727295, 'time_total_s': 118.97596025466919, 'pid': 291897, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dyna ...
# 9 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_2-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.61745693947499, 'cur_kl_coeff': 0.025000000000000005, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.232125264406204, 'policy_loss': -0.0003977263021321657, 'vf_loss': 9.232419043779373, 'vf_explained_var': 0.07152188941836357, 'kl': 0.004157200992707053, 'entropy': 1.1277954634279013, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 9120.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}, 'zone_1-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.2414228717486064, 'cur_kl_coeff': 0.012500000000000002, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.268699509898822, 'policy_loss': -0.004684758961957414, 'vf_loss': 9.273175181945165, 'vf_explained_var': 0.021630555018782617, 'kl': 0.01672490037644631, 'entropy': 1.2356633791079124, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 9120.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}}, 'num_env_steps_sampled': 40000, 'num_env_steps_trained': 40000, 'num_agent_steps_sampled': 80000, 'num_agent_steps_trained': 80000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 80000, 'num_agent_steps_trained': 80000, 'num_env_steps_sampled': 40000, 'num_env_steps_trained': 40000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 307.06283564604234, 'num_env_steps_trained_throughput_per_sec': 307.06283564604234, 'timesteps_total': 40000, 'num_env_steps_sampled_lifetime': 40000, 'num_agent_steps_sampled_lifetime': 80000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 80000, 'timers': {'training_iteration_time_ms': 13198.346, 'restore_workers_time_ms': 0.007, 'training_step_time_ms': 13198.323, 'sample_time_ms': 5601.986, 'learn_time_ms': 7592.767, 'learn_throughput': 526.817, 'synch_weights_time_ms': 3.45}, 'counters': {'num_env_steps_sampled': 40000, 'num_env_steps_trained': 40000, 'num_agent_steps_sampled': 80000, 'num_agent_steps_trained': 80000}, 'done': False, 'training_iteration': 10, 'trial_id': 'default', 'date': '2024-10-05_18-10-49', 'timestamp': 1728151849, 'time_this_iter_s': 13.028852462768555, 'time_total_s': 132.00481271743774, 'pid': 291897, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_dyn ...
# 10 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_2-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.631301077424238, 'cur_kl_coeff': 0.012500000000000002, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.306907870372136, 'policy_loss': -0.0018395377788692712, 'vf_loss': 9.308634200692177, 'vf_explained_var': 0.06509446085741123, 'kl': 0.009052448090572337, 'entropy': 1.058024185958008, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 10080.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}, 'zone_1-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 1.4004124140987793, 'cur_kl_coeff': 0.012500000000000002, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.350535616278648, 'policy_loss': -0.003851256959994013, 'vf_loss': 9.354281306266785, 'vf_explained_var': 0.024350684011975925, 'kl': 0.008438214863908418, 'entropy': 1.23160635518531, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 10080.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}}, 'num_env_steps_sampled': 44000, 'num_env_steps_trained': 44000, 'num_agent_steps_sampled': 88000, 'num_agent_steps_trained': 88000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 88000, 'num_agent_steps_trained': 88000, 'num_env_steps_sampled': 44000, 'num_env_steps_trained': 44000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 309.51920259935963, 'num_env_steps_trained_throughput_per_sec': 309.51920259935963, 'timesteps_total': 44000, 'num_env_steps_sampled_lifetime': 44000, 'num_agent_steps_sampled_lifetime': 88000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 88000, 'timers': {'training_iteration_time_ms': 13112.073, 'restore_workers_time_ms': 0.006, 'training_step_time_ms': 13112.053, 'sample_time_ms': 5530.109, 'learn_time_ms': 7578.452, 'learn_throughput': 527.812, 'synch_weights_time_ms': 3.378}, 'counters': {'num_env_steps_sampled': 44000, 'num_env_steps_trained': 44000, 'num_agent_steps_sampled': 88000, 'num_agent_steps_trained': 88000}, 'done': False, 'training_iteration': 11, 'trial_id': 'default', 'date': '2024-10-05_18-11-02', 'timestamp': 1728151862, 'time_this_iter_s': 12.925422668457031, 'time_total_s': 144.93023538589478, 'pid': 291897, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False, 'torch_compile_learner_what_to_compile': <TorchCompileWhatToCompile.FORWARD_TRAIN: 'forward_train'>, 'torch_compile_learner_dynamo_backend': 'inductor', 'torch_compile_learner_dynamo_mode': None, 'torch_compile_worker': False, 'torch_compile_worker_dynamo_backend': 'onnxrt', 'torch_compile_worker_ ...
# ...
# 18 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_2-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 2.88145517980059, 'cur_kl_coeff': 0.012500000000000002, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.944193987051646, 'policy_loss': -0.005189415998271821, 'vf_loss': 9.949231830239295, 'vf_explained_var': -0.0006416700159509977, 'kl': 0.012128681301665757, 'entropy': 0.6591343451601763, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 17760.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}, 'zone_1-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 2.6902819824094575, 'cur_kl_coeff': 0.018749999999999996, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.9739109903574, 'policy_loss': -0.006422043135777737, 'vf_loss': 9.980132255951563, 'vf_explained_var': 0.00770159550011158, 'kl': 0.01070797757038995, 'entropy': 0.5206039378109077, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 17760.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}}, 'num_env_steps_sampled': 76000, 'num_env_steps_trained': 76000, 'num_agent_steps_sampled': 152000, 'num_agent_steps_trained': 152000}, 'env_runners': {'episode_reward_max': 72568.26065051211, 'episode_reward_min': 72222.46765236437, 'episode_reward_mean': 72395.36415143823, 'episode_len_mean': 35040.0, 'episode_media': {}, 'episodes_timesteps_total': 70080, 'policy_reward_min': {'zone_1-1': 43998.49218036745, 'zone_2-1': 28223.975471996928}, 'policy_reward_max': {'zone_1-1': 44294.522024703634, 'zone_2-1': 28273.738625808473}, 'policy_reward_mean': {'zone_1-1': 44146.50710253554, 'zone_2-1': 28248.8570489027}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [72568.26065051211, 72222.46765236437], 'episode_lengths': [35040, 35040], 'policy_zone_1-1_reward': [44294.522024703634, 43998.49218036745], 'policy_zone_2-1_reward': [28273.738625808473, 28223.975471996928]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.20243827385820554, 'mean_inference_ms': 1.1618434306707828, 'mean_action_processing_ms': 0.14814768398571637, 'mean_env_wait_ms': 1.297778023275347, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': 72568.26065051211, 'episode_return_min': 72222.46765236437, 'episode_return_mean': 72395.36415143823, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 152000, 'num_agent_steps_trained': 152000, 'num_env_steps_sampled': 76000, 'num_env_steps_trained': 76000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 305.65834876256235, 'num_env_steps_trained_throughput_per_sec': 305.65834876256235, 'timesteps_total': 76000, 'num_env_steps_sampled_lifetime': 76000, 'num_agent_steps_sampled_lifetime': 152000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 152000, 'timers': {'training_iteration_time_ms': 13274.724, 'restore_workers_time_ms': 0.006, 'training_step_time_ms': 13274.708, 'sample_time_ms': 5690.467, 'learn_time_ms': 7580.784, 'learn_throughput': 527.65, 'synch_weights_time_ms': 3.344}, 'counters': {'num_env_steps_sampled': 76000, 'num_env_steps_trained': 76000, 'num_agent_steps_sampled': 152000, 'num_agent_steps_trained': 152000}, 'done': False, 'training_iteration': 19, 'trial_id': 'default', 'date': '2024-10-05_18-12-49', 'timestamp': 1728151969, 'time_this_iter_s': 13.088821411132812, 'time_total_s': 251.7454333305359, 'pid': 291897, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'ea ...
# 19 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_2-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 3.434631601969401, 'cur_kl_coeff': 0.012500000000000002, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.966155435641607, 'policy_loss': -0.008094219368649647, 'vf_loss': 9.974071160952251, 'vf_explained_var': 0.0001290066788593928, 'kl': 0.01427908953804341, 'entropy': 0.5035209407409033, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 18720.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}, 'zone_1-1': {'learner_stats': {'allreduce_latency': 0.0, 'grad_gnorm': 2.4172426162908476, 'cur_kl_coeff': 0.018749999999999996, 'cur_lr': 5.0000000000000016e-05, 'total_loss': 9.995346726973851, 'policy_loss': -0.004813506110319092, 'vf_loss': 10.0, 'vf_explained_var': 0.01463090901573499, 'kl': 0.008546266369372325, 'entropy': 0.5482000633142888, 'entropy_coeff': 0.0}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': 125.0, 'num_grad_updates_lifetime': 18720.5, 'diff_num_grad_updates_vs_sampler_policy': 479.5}}, 'num_env_steps_sampled': 80000, 'num_env_steps_trained': 80000, 'num_agent_steps_sampled': 160000, 'num_agent_steps_trained': 160000}, 'env_runners': {'episode_reward_max': 72568.26065051211, 'episode_reward_min': 72222.46765236437, 'episode_reward_mean': 72395.36415143823, 'episode_len_mean': 35040.0, 'episode_media': {}, 'episodes_timesteps_total': 70080, 'policy_reward_min': {'zone_1-1': 43998.49218036745, 'zone_2-1': 28223.975471996928}, 'policy_reward_max': {'zone_1-1': 44294.522024703634, 'zone_2-1': 28273.738625808473}, 'policy_reward_mean': {'zone_1-1': 44146.50710253554, 'zone_2-1': 28248.8570489027}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [72568.26065051211, 72222.46765236437], 'episode_lengths': [35040, 35040], 'policy_zone_1-1_reward': [44294.522024703634, 43998.49218036745], 'policy_zone_2-1_reward': [28273.738625808473, 28223.975471996928]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.20243827385820554, 'mean_inference_ms': 1.1618434306707828, 'mean_action_processing_ms': 0.14814768398571637, 'mean_env_wait_ms': 1.297778023275347, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': 72568.26065051211, 'episode_return_min': 72222.46765236437, 'episode_return_mean': 72395.36415143823, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 160000, 'num_agent_steps_trained': 160000, 'num_env_steps_sampled': 80000, 'num_env_steps_trained': 80000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 289.9633111347848, 'num_env_steps_trained_throughput_per_sec': 289.9633111347848, 'timesteps_total': 80000, 'num_env_steps_sampled_lifetime': 80000, 'num_agent_steps_sampled_lifetime': 160000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 160000, 'timers': {'training_iteration_time_ms': 13351.544, 'restore_workers_time_ms': 0.006, 'training_step_time_ms': 13351.528, 'sample_time_ms': 5758.75, 'learn_time_ms': 7589.31, 'learn_throughput': 527.057, 'synch_weights_time_ms': 3.356}, 'counters': {'num_env_steps_sampled': 80000, 'num_env_steps_trained': 80000, 'num_agent_steps_sampled': 160000, 'num_agent_steps_trained': 160000}, 'done': False, 'training_iteration': 20, 'trial_id': 'default', 'date': '2024-10-05_18-13-02', 'timestamp': 1728151982, 'time_this_iter_s': 13.797001600265503, 'time_total_s': 265.5424349308014, 'pid': 291897, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retrac ...
# (RolloutWorker pid=292217) /home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py:365: TemporaryUnavailableWarning: ("OutputMeter(OutputMeter.Ref(type='Electricity:HVAC'))", <function MultiAgentEnv.schedule_episode.<locals>._ at 0x7febe8dbf7e0>)
# (RolloutWorker pid=292217)   _warnings_.warn(e.warning(f))
# (RolloutWorker pid=292217) Exception in thread Thread-3:
# (RolloutWorker pid=292217) Traceback (most recent call last):
# (RolloutWorker pid=292217)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/events.py", line 136, in cb_
# (RolloutWorker pid=292217)     return cb(*args, **kwargs)
# (RolloutWorker pid=292217)            ^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=292217)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/events.py", line 166, in _state
# (RolloutWorker pid=292217)     self._event.__call__(
# (RolloutWorker pid=292217)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/events.py", line 105, in __call__
# (RolloutWorker pid=292217)     return super().__call__(context)
# (RolloutWorker pid=292217)            ^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=292217)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/callbacks.py", line 414, in __call__
# (RolloutWorker pid=292217)     return self._callables.__call__(*args, **kwargs)
# (RolloutWorker pid=292217)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=292217)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/callables.py", line 81, in __call__
# (RolloutWorker pid=292217)     res[f] = f(*args, **kwargs)
# (RolloutWorker pid=292217)              ^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=292217)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 363, in f_wrapped
# (RolloutWorker pid=292217)     #     1. Call `episode_id = self.start_episode(episode_id?)`.
# (RolloutWorker pid=292217)                            ^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=292217)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 386, in _
# (RolloutWorker pid=292217)     #         self.step_episode(current_episode_id)
# (RolloutWorker pid=292217)                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=292217)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 296, in step_episode
# (RolloutWorker pid=292217)     except TemporaryUnavailableError as e:
# (RolloutWorker pid=292217)                             ^^^^^^^^^^^^^^^
# (RolloutWorker pid=292217)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 214, in get_action
# (RolloutWorker pid=292217)     if info_dict is None:
# (RolloutWorker pid=292217)            ^^^^^^^^^^^^^^
# (RolloutWorker pid=292217)   File "/home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/rllib/env/external_multi_agent_env.py", line 92, in get_action
# (RolloutWorker pid=292217)     return episode.wait_for_action(observation_dict)
# (RolloutWorker pid=292217)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=292217)   File "/home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 297, in wait_for_action
# (RolloutWorker pid=292217)     return self.action_queue.get(True, timeout=300.0)
# (RolloutWorker pid=292217)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=292217)   File "/usr/lib/python3.11/queue.py", line 179, in get
# (RolloutWorker pid=292217)     raise Empty
# (RolloutWorker pid=292217) _queue.Empty
# (RolloutWorker pid=292217)
# (RolloutWorker pid=292217) The above exception was the direct cause of the following exception:
# (RolloutWorker pid=292217)
# (RolloutWorker pid=292217) Traceback (most recent call last):
# (RolloutWorker pid=292217)   File "/usr/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
# (RolloutWorker pid=292217)     self.run()
# (RolloutWorker pid=292217)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/systems.py", line 97, in run
# (RolloutWorker pid=292217)     status = self._core.run(args=self._cli_args)
# (RolloutWorker pid=292217)              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=292217)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/_core/__init__.py", line 104, in run
# (RolloutWorker pid=292217)     self.hooks.__call__('run:post')
# (RolloutWorker pid=292217)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/callbacks.py", line 457, in __call__
# (RolloutWorker pid=292217)     return self[ref].__call__(*args, **kwargs)
# (RolloutWorker pid=292217)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=292217)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/callbacks.py", line 414, in __call__
# (RolloutWorker pid=292217)     return self._callables.__call__(*args, **kwargs)
# (RolloutWorker pid=292217)            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=292217)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/callables.py", line 81, in __call__
# (RolloutWorker pid=292217)     res[f] = f(*args, **kwargs)
# (RolloutWorker pid=292217)              ^^^^^^^^^^^^^^^^^^
# (RolloutWorker pid=292217)   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/events.py", line 141, in _raise_exc
# (RolloutWorker pid=292217)     raise Exception from __exc__
# (RolloutWorker pid=292217) Exception
# (RolloutWorker pid=292213)
# (RolloutWorker pid=292213)

# %%
# TODO evaluate plot
algo.evaluate()
# Out:
# {'env_runners': {'episode_reward_max': nan,
#   'episode_reward_min': nan,
#   'episode_reward_mean': nan,
#   'episode_len_mean': nan,
#   'episode_media': {},
#   'episodes_timesteps_total': 0,
#   'policy_reward_min': {},
#   'policy_reward_max': {},
#   'policy_reward_mean': {},
#   'custom_metrics': {},
#   'hist_stats': {'episode_reward': [], 'episode_lengths': []},
#   'sampler_perf': {},
#   'num_faulty_episodes': 0,
#   'connector_metrics': {},
#   'num_episodes': 0,
#   'episode_return_max': nan,
#   'episode_return_min': nan,
#   'episode_return_mean': nan,
#   'episodes_this_iter': 0},
#  'num_agent_steps_sampled_this_iter': 40000,
#  'num_env_steps_sampled_this_iter': 20000,
#  'timesteps_this_iter': 20000}
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/events.py", line 136, in cb_
#     return cb(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/events.py", line 166, in _state
#     self._event.__call__(
#   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/events.py", line 105, in __call__
#     return super().__call__(context)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/callbacks.py", line 414, in __call__
#     return self._callables.__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/callables.py", line 81, in __call__
#     res[f] = f(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 363, in f_wrapped
#     __all__ = [
#
#   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 386, in _
#   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 296, in step_episode
#
#   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/tools/rllib/env.py", line 214, in get_action
#     self.agents.__attach__(system)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/rllib/env/external_multi_agent_env.py", line 92, in get_action
#     return episode.wait_for_action(observation_dict)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/EnergyPlus-OOEP/.venv/lib/python3.11/site-packages/ray/rllib/env/external_env.py", line 297, in wait_for_action
#     return self.action_queue.get(True, timeout=300.0)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/queue.py", line 179, in get
#     raise Empty
# _queue.Empty
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/systems.py", line 97, in run
#     status = self._core.run(args=self._cli_args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/_core/__init__.py", line 104, in run
#     self.hooks.__call__('run:post')
#   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/callbacks.py", line 457, in __call__
#     return self[ref].__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/callbacks.py", line 414, in __call__
#     return self._callables.__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/core/callables.py", line 81, in __call__
#     res[f] = f(*args, **kwargs)
#              ^^^^^^^^^^^^^^^^^^
#   File "/home/AD/user/lab/EnergyPlus-OOEP/packages/controllables/energyplus/events.py", line 141, in _raise_exc
#     raise Exception from __exc__
# Exception
