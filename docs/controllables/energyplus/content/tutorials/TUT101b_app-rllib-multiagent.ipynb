# %% [markdown]
# # 📚 Case Study 101b: Reinforcement Learning Based Control, Multi-Agent
#
# Before you start:
# - Make sure you have completed [](TUT000_setup.ipynb) through [](TUT003_variables.ipynb),
# as well as [](TUT101a_app-rllib-monoagent.ipynb).
#
# What you will learn in this chapter:
# - TODO

# %%
import numpy as _numpy_

from controllables.core.tools.gymnasium import BoxSpace, DictSpace
from controllables.core.tools.rllib import MultiAgentEnv
from controllables.energyplus import Actuator, OutputMeter
from controllables.energyplus import examples


class UserMultiAgentEnv(MultiAgentEnv):
    action_spaces = {
        space_key: DictSpace({
            'thermostat': BoxSpace(
                low=15., high=20.,
                dtype=_numpy_.float32,
                shape=(),
            ).bind(
                Actuator.Ref(
                    type='Zone Temperature Control',
                    control_type='Heating Setpoint',
                    key=ref_key,
                ) 
            ),
        })
        for space_key, ref_key in [
            ('zone_1-1', 'SPACE1-1'),
            ('zone_2-1', 'SPACE2-1'),
        ]
    }

    observation_spaces = {
        space_key: DictSpace({
            'energy-transfer': BoxSpace(
                low=-_numpy_.inf, high=+_numpy_.inf,
                dtype=_numpy_.float32,
                shape=(),
            ).bind(
                lambda x: x[OutputMeter.Ref(
                    type=f'EnergyTransfer:Zone:{ref_key}',
                )].cast(_numpy_.array)
            ),
            'energy-consumption': BoxSpace(
                low=-_numpy_.inf, high=+_numpy_.inf,
                dtype=_numpy_.float32,
                shape=(),
            ).bind(
                lambda x: x[OutputMeter.Ref(
                    type=f'Electricity:HVAC',
                )].cast(_numpy_.array)
            ),
        })
        for space_key, ref_key in [
            ('zone_1-1', 'SPACE1-1'),
            ('zone_2-1', 'SPACE2-1'),
        ]
    }

    rewards = {
        space_key: lambda agent: (
            agent.observation.value['energy-transfer'] 
            / agent.observation.value['energy-consumption']
        ) if agent.observation.value['energy-consumption'] != 0. else 0.
        for space_key in [
            'zone_1-1',
            'zone_2-1',
        ]
    }

    def __init__(self, config: dict = dict()):
        super().__init__({
            'action_spaces': self.__class__.action_spaces,
            'observation_spaces': self.__class__.observation_spaces,
            'rewards': self.__class__.rewards,
            **config,
        })

    def run(self):
        system = examples.systems.X5ZoneAirCooled(repeat=True)
        #system.add('logging:progress')
        # schedule a (recurring) episode associated with the system
        self.__attach__(system).schedule_episode()
        # run the system in background
        system.start()
        # wait for the system to finish to keep this env alive
        system.wait()

# %%
from ray.rllib.policy.policy import PolicySpec
from ray.rllib.algorithms.ppo import PPO, PPOConfig

algo = PPO(
    PPOConfig()
    .environment(UserMultiAgentEnv)
    .rollouts(
        # NOTE this env (an `ExternalEnv`) does not support connectors
        enable_connectors=False,
        # TODO for eval
        create_env_on_local_worker=True,
        # TODO rm
        #num_rollout_workers=0,
        #rollout_fragment_length=1_000,
    )
    .multi_agent(
        # TODO doc policy mapping
        policies={
            space_key: PolicySpec(
                action_space=UserMultiAgentEnv.action_spaces[space_key],
                observation_space=UserMultiAgentEnv.observation_spaces[space_key],
            )
            for space_key in ['zone_1-1', 'zone_2-1']
        },
        policy_mapping_fn=lambda agent_id, *args, **kwargs: str(agent_id),
    )
    # TODO
    .resources(num_gpus=1.)
)
# Out:
# /home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/rllib/algorithms/algorithm.py:568: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# `UnifiedLogger` will be removed in Ray 2.7.
#   return UnifiedLogger(config, logdir, loggers=None)
# /home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `JsonLogger interface is deprecated in favor of the `ray.tune.json.JsonLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `CSVLogger interface is deprecated in favor of the `ray.tune.csv.CSVLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# /home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/ray/tune/logger/unified.py:53: RayDeprecationWarning: This API is deprecated and may be removed in future Ray releases. You could suppress this warning by setting env variable PYTHONWARNINGS="ignore::DeprecationWarning"
# The `TBXLogger interface is deprecated in favor of the `ray.tune.tensorboardx.TBXLoggerCallback` interface and will be removed in Ray 2.7.
#   self._loggers.append(cls(self.config, self.logdir, self.trial))
# 2025-01-22 14:58:54,811	WARNING util.py:61 -- Install gputil for GPU system monitoring.

# %%
for i in range(20):
    print(i, algo.train())
# Out:
# 2025-01-22 14:59:00,441	WARNING deprecation.py:50 -- DeprecationWarning: `_get_slice_indices` has been deprecated. This will raise an error in the future!
# 0 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_1-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.3372318), 'cur_kl_coeff': np.float64(0.20000000000000004), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.969870257377625), 'policy_loss': np.float64(-0.0033367656733995924), 'vf_loss': np.float64(9.972520725925763), 'vf_explained_var': np.float64(-0.0030253227179249127), 'kl': np.float64(0.0034315682342139554), 'entropy': np.float64(1.3916464991867543), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(480.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}, 'zone_2-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.221515), 'cur_kl_coeff': np.float64(0.20000000000000004), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.968686240911484), 'policy_loss': np.float64(-0.005029083588548626), 'vf_loss': np.float64(9.972913698355358), 'vf_explained_var': np.float64(-0.002993464469909668), 'kl': np.float64(0.00400816112519351), 'entropy': np.float64(1.4283462703227996), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(480.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}}, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000, 'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 295.8969670289978, 'num_env_steps_trained_throughput_per_sec': 295.8969670289978, 'timesteps_total': 4000, 'num_env_steps_sampled_lifetime': 4000, 'num_agent_steps_sampled_lifetime': 8000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 8000, 'timers': {'training_iteration_time_ms': 13518.226, 'restore_workers_time_ms': 0.013, 'training_step_time_ms': 13518.191, 'sample_time_ms': 5623.114, 'learn_time_ms': 7891.062, 'learn_throughput': 506.903, 'synch_weights_time_ms': 3.886}, 'counters': {'num_env_steps_sampled': 4000, 'num_env_steps_trained': 4000, 'num_agent_steps_sampled': 8000, 'num_agent_steps_trained': 8000}, 'done': False, 'training_iteration': 1, 'trial_id': 'default', 'date': '2025-01-22_14-59-08', 'timestamp': 1737557948, 'time_this_iter_s': 13.520742416381836, 'time_total_s': 13.520742416381836, 'pid': 33430, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': False,  ...
# 1 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_1-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.310004), 'cur_kl_coeff': np.float64(0.10000000000000002), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.969825939337413), 'policy_loss': np.float64(-0.005501065479863124), 'vf_loss': np.float64(9.9746857325236), 'vf_explained_var': np.float64(-0.0029460153232018153), 'kl': np.float64(0.006412884096276451), 'entropy': np.float64(1.3636899570624033), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(1440.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}, 'zone_2-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.2562398), 'cur_kl_coeff': np.float64(0.10000000000000002), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.968754083911579), 'policy_loss': np.float64(-0.005558676231885329), 'vf_loss': np.float64(9.973696345090866), 'vf_explained_var': np.float64(-0.0037705481673280397), 'kl': np.float64(0.006163936762203075), 'entropy': np.float64(1.4656992404411235), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(1440.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}}, 'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_agent_steps_sampled': 16000, 'num_agent_steps_trained': 16000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 16000, 'num_agent_steps_trained': 16000, 'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 308.67481336655675, 'num_env_steps_trained_throughput_per_sec': 308.67481336655675, 'timesteps_total': 8000, 'num_env_steps_sampled_lifetime': 8000, 'num_agent_steps_sampled_lifetime': 16000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 16000, 'timers': {'training_iteration_time_ms': 13238.426, 'restore_workers_time_ms': 0.009, 'training_step_time_ms': 13238.399, 'sample_time_ms': 5410.023, 'learn_time_ms': 7824.521, 'learn_throughput': 511.213, 'synch_weights_time_ms': 3.733}, 'counters': {'num_env_steps_sampled': 8000, 'num_env_steps_trained': 8000, 'num_agent_steps_sampled': 16000, 'num_agent_steps_trained': 16000}, 'done': False, 'training_iteration': 2, 'trial_id': 'default', 'date': '2025-01-22_14-59-21', 'timestamp': 1737557961, 'time_this_iter_s': 12.960707902908325, 'time_total_s': 26.48145031929016, 'pid': 33430, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner' ...
# 2 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_1-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.2585824), 'cur_kl_coeff': np.float64(0.10000000000000002), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.965542802214623), 'policy_loss': np.float64(-0.00573272534335653), 'vf_loss': np.float64(9.970354688167571), 'vf_explained_var': np.float64(-0.0015350500121712684), 'kl': np.float64(0.009208671223570993), 'entropy': np.float64(1.3317032042890786), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(2400.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}, 'zone_2-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.2181906), 'cur_kl_coeff': np.float64(0.10000000000000002), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.968027179439863), 'policy_loss': np.float64(-0.0021253588027320804), 'vf_loss': np.float64(9.96980073750019), 'vf_explained_var': np.float64(3.508422523736954e-05), 'kl': np.float64(0.0035180812666240524), 'entropy': np.float64(1.4829959078381458), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(2400.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}}, 'num_env_steps_sampled': 12000, 'num_env_steps_trained': 12000, 'num_agent_steps_sampled': 24000, 'num_agent_steps_trained': 24000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 24000, 'num_agent_steps_trained': 24000, 'num_env_steps_sampled': 12000, 'num_env_steps_trained': 12000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 313.11235590918943, 'num_env_steps_trained_throughput_per_sec': 313.11235590918943, 'timesteps_total': 12000, 'num_env_steps_sampled_lifetime': 12000, 'num_agent_steps_sampled_lifetime': 24000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 24000, 'timers': {'training_iteration_time_ms': 13083.941, 'restore_workers_time_ms': 0.008, 'training_step_time_ms': 13083.913, 'sample_time_ms': 5354.632, 'learn_time_ms': 7725.578, 'learn_throughput': 517.761, 'synch_weights_time_ms': 3.582}, 'counters': {'num_env_steps_sampled': 12000, 'num_env_steps_trained': 12000, 'num_agent_steps_sampled': 24000, 'num_agent_steps_trained': 24000}, 'done': False, 'training_iteration': 3, 'trial_id': 'default', 'date': '2025-01-22_14-59-34', 'timestamp': 1737557974, 'time_this_iter_s': 12.777112245559692, 'time_total_s': 39.25856256484985, 'pid': 33430, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compil ...
# 3 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_1-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.2915785), 'cur_kl_coeff': np.float64(0.10000000000000002), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.964653317133585), 'policy_loss': np.float64(-0.006766153855035858), 'vf_loss': np.float64(9.970651979247728), 'vf_explained_var': np.float64(0.0040873723104596135), 'kl': np.float64(0.007675188223950617), 'entropy': np.float64(1.3392530579119921), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(3360.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}, 'zone_2-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.0466858), 'cur_kl_coeff': np.float64(0.05000000000000001), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.966815408070882), 'policy_loss': np.float64(-0.004821480703928197), 'vf_loss': np.float64(9.97124476234118), 'vf_explained_var': np.float64(0.005940925019482772), 'kl': np.float64(0.007842022419404298), 'entropy': np.float64(1.4902417985101541), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(3360.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}}, 'num_env_steps_sampled': 16000, 'num_env_steps_trained': 16000, 'num_agent_steps_sampled': 32000, 'num_agent_steps_trained': 32000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 32000, 'num_agent_steps_trained': 32000, 'num_env_steps_sampled': 16000, 'num_env_steps_trained': 16000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 316.8116644712142, 'num_env_steps_trained_throughput_per_sec': 316.8116644712142, 'timesteps_total': 16000, 'num_env_steps_sampled_lifetime': 16000, 'num_agent_steps_sampled_lifetime': 32000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 32000, 'timers': {'training_iteration_time_ms': 12969.407, 'restore_workers_time_ms': 0.008, 'training_step_time_ms': 12969.38, 'sample_time_ms': 5295.234, 'learn_time_ms': 7670.538, 'learn_throughput': 521.476, 'synch_weights_time_ms': 3.492}, 'counters': {'num_env_steps_sampled': 16000, 'num_env_steps_trained': 16000, 'num_agent_steps_sampled': 32000, 'num_agent_steps_trained': 32000}, 'done': False, 'training_iteration': 4, 'trial_id': 'default', 'date': '2025-01-22_14-59-46', 'timestamp': 1737557986, 'time_this_iter_s': 12.627860307693481, 'time_total_s': 51.886422872543335, 'pid': 33430, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_lea ...
# 4 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_1-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.774526), 'cur_kl_coeff': np.float64(0.10000000000000002), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.297461041808129), 'policy_loss': np.float64(-0.006211731189978309), 'vf_loss': np.float64(9.302649927139282), 'vf_explained_var': np.float64(0.0688837114100655), 'kl': np.float64(0.010228990148859893), 'entropy': np.float64(1.2450900436689456), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(4320.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}, 'zone_2-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.6345395), 'cur_kl_coeff': np.float64(0.05000000000000001), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.286329690615336), 'policy_loss': np.float64(-0.00187136929986688), 'vf_loss': np.float64(9.287970491250356), 'vf_explained_var': np.float64(0.06399296522140503), 'kl': np.float64(0.0046114648894652315), 'entropy': np.float64(1.4046697987864414), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(4320.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}}, 'num_env_steps_sampled': 20000, 'num_env_steps_trained': 20000, 'num_agent_steps_sampled': 40000, 'num_agent_steps_trained': 40000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 40000, 'num_agent_steps_trained': 40000, 'num_env_steps_sampled': 20000, 'num_env_steps_trained': 20000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 318.12064848524795, 'num_env_steps_trained_throughput_per_sec': 318.12064848524795, 'timesteps_total': 20000, 'num_env_steps_sampled_lifetime': 20000, 'num_agent_steps_sampled_lifetime': 40000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 40000, 'timers': {'training_iteration_time_ms': 12890.296, 'restore_workers_time_ms': 0.007, 'training_step_time_ms': 12890.27, 'sample_time_ms': 5225.65, 'learn_time_ms': 7660.892, 'learn_throughput': 522.132, 'synch_weights_time_ms': 3.609}, 'counters': {'num_env_steps_sampled': 20000, 'num_env_steps_trained': 20000, 'num_agent_steps_sampled': 40000, 'num_agent_steps_trained': 40000}, 'done': False, 'training_iteration': 5, 'trial_id': 'default', 'date': '2025-01-22_14-59-59', 'timestamp': 1737557999, 'time_this_iter_s': 12.575777530670166, 'time_total_s': 64.4622004032135, 'pid': 33430, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner' ...
# 5 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_1-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.5489328), 'cur_kl_coeff': np.float64(0.10000000000000002), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(8.95920299788316), 'policy_loss': np.float64(-0.003962777704873588), 'vf_loss': np.float64(8.96243423173825), 'vf_explained_var': np.float64(0.09409020965298016), 'kl': np.float64(0.007315513508771692), 'entropy': np.float64(1.15786811063687), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(5280.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}, 'zone_2-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.4543992), 'cur_kl_coeff': np.float64(0.025000000000000005), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(8.952030749619007), 'policy_loss': np.float64(-0.002570769489102531), 'vf_loss': np.float64(8.954402963320414), 'vf_explained_var': np.float64(0.09170573937396208), 'kl': np.float64(0.007941381575144154), 'entropy': np.float64(1.3654219267268977), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(5280.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}}, 'num_env_steps_sampled': 24000, 'num_env_steps_trained': 24000, 'num_agent_steps_sampled': 48000, 'num_agent_steps_trained': 48000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 48000, 'num_agent_steps_trained': 48000, 'num_env_steps_sampled': 24000, 'num_env_steps_trained': 24000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 334.032116524639, 'num_env_steps_trained_throughput_per_sec': 334.032116524639, 'timesteps_total': 24000, 'num_env_steps_sampled_lifetime': 24000, 'num_agent_steps_sampled_lifetime': 48000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 48000, 'timers': {'training_iteration_time_ms': 12737.73, 'restore_workers_time_ms': 0.008, 'training_step_time_ms': 12737.704, 'sample_time_ms': 5144.964, 'learn_time_ms': 7589.1, 'learn_throughput': 527.072, 'synch_weights_time_ms': 3.523}, 'counters': {'num_env_steps_sampled': 24000, 'num_env_steps_trained': 24000, 'num_agent_steps_sampled': 48000, 'num_agent_steps_trained': 48000}, 'done': False, 'training_iteration': 6, 'trial_id': 'default', 'date': '2025-01-22_15-00-11', 'timestamp': 1737558011, 'time_this_iter_s': 11.97691035270691, 'time_total_s': 76.43911075592041, 'pid': 33430, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learner': Fals ...
# 6 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_1-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.5784439), 'cur_kl_coeff': np.float64(0.10000000000000002), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.003285376230876), 'policy_loss': np.float64(-0.003941298236410754), 'vf_loss': np.float64(9.006360906362534), 'vf_explained_var': np.float64(0.08167963605374098), 'kl': np.float64(0.008657826989575314), 'entropy': np.float64(1.1240399908274412), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(6240.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}, 'zone_2-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.3150214), 'cur_kl_coeff': np.float64(0.025000000000000005), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.004195812344552), 'policy_loss': np.float64(-0.000809325083779792), 'vf_loss': np.float64(9.004864736894767), 'vf_explained_var': np.float64(0.08139208269615968), 'kl': np.float64(0.005615534116623167), 'entropy': np.float64(1.3631301214297613), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(6240.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}}, 'num_env_steps_sampled': 28000, 'num_env_steps_trained': 28000, 'num_agent_steps_sampled': 56000, 'num_agent_steps_trained': 56000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 56000, 'num_agent_steps_trained': 56000, 'num_env_steps_sampled': 28000, 'num_env_steps_trained': 28000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 325.0898466468413, 'num_env_steps_trained_throughput_per_sec': 325.0898466468413, 'timesteps_total': 28000, 'num_env_steps_sampled_lifetime': 28000, 'num_agent_steps_sampled_lifetime': 56000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 56000, 'timers': {'training_iteration_time_ms': 12675.811, 'restore_workers_time_ms': 0.008, 'training_step_time_ms': 12675.786, 'sample_time_ms': 5090.844, 'learn_time_ms': 7581.358, 'learn_throughput': 527.61, 'synch_weights_time_ms': 3.469}, 'counters': {'num_env_steps_sampled': 28000, 'num_env_steps_trained': 28000, 'num_agent_steps_sampled': 56000, 'num_agent_steps_trained': 56000}, 'done': False, 'training_iteration': 7, 'trial_id': 'default', 'date': '2025-01-22_15-00-23', 'timestamp': 1737558023, 'time_this_iter_s': 12.306258201599121, 'time_total_s': 88.74536895751953, 'pid': 33430, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_learn ...
# 7 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_1-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.5533099), 'cur_kl_coeff': np.float64(0.10000000000000002), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.07749184370041), 'policy_loss': np.float64(-0.0007081798151678717), 'vf_loss': np.float64(9.07785318493843), 'vf_explained_var': np.float64(0.07821915758152803), 'kl': np.float64(0.0034683023904335687), 'entropy': np.float64(1.0946787143747012), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(7200.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}, 'zone_2-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.2470945), 'cur_kl_coeff': np.float64(0.025000000000000005), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.073344598710538), 'policy_loss': np.float64(-0.0002785127542059248), 'vf_loss': np.float64(9.07348516434431), 'vf_explained_var': np.float64(0.07760593040535847), 'kl': np.float64(0.005518697773365015), 'entropy': np.float64(1.349181299780806), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(7200.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}}, 'num_env_steps_sampled': 32000, 'num_env_steps_trained': 32000, 'num_agent_steps_sampled': 64000, 'num_agent_steps_trained': 64000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 64000, 'num_agent_steps_trained': 64000, 'num_env_steps_sampled': 32000, 'num_env_steps_trained': 32000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 325.23536709279637, 'num_env_steps_trained_throughput_per_sec': 325.23536709279637, 'timesteps_total': 32000, 'num_env_steps_sampled_lifetime': 32000, 'num_agent_steps_sampled_lifetime': 64000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 64000, 'timers': {'training_iteration_time_ms': 12628.683, 'restore_workers_time_ms': 0.008, 'training_step_time_ms': 12628.659, 'sample_time_ms': 5040.096, 'learn_time_ms': 7585.002, 'learn_throughput': 527.356, 'synch_weights_time_ms': 3.448}, 'counters': {'num_env_steps_sampled': 32000, 'num_env_steps_trained': 32000, 'num_agent_steps_sampled': 64000, 'num_agent_steps_trained': 64000}, 'done': False, 'training_iteration': 8, 'trial_id': 'default', 'date': '2025-01-22_15-00-35', 'timestamp': 1737558035, 'time_this_iter_s': 12.30088186264038, 'time_total_s': 101.04625082015991, 'pid': 33430, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_lea ...
# 8 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_1-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.5076736), 'cur_kl_coeff': np.float64(0.05000000000000001), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.149229173858961), 'policy_loss': np.float64(-0.0055050451696539915), 'vf_loss': np.float64(9.15430777768294), 'vf_explained_var': np.float64(0.07461342532187701), 'kl': np.float64(0.008528861751157756), 'entropy': np.float64(1.094644009321928), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(8160.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}, 'zone_2-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.2234299), 'cur_kl_coeff': np.float64(0.025000000000000005), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.155180071791014), 'policy_loss': np.float64(-0.0027950008331875625), 'vf_loss': np.float64(9.157840476433437), 'vf_explained_var': np.float64(0.07320452195902666), 'kl': np.float64(0.005384214057403371), 'entropy': np.float64(1.3645476539929708), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(8160.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}}, 'num_env_steps_sampled': 36000, 'num_env_steps_trained': 36000, 'num_agent_steps_sampled': 72000, 'num_agent_steps_trained': 72000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 72000, 'num_agent_steps_trained': 72000, 'num_env_steps_sampled': 36000, 'num_env_steps_trained': 36000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 330.81613045546527, 'num_env_steps_trained_throughput_per_sec': 330.81613045546527, 'timesteps_total': 36000, 'num_env_steps_sampled_lifetime': 36000, 'num_agent_steps_sampled_lifetime': 72000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 72000, 'timers': {'training_iteration_time_ms': 12568.976, 'restore_workers_time_ms': 0.007, 'training_step_time_ms': 12568.953, 'sample_time_ms': 4993.299, 'learn_time_ms': 7572.104, 'learn_throughput': 528.255, 'synch_weights_time_ms': 3.438}, 'counters': {'num_env_steps_sampled': 36000, 'num_env_steps_trained': 36000, 'num_agent_steps_sampled': 72000, 'num_agent_steps_trained': 72000}, 'done': False, 'training_iteration': 9, 'trial_id': 'default', 'date': '2025-01-22_15-00-48', 'timestamp': 1737558048, 'time_this_iter_s': 12.093578577041626, 'time_total_s': 113.13982939720154, 'pid': 33430, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_l ...
# 9 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_1-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.5656675), 'cur_kl_coeff': np.float64(0.05000000000000001), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.230896401405335), 'policy_loss': np.float64(-0.0025236795816454107), 'vf_loss': np.float64(9.233143051465353), 'vf_explained_var': np.float64(0.07288440900544325), 'kl': np.float64(0.005540491453196714), 'entropy': np.float64(1.0943300611029068), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(9120.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}, 'zone_2-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.1924437), 'cur_kl_coeff': np.float64(0.025000000000000005), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.232628109057744), 'policy_loss': np.float64(-0.0012459296636128177), 'vf_loss': np.float64(9.233753533164661), 'vf_explained_var': np.float64(0.07198766258855661), 'kl': np.float64(0.00482022552377591), 'entropy': np.float64(1.3716865813980499), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(9120.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}}, 'num_env_steps_sampled': 40000, 'num_env_steps_trained': 40000, 'num_agent_steps_sampled': 80000, 'num_agent_steps_trained': 80000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 80000, 'num_agent_steps_trained': 80000, 'num_env_steps_sampled': 40000, 'num_env_steps_trained': 40000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 330.0347073933865, 'num_env_steps_trained_throughput_per_sec': 330.0347073933865, 'timesteps_total': 40000, 'num_env_steps_sampled_lifetime': 40000, 'num_agent_steps_sampled_lifetime': 80000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 80000, 'timers': {'training_iteration_time_ms': 12524.072, 'restore_workers_time_ms': 0.007, 'training_step_time_ms': 12524.05, 'sample_time_ms': 4968.107, 'learn_time_ms': 7552.404, 'learn_throughput': 529.633, 'synch_weights_time_ms': 3.428}, 'counters': {'num_env_steps_sampled': 40000, 'num_env_steps_trained': 40000, 'num_agent_steps_sampled': 80000, 'num_agent_steps_trained': 80000}, 'done': False, 'training_iteration': 10, 'trial_id': 'default', 'date': '2025-01-22_15-01-00', 'timestamp': 1737558060, 'time_this_iter_s': 12.12198519706726, 'time_total_s': 125.2618145942688, 'pid': 33430, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compile_lear ...
# 10 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_1-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.4406863), 'cur_kl_coeff': np.float64(0.05000000000000001), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.307626098394394), 'policy_loss': np.float64(-0.0032259316013854306), 'vf_loss': np.float64(9.310456812381744), 'vf_explained_var': np.float64(0.06608698908239603), 'kl': np.float64(0.007904653154958656), 'entropy': np.float64(1.0662562049925328), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(10080.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}, 'zone_2-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.2782303), 'cur_kl_coeff': np.float64(0.012500000000000002), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.308739445606868), 'policy_loss': np.float64(-0.00351508528207584), 'vf_loss': np.float64(9.312159556150437), 'vf_explained_var': np.float64(0.06429239325225353), 'kl': np.float64(0.007596279989178359), 'entropy': np.float64(1.3320684837798278), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(10080.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}}, 'num_env_steps_sampled': 44000, 'num_env_steps_trained': 44000, 'num_agent_steps_sampled': 88000, 'num_agent_steps_trained': 88000}, 'env_runners': {'episode_reward_max': nan, 'episode_reward_min': nan, 'episode_reward_mean': nan, 'episode_len_mean': nan, 'episode_media': {}, 'episodes_timesteps_total': 0, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [], 'episode_lengths': []}, 'sampler_perf': {}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': nan, 'episode_return_min': nan, 'episode_return_mean': nan, 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 88000, 'num_agent_steps_trained': 88000, 'num_env_steps_sampled': 44000, 'num_env_steps_trained': 44000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 326.16903468778673, 'num_env_steps_trained_throughput_per_sec': 326.16903468778673, 'timesteps_total': 44000, 'num_env_steps_sampled_lifetime': 44000, 'num_agent_steps_sampled_lifetime': 88000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 88000, 'timers': {'training_iteration_time_ms': 12398.608, 'restore_workers_time_ms': 0.006, 'training_step_time_ms': 12398.588, 'sample_time_ms': 4879.025, 'learn_time_ms': 7516.097, 'learn_throughput': 532.191, 'synch_weights_time_ms': 3.358}, 'counters': {'num_env_steps_sampled': 44000, 'num_env_steps_trained': 44000, 'num_agent_steps_sampled': 88000, 'num_agent_steps_trained': 88000}, 'done': False, 'training_iteration': 11, 'trial_id': 'default', 'date': '2025-01-22_15-01-12', 'timestamp': 1737558072, 'time_this_iter_s': 12.265622854232788, 'time_total_s': 137.5274374485016, 'pid': 33430, 'hostname': 'hvaclab-srv.ad.hvaiclab.internal', 'node_ip': '192.168.200.249', 'config': {'extra_python_environs_for_driver': {}, 'extra_python_environs_for_worker': {}, 'placement_strategy': 'PACK', 'num_gpus': 1.0, '_fake_gpus': False, 'num_cpus_for_main_process': 1, 'eager_tracing': True, 'eager_max_retraces': 20, 'tf_session_args': {'intra_op_parallelism_threads': 2, 'inter_op_parallelism_threads': 2, 'gpu_options': {'allow_growth': True}, 'log_device_placement': False, 'device_count': {'CPU': 1}, 'allow_soft_placement': True}, 'local_tf_session_args': {'intra_op_parallelism_threads': 8, 'inter_op_parallelism_threads': 8}, 'torch_compil ...
# ...
# 17 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_1-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.7309067), 'cur_kl_coeff': np.float64(0.025000000000000005), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.876608952879906), 'policy_loss': np.float64(-0.0038701342535205187), 'vf_loss': np.float64(9.88033252954483), 'vf_explained_var': np.float64(-0.0015552465493480364), 'kl': np.float64(0.005861768176112996), 'entropy': np.float64(1.021134726020197), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(16800.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}, 'zone_2-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(2.058169), 'cur_kl_coeff': np.float64(0.006250000000000001), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.877201381325722), 'policy_loss': np.float64(-0.00520330383151304), 'vf_loss': np.float64(9.882355544964472), 'vf_explained_var': np.float64(-0.0013617648432652156), 'kl': np.float64(0.007863971870491104), 'entropy': np.float64(0.7661300389096141), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(16800.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}}, 'num_env_steps_sampled': 72000, 'num_env_steps_trained': 72000, 'num_agent_steps_sampled': 144000, 'num_agent_steps_trained': 144000}, 'env_runners': {'episode_reward_max': np.float64(57268.07736125308), 'episode_reward_min': np.float64(57003.695631187235), 'episode_reward_mean': np.float64(57135.88649622016), 'episode_len_mean': np.float64(35040.0), 'episode_media': {}, 'episodes_timesteps_total': 70080, 'policy_reward_min': {'zone_1-1': np.float64(28501.847815593595), 'zone_2-1': np.float64(28501.847815593595)}, 'policy_reward_max': {'zone_1-1': np.float64(28634.038680626625), 'zone_2-1': np.float64(28634.038680626625)}, 'policy_reward_mean': {'zone_1-1': np.float64(28567.94324811011), 'zone_2-1': np.float64(28567.94324811011)}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [np.float64(57268.07736125308), np.float64(57003.695631187235)], 'episode_lengths': [35040, 35040], 'policy_zone_1-1_reward': [np.float64(28634.038680626625), np.float64(28501.847815593595)], 'policy_zone_2-1_reward': [np.float64(28634.038680626625), np.float64(28501.847815593595)]}, 'sampler_perf': {'mean_raw_obs_processing_ms': np.float64(0.18961373239575172), 'mean_inference_ms': np.float64(1.1084501984768276), 'mean_action_processing_ms': np.float64(0.14140419705458057), 'mean_env_wait_ms': np.float64(1.0479125742925273), 'mean_env_render_ms': np.float64(0.0)}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 2, 'episode_return_max': np.float64(57268.07736125308), 'episode_return_min': np.float64(57003.695631187235), 'episode_return_mean': np.float64(57135.88649622016), 'episodes_this_iter': 2}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 144000, 'num_agent_steps_trained': 144000, 'num_env_steps_sampled': 72000, 'num_env_steps_trained': 72000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 312.9892154151463, 'num_env_steps_trained_throughput_per_sec': 312.9892154151463, 'timesteps_total': 72000, 'num_env_steps_sampled_lifetime': 72000, 'num_agent_steps_sampled_lifetime': 144000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 144000, 'timers': {'training_iteration_time_ms': 12497.874, 'restore_workers_time_ms': 0.005, 'training_step_time_ms': 12497.858, 'sample_time_ms': 4979.624, 'learn_time_ms': 7514.77, 'learn_throughput': 532.285, 'synch_weights_time_ms': 3.361}, 'counters': {'num_env_steps_sampled': ...
# 18 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_1-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.737715), 'cur_kl_coeff': np.float64(0.025000000000000005), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.935456310709318), 'policy_loss': np.float64(-0.006401500594802201), 'vf_loss': np.float64(9.941558514038721), 'vf_explained_var': np.float64(0.00024394368131955464), 'kl': np.float64(0.011972389294063164), 'entropy': np.float64(0.9778959469869732), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(17760.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}, 'zone_2-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.9777219), 'cur_kl_coeff': np.float64(0.006250000000000001), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.929617672165234), 'policy_loss': np.float64(-0.012514508684398606), 'vf_loss': np.float64(9.942017461856206), 'vf_explained_var': np.float64(7.657334208488465e-07), 'kl': np.float64(0.018356465456251202), 'entropy': np.float64(0.6748020156597098), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(17760.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}}, 'num_env_steps_sampled': 76000, 'num_env_steps_trained': 76000, 'num_agent_steps_sampled': 152000, 'num_agent_steps_trained': 152000}, 'env_runners': {'episode_reward_max': np.float64(57268.07736125308), 'episode_reward_min': np.float64(57003.695631187235), 'episode_reward_mean': np.float64(57135.88649622016), 'episode_len_mean': np.float64(35040.0), 'episode_media': {}, 'episodes_timesteps_total': 70080, 'policy_reward_min': {'zone_1-1': np.float64(28501.847815593595), 'zone_2-1': np.float64(28501.847815593595)}, 'policy_reward_max': {'zone_1-1': np.float64(28634.038680626625), 'zone_2-1': np.float64(28634.038680626625)}, 'policy_reward_mean': {'zone_1-1': np.float64(28567.94324811011), 'zone_2-1': np.float64(28567.94324811011)}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [np.float64(57268.07736125308), np.float64(57003.695631187235)], 'episode_lengths': [35040, 35040], 'policy_zone_1-1_reward': [np.float64(28634.038680626625), np.float64(28501.847815593595)], 'policy_zone_2-1_reward': [np.float64(28634.038680626625), np.float64(28501.847815593595)]}, 'sampler_perf': {'mean_raw_obs_processing_ms': np.float64(0.18961373239575172), 'mean_inference_ms': np.float64(1.1084501984768276), 'mean_action_processing_ms': np.float64(0.14140419705458057), 'mean_env_wait_ms': np.float64(1.0479125742925273), 'mean_env_render_ms': np.float64(0.0)}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': np.float64(57268.07736125308), 'episode_return_min': np.float64(57003.695631187235), 'episode_return_mean': np.float64(57135.88649622016), 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 152000, 'num_agent_steps_trained': 152000, 'num_env_steps_sampled': 76000, 'num_env_steps_trained': 76000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 315.2554087441295, 'num_env_steps_trained_throughput_per_sec': 315.2554087441295, 'timesteps_total': 76000, 'num_env_steps_sampled_lifetime': 76000, 'num_agent_steps_sampled_lifetime': 152000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 152000, 'timers': {'training_iteration_time_ms': 12557.555, 'restore_workers_time_ms': 0.005, 'training_step_time_ms': 12557.54, 'sample_time_ms': 5052.318, 'learn_time_ms': 7501.762, 'learn_throughput': 533.208, 'synch_weights_time_ms': 3.357}, 'counters': {'num_env_steps_sampled' ...
# /home/AD/user/lab/controllables-core/packages/controllables/core/tools/rllib/env.py:104: RuntimeWarning: Episode 'c978cb9be9944fc29ad2b8dd8b6b317b' @ 'step':
#   _warnings_.warn(RuntimeWarning(spec.message))
# 19 {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'zone_1-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(1.7174817), 'cur_kl_coeff': np.float64(0.025000000000000005), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.969602938493093), 'policy_loss': np.float64(-0.0035884468161384575), 'vf_loss': np.float64(9.973036576310793), 'vf_explained_var': np.float64(-0.005631253619988759), 'kl': np.float64(0.006192493883015976), 'entropy': np.float64(0.9751135553543766), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(18720.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}, 'zone_2-1': {'learner_stats': {'allreduce_latency': np.float64(0.0), 'grad_gnorm': np.float32(2.1821375), 'cur_kl_coeff': np.float64(0.006250000000000001), 'cur_lr': np.float64(5.0000000000000016e-05), 'total_loss': np.float64(9.966970399022102), 'policy_loss': np.float64(-0.0065989897712521875), 'vf_loss': np.float64(9.973498598734539), 'vf_explained_var': np.float64(-0.007496593830486138), 'kl': np.float64(0.011326012079037684), 'entropy': np.float64(0.6100241384158532), 'entropy_coeff': np.float64(0.0)}, 'model': {}, 'custom_metrics': {}, 'num_agent_steps_trained': np.float64(125.0), 'num_grad_updates_lifetime': np.float64(18720.5), 'diff_num_grad_updates_vs_sampler_policy': np.float64(479.5)}}, 'num_env_steps_sampled': 80000, 'num_env_steps_trained': 80000, 'num_agent_steps_sampled': 160000, 'num_agent_steps_trained': 160000}, 'env_runners': {'episode_reward_max': np.float64(57268.07736125308), 'episode_reward_min': np.float64(57003.695631187235), 'episode_reward_mean': np.float64(57135.88649622016), 'episode_len_mean': np.float64(35040.0), 'episode_media': {}, 'episodes_timesteps_total': 70080, 'policy_reward_min': {'zone_1-1': np.float64(28501.847815593595), 'zone_2-1': np.float64(28501.847815593595)}, 'policy_reward_max': {'zone_1-1': np.float64(28634.038680626625), 'zone_2-1': np.float64(28634.038680626625)}, 'policy_reward_mean': {'zone_1-1': np.float64(28567.94324811011), 'zone_2-1': np.float64(28567.94324811011)}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [np.float64(57268.07736125308), np.float64(57003.695631187235)], 'episode_lengths': [35040, 35040], 'policy_zone_1-1_reward': [np.float64(28634.038680626625), np.float64(28501.847815593595)], 'policy_zone_2-1_reward': [np.float64(28634.038680626625), np.float64(28501.847815593595)]}, 'sampler_perf': {'mean_raw_obs_processing_ms': np.float64(0.18961373239575172), 'mean_inference_ms': np.float64(1.1084501984768276), 'mean_action_processing_ms': np.float64(0.14140419705458057), 'mean_env_wait_ms': np.float64(1.0479125742925273), 'mean_env_render_ms': np.float64(0.0)}, 'num_faulty_episodes': 0, 'connector_metrics': {}, 'num_episodes': 0, 'episode_return_max': np.float64(57268.07736125308), 'episode_return_min': np.float64(57003.695631187235), 'episode_return_mean': np.float64(57135.88649622016), 'episodes_this_iter': 0}, 'num_healthy_workers': 2, 'num_in_flight_async_sample_reqs': 0, 'num_remote_worker_restarts': 0, 'num_agent_steps_sampled': 160000, 'num_agent_steps_trained': 160000, 'num_env_steps_sampled': 80000, 'num_env_steps_trained': 80000, 'num_env_steps_sampled_this_iter': 4000, 'num_env_steps_trained_this_iter': 4000, 'num_env_steps_sampled_throughput_per_sec': 311.8557045484713, 'num_env_steps_trained_throughput_per_sec': 311.8557045484713, 'timesteps_total': 80000, 'num_env_steps_sampled_lifetime': 80000, 'num_agent_steps_sampled_lifetime': 160000, 'num_steps_trained_this_iter': 4000, 'agent_timesteps_total': 160000, 'timers': {'training_iteration_time_ms': 12628.206, 'restore_workers_time_ms': 0.005, 'training_step_time_ms': 12628.19, 'sample_time_ms': 5108.484, 'learn_time_ms': 7516.248, 'learn_throughput': 532.18, 'synch_weights_time_ms': 3.356}, 'counters': {'num_env_steps_sampled ...

# %%
# TODO evaluate plot
algo.evaluate()
# Out:
# {'env_runners': {'episode_reward_max': nan,
#   'episode_reward_min': nan,
#   'episode_reward_mean': nan,
#   'episode_len_mean': nan,
#   'episode_media': {},
#   'episodes_timesteps_total': 0,
#   'policy_reward_min': {},
#   'policy_reward_max': {},
#   'policy_reward_mean': {},
#   'custom_metrics': {},
#   'hist_stats': {'episode_reward': [], 'episode_lengths': []},
#   'sampler_perf': {},
#   'num_faulty_episodes': 0,
#   'connector_metrics': {},
#   'num_episodes': 0,
#   'episode_return_max': nan,
#   'episode_return_min': nan,
#   'episode_return_mean': nan,
#   'episodes_this_iter': 0},
#  'num_agent_steps_sampled_this_iter': 40000,
#  'num_env_steps_sampled_this_iter': 20000,
#  'timesteps_this_iter': 20000}
# /home/AD/user/lab/controllables-core/packages/controllables/core/tools/rllib/env.py:104: RuntimeWarning: Episode 'ca3c25a0df784345a6b99bb70b774ca3' @ 'step':
#   _warnings_.warn(RuntimeWarning(spec.message))
