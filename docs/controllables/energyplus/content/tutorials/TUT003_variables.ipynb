# %% [markdown]
# # 🔢 Chapter 3: Variables
#
# Before you start:
# - Make sure you have completed [](TUT000_setup.ipynb).
#
# What you will learn in this chapter:
# - How to _explore_ variables available.
# - How to _interact_ with variables.
# - Quirks.

# %%
from controllables.energyplus import examples

system = examples.systems.X1ZoneEvapCooler()

# %%
system.add('logging:progress').start()
# Out:
#   0%|          | 0/100.0 [00:00<?, ?it/s]
# System({'building': PosixPath('/home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/energyplus/dataset/basic/assets/models/1ZoneEvapCooler.idf'), 'weather': PosixPath('/home/AD/user/lab/controllables-core/.venv/lib/python3.11/site-packages/energyplus/dataset/basic/assets/weathers/USA_CO_Denver-Aurora-Buckley.AFB.724695_TMY3.epw')})

# %%
system.variables.available_keys()
# Out:
# /home/AD/user/lab/controllables-core/packages/controllables/energyplus/variables.py:546: OptionalModuleNotFoundWarning: Missing optional dependency(ies)/module(s), run: `/home/AD/user/lab/controllables-core/.venv/bin/python -m pip install "itables"`
#   _warnings_.warn(
#                     <details open>
#                         <summary>controllables.energyplus.variables.WallClock.Ref</summary>
#                         <figure><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>calendar</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>False</td>
#     </tr>
#   </tbody>
# </table></figure>
#                     </details>
#
#                     <details open>
#                         <summary>controllables.energyplus.variables.Actuator.Ref</summary>
#                         <figure><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>type</th>
#       <th>control_type</th>
#       <th>key</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Weather Data</td>
#       <td>Outdoor Dry Bulb</td>
#       <td>Environment</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Weather Data</td>
#       <td>Outdoor Dew Point</td>
#       <td>Environment</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Weather Data</td>
#       <td>Outdoor Relative Humidity</td>
#       <td>Environment</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Weather Data</td>
#       <td>Diffuse Solar</td>
#       <td>Environment</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Weather Data</td>
#       <td>Direct Solar</td>
#       <td>Environment</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Weather Data</td>
#       <td>Wind Speed</td>
#       <td>Environment</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Weather Data</td>
#       <td>Wind Direction</td>
#       <td>Environment</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Schedule:Compact</td>
#       <td>Schedule Value</td>
#       <td>SYSTEM AVAILABILITY SCHEDULE</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Schedule:Compact</td>
#       <td>Schedule Value</td>
#       <td>FAN AVAILABILITY SCHEDULE</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Schedule:Compact</td>
#       <td>Schedule Value</td>
#       <td>ZONE CONTROL TYPE SCHED</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Schedule:Compact</td>
#       <td>Schedule Value</td>
#       <td>HEATING SETPOINT SCHEDULE</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Material</td>
#       <td>Surface Property Solar Absorptance</td>
#       <td>C5 - 4 IN HW CONCRETE</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Material</td>
#       <td>Surface Property Thermal Absorptance</td>
#       <td>C5 - 4 IN HW CONCRETE</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Material</td>
#       <td>Surface Property Visible Absorptance</td>
#       <td>C5 - 4 IN HW CONCRETE</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Material</td>
#       <td>Surface Property Solar Absorptance</td>
#       <td>R13LAYER</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Material</td>
#       <td>Surface Property Thermal Absorptance</td>
#       <td>R13LAYER</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Material</td>
#       <td>Surface Property Visible Absorptance</td>
#       <td>R13LAYER</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Material</td>
#       <td>Surface Property Solar Absorptance</td>
#       <td>R31LAYER</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Material</td>
#       <td>Surface Property Thermal Absorptance</td>
#       <td>R31LAYER</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Material</td>
#       <td>Surface Property Visible Absorptance</td>
#       <td>R31LAYER</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Surface</td>
#       <td>Interior Surface Convection Heat Transfer Coefficient</td>
#       <td>ZN001:WALL001</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Surface</td>
#       <td>Exterior Surface Convection Heat Transfer Coefficient</td>
#       <td>ZN001:WALL001</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Surface</td>
#       <td>Interior Surface Convection Heat Transfer Coefficient</td>
#       <td>ZN001:WALL002</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Surface</td>
#       <td>Exterior Surface Convection Heat Transfer Coefficient</td>
#       <td>ZN001:WALL002</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Surface</td>
#       <td>Interior Surface Convection Heat Transfer Coefficient</td>
#       <td>ZN001:WALL003</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>Surface</td>
#       <td>Exterior Surface Convection Heat Transfer Coefficient</td>
#       <td>ZN001:WALL003</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>Surface</td>
#       <td>Interior Surface Convection Heat Transfer Coefficient</td>
#       <td>ZN001:WALL004</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Surface</td>
#       <td>Exterior Surface Convection Heat Transfer Coefficient</td>
#       <td>ZN001:WALL004</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Surface</td>
#       <td>Interior Surface Convection Heat Transfer Coefficient</td>
#       <td>ZN001:FLR001</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Surface</td>
#       <td>Exterior Surface Convection Heat Transfer Coefficient</td>
#       <td>ZN001:FLR001</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>Surface</td>
#       <td>Interior Surface Convection Heat Transfer Coefficient</td>
#       <td>ZN001:ROOF001</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Surface</td>
#       <td>Exterior Surface Convection Heat Transfer Coefficient</td>
#       <td>ZN001:ROOF001</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Surface</td>
#       <td>Construction State</td>
#       <td>ZN001:WALL001</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>Surface</td>
#       <td>Construction State</td>
#       <td>ZN001:WALL002</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>Surface</td>
#       <td>Construction State</td>
#       <td>ZN001:WALL003</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>Surface</td>
#       <td>Construction State</td>
#       <td>ZN001:WALL004</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>Surface</td>
#       <td>Construction State</td>
#       <td>ZN001:FLR001</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>Surface</td>
#       <td>Construction State</td>
#       <td>ZN001:ROOF001</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>Surface</td>
#       <td>View Factor To Ground</td>
#       <td>ZN001:WALL001</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>Surface</td>
#       <td>Outdoor Air Drybulb Temperature</td>
#       <td>ZN001:WALL001</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>Surface</td>
#       <td>Outdoor Air Wetbulb Temperature</td>
#       <td>ZN001:WALL001</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>Surface</td>
#       <td>Outdoor Air Wind Speed</td>
#       <td>ZN001:WALL001</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>Surface</td>
#       <td>Outdoor Air Wind Direction</td>
#       <td>ZN001:WALL001</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>Surface</td>
#       <td>View Factor To Ground</td>
#       <td>ZN001:WALL002</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>Surface</td>
#       <td>Outdoor Air Drybulb Temperature</td>
#       <td>ZN001:WALL002</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>Surface</td>
#       <td>Outdoor Air Wetbulb Temperature</td>
#       <td>ZN001:WALL002</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>Surface</td>
#       <td>Outdoor Air Wind Speed</td>
#       <td>ZN001:WALL002</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>Surface</td>
#       <td>Outdoor Air Wind Direction</td>
#       <td>ZN001:WALL002</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>Surface</td>
#       <td>View Factor To Ground</td>
#       <td>ZN001:WALL003</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>Surface</td>
#       <td>Outdoor Air Drybulb Temperature</td>
#       <td>ZN001:WALL003</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>Surface</td>
#       <td>Outdoor Air Wetbulb Temperature</td>
#       <td>ZN001:WALL003</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>Surface</td>
#       <td>Outdoor Air Wind Speed</td>
#       <td>ZN001:WALL003</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>Surface<

# %%
from controllables.core import TemporaryUnavailableError
from controllables.energyplus import (
    Actuator, 
    OutputVariable,
)

# %% [markdown]
# TODO notes on output varibles requested warning... and TempUnavailError

# %%
try:
    print(system['wallclock'].value)
    print(
        system[OutputVariable.Ref(
            type='Site Outdoor Air Drybulb Temperature', 
            key='ENVIRONMENT',
        )].value
    )
    print(
        system[
            Actuator.Ref(
                type='Weather Data', 
                control_type='Environment', 
                key='Outdoor Dry Bulb',
            )
        ].value
    )
except TemporaryUnavailableError:
    pass
# Out:
# 1999-04-15 21:40:00+00:00
# -2.166666666666667
# /home/AD/user/lab/controllables-core/packages/controllables/energyplus/variables.py:396: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Site Outdoor Air Drybulb Temperature', key='ENVIRONMENT')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(

# %%
from controllables.core.tools.records import VariableRecords

records = VariableRecords({
    '🕰️': system['wallclock:calendar'],
    'Δ🌡️': 
        system[OutputVariable.Ref('Site Outdoor Air Drybulb Temperature', 'ENVIRONMENT')] 
        - system[OutputVariable.Ref('Zone Mean Air Temperature', 'MAIN ZONE')],
}).watch(system.events['timestep'])
# Out:
# /home/AD/user/lab/controllables-core/packages/controllables/energyplus/variables.py:396: RuntimeWarning: OutputVariable(OutputVariable.Ref(type='Zone Mean Air Temperature', key='MAIN ZONE')) requested while Kernel() is running; It may not be available until the next run. More info: https://energyplus.readthedocs.io/en/latest/datatransfer.html#datatransfer.DataExchange.request_variable
#   _warnings_.warn(

# %%
records.plot.scatter(x='🕰️', y='Δ🌡️').watch(records.events['change'] % 1_000)

# %%
records.dataframe()
# Out:
#                             🕰️        Δ🌡️
# 0    2013-04-25 10:30:00+00:00 -15.500000
# 1    2013-04-25 10:40:00+00:00 -15.333333
# 2    2013-04-25 10:50:00+00:00 -15.166667
# 3    2013-04-25 11:00:00+00:00 -15.000000
# 4    2013-04-25 11:10:00+00:00 -14.666667
# ...                        ...        ...
# 3353 2013-05-18 17:20:00+00:00  -9.323357
# 3354 2013-05-18 17:30:00+00:00 -10.217497
# 3355 2013-05-18 17:40:00+00:00 -11.117938
# 3356 2013-05-18 17:50:00+00:00 -12.014128
# 3357 2013-05-18 18:00:00+00:00 -12.897728
#
# [3358 rows x 2 columns]
